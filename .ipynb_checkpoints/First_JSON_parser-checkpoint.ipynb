# %% [markdown]
# # Extract Lemmatization from JSON: Basic Parser
# The code in this notebook will parse [ORACC](http://oracc.org) `JSON` files to extract lemmatization data for one or more texts. The resulting `csv` (Comma Separated Values) file has two fields: a Text ID (e.g. `dcclt/Q000039`) and a string of lemmas in the format `lugal[king]N` (or `šarru[king]N` for Akkadian texts).
#
# The `JSON` files are available in a zipped format on [ORACC](http://oracc.org), at the address http://build-oracc.museum.upenn.edu/json/PROJECT.zip (replace PROJECT with the project abbreviation in lower case). If you wish to download a subproject, the address becomes http://build-oracc.museum.upenn.edu/json/PROJECT-SUBPROJECT.zip. The downloaded `ZIP` files must be put in a directory called `jsonzip`. You may use the script [download_ORACC-JSON.ipynb](download_ORACC-JSON.ipynb) or download the files by hand.
#
# The output of the Basic Parser does not recognize lines (all words/lemmas in a text are listed sequentially) and does not indicate breakage. These issues are of little consequence for [bag of words](https://en.wikipedia.org/wiki/Bag-of-words_model) techniques such as word clouds or [topic modeling](https://en.wikipedia.org/wiki/Topic_model), but may become serious limitations for other types of computational approaches. The Advanced Parser will introduce techniques to extract such data.
#
# [ORACC](http://oracc.org) `JSON` files also include data on the sign level (reading, sign name, unicode number, function, etc). These data are not extracted in the parsers demonstrated here, but the example code should provide a model for how any type of data can be extracted.

# %%
import pandas as pd
import zipfile
import json

# %% [markdown]
# ## 1.1 Input List of Text IDs
# Identify a list of text IDs (P, Q, and X numbers) in the directory `text_ids`. The IDs are six-digit P, Q, or X numbers preceded by a project abbreviation in the format 'PROJECT/P######' or 'PROJECT/SUBPROJECT/Q######'. For example:
# * dcclt/P117395
# * etcsri/Q001203
# * rinap/rinap1/Q003421
#
# The list should be created with a flat text editor such as Textedit or Emacs, and the filename should end in `.txt`.

# %%
filename = input('Filename: ')
# Out:
# Filename: sargonletters.txt

# %% [markdown]
# ## 1.2 Open the List of Text IDs and Remove Spaces and Empty Lines
# The list of text IDs is read; accidental space at the beginning or end of each line are removed, as well as blank lines. The Advanced Parser can read a partial text by indicating the beginning and the end of the desired text segment and this is also indicated in the list of text IDs in the format `PROJECT/TEXTID start line - stop line`. Since the Basic Parser only parses full texts, we strip everything after the first space.

# %%
textids = 'text_ids/' + filename
with open(textids, 'r') as f:
    pqxnos = f.readlines()
pqxnos = [x.strip() for x in pqxnos]        # strip spaces left and right
pqxnos = [x for x in pqxnos if not x == ""] # strip empty lines
pqxnos = [x.split()[0] for x in pqxnos]     # strip everything after the first space

# %% [markdown]
# ## 2.1 The `parsejson()` function
# The `parsejson()` function will "dig into" the `json` file (transformed into a dictionary) until it finds the relevant data. The `json` file consists of a hierarchy of `cdl` nodes; only the lowest nodes contain lemmatization data. The function goes down this hierarchy by calling itself when another `cdl` node is encountered. For nore information about the data hierarchy in the [ORACC](http://oracc.org) `json` files, see [ORACC Open Data](http://oracc.museum.upenn.edu/doc/opendata/index.html).
#
# The first argument of the `parsejson()` function is a `JSON` object, a dictionary that initially contains the entire contents of the original JSON file. The code takes the key `cdl` which itself contains an array (a list) of `JSON` objects. Iterating through these objects, if an object contains another `cdl` node, the function calls itself with this object as first argument. This way the function digs deeper and deeper into the `JSON` tree, until it does not encounter a `cdl` key anymore. Here we are at the level of individual words. The code checks for a key `f`, if it exists the value of that key is appended to the list `lemm_l`. This list is defined outside of the function proper.
#
# The field `id_text` is derived from the input list. It consists of a project abbreviation, such as `blms` or `cams/gkab` plus a text ID, in the format `cams/gkab/P338616` or `dcclt/Q000039`. The `id_text` is added as a second argument to the function and is added to the lemmatization data of every word.

# %%
def parsejson(text, id_text):
    for JSONobject in text["cdl"]:
        if "cdl" in JSONobject: 
            parsejson(JSONobject, id_text)
        if "f" in JSONobject:
            lemm = JSONobject["f"]
            lemm["id_text"] = id_text
            lemm_l.append(lemm)
    return

# %% [markdown]
# ## 2.2 Call the `parsejson()` function for every `JSON` file
# The code in this cell will read the list of text IDs identified above. Each text ID (e.g.`dcclt/Q000039`) is split into the ID number (`Q000039`) and the project designation (`dcclt`). The project designation is used to identify the right ZIP file in the directory `jsonzip`. The ID number is used to find the pertinent `json` file inside the ZIP.
#
# The command `json.loads()` reads the json data and transforms it into a Python dictionary (a sequence of keys and values).
#
# This dictionary, which is called `text` is now sent to the `parsejson()` function, with the text ID as second argument. The function adds lemmata to the `lemm_l` list.

# %%
lemm_l = []
for id_text in pqxnos:
    project = id_text[:-8].lower()
    pqx = id_text[-7:].upper()
    file = "jsonzip/" + project.replace("/", "-") + ".zip"
    try:
        z = zipfile.ZipFile(file)
    except:
        print(file + " does not exist or is not a proper ZIP file")
        continue
    data = z.read(project + "/corpusjson/" + pqx +".json")
    data_json = json.loads(data)
    try:
        print("parsing " + id_text)
        parsejson(data_json, id_text)
    except:
        print(id_text + ' is not available or not complete')
# Out:
# parsing saao/sargonletters/P224485
# parsing saao/sargonletters/P237089
# parsing saao/sargonletters/P238649
# parsing saao/sargonletters/P313416
# parsing saao/sargonletters/P313417
# parsing saao/sargonletters/P313419
# parsing saao/sargonletters/P313420
# parsing saao/sargonletters/P313421
# parsing saao/sargonletters/P313422
# parsing saao/sargonletters/P313425
# parsing saao/sargonletters/P313427
# parsing saao/sargonletters/P313434
# parsing saao/sargonletters/P313435
# parsing saao/sargonletters/P313437
# parsing saao/sargonletters/P313439
# parsing saao/sargonletters/P313442
# parsing saao/sargonletters/P313444
# parsing saao/sargonletters/P313445
# parsing saao/sargonletters/P313447
# parsing saao/sargonletters/P313448
# parsing saao/sargonletters/P313450
# parsing saao/sargonletters/P313451
# parsing saao/sargonletters/P313452
# parsing saao/sargonletters/P313453
# parsing saao/sargonletters/P313454
# parsing saao/sargonletters/P313455
# parsing saao/sargonletters/P313457
# parsing saao/sargonletters/P313458
# parsing saao/sargonletters/P313462
# parsing saao/sargonletters/P313469
# parsing saao/sargonletters/P313470
# parsing saao/sargonletters/P313471
# parsing saao/sargonletters/P313472
# parsing saao/sargonletters/P313473
# parsing saao/sargonletters/P313474
# parsing saao/sargonletters/P313476
# parsing saao/sargonletters/P313477
# parsing saao/sargonletters/P313478
# parsing saao/sargonletters/P313479
# parsing saao/sargonletters/P337150
# parsing saao/sargonletters/P337151
# parsing saao/sargonletters/P393855
# parsing saao/sargonletters/P393866
# parsing saao/sargonletters/X900004
# parsing saao/sargonletters/X900005
# parsing saao/sargonletters/X900006
# parsing saao/sargonletters/X900007
# parsing saao/sargonletters/X900008
# parsing saao/sargonletters/X900009
# parsing saao/sargonletters/X900010
# parsing saao/sargonletters/X900011
# parsing saao/sargonletters/X900012
# parsing saao/sargonletters/X900014
# parsing saao/sargonletters/X900015

# %%
word_df = pd.DataFrame(lemm_l).fillna('')
word_df
# Out:
#                      cf delim epos                   form  \
# 0                 awātu          N                  a-bat
# 1                 šarru          N                  LUGAL
# 2                   ana        PRP                   a-na
# 3      Aššur-šarru-uṣur         PN      {1}aš-šur-MAN-PAB
# 4                 šulmu          N                 šul-mu
# 5                 yâšim         IP                ia-a-ši
# 6                 šulmu          N                 šul-mu
# 7                   ana        PRP                   a-na
# 8             Mat-Aššur         GN         KUR-aš-šur{KI}
# 9                 libbu          N                 ŠA₃-ka
# 10                   lū        MOD                     lu
# 11                 ṭābu         AJ             DUG₃.GA-ka
# 12                   ša        REL                     ša
# 13               šapāru          V          taš-pur-an-ni
# 14                   mā        PRP                   ma-a
# 15                 māru          N          {LU₂}A-šip-ri
# 16                šipru          N          {LU₂}A-šip-ri
# 17                   ša        DET                     ša
# 18                 Mita         PN             {1}me-ta-a
# 19              Muskaya         EN        {KUR}mus-ka-a.a
# 20                  ina        PRP                    ina
# 21                muhhu          N              UGU-hi-ia
# 22                alāku          V              it-tal-ka
# 23                   mā        PRP                   ma-a
# 24                                                     14
# 25                 ṣābu          N               ERIM-MEŠ
# 26               Quwaya         EN          {KUR}qu-u-a.a
# 27                   ša        REL                     ša
# 28                 Urik         PN            {1}u₂-ri-ik
# 29                  ana        PRP                   a-na
# ...                 ...   ...  ...                    ...
# 87586              māru          N                   DUMU
# 87587                                                 x+x
# 87588                                                   x
# 87589                                                   x
# 87590                                                   x
# 87591                                                   x
# 87592                                                   x
# 87593                lā        MOD                     la
# 87594                                                al-x
# 87595                                                   x
# 87596                                                   x
# 87597                                                   x
# 87598                                                   x
# 87599               ina        PRP                    ina
# 87600              pānu          N           pa-ni-šu₂-nu
# 87601                mā        PRP                   ma-a
# 87602                                                   x
# 87603                                                   x
# 87604                lā        MOD                   la-a
# 87605             alāku          V               DU-ku-ni
# 87606              sisû          N       {ANŠE}KUR.RA-MEŠ
# 87607              leqû          V              ni-laq-qi
# 87608            wabālu          V                 nu-bal
# 87609             kallû          N              kal-li-u₂
# 87610                ša        DET                     ša
# 87611  Aššur-daʾʾinanni         PN  {1}aš-šur-KALAG-an-ni
# 87612           šaṣbutu          N           ša-aṣ-bu-tu₂
# 87613                ša        DET                     ša
# 87614        Arzuhinaya         EN  {URU}ar₂-zu-hi-na-a.a
# 87615             etāku          V               lu-ti-ki
#
#                                                      gdl                 gw  \
# 0      [{'v': 'a', 'gdl_utf8': '𒀀', 'id': 'P224485.2....               word
# 1      [{'gg': 'logo', 'gdl_type': 'logo', 'group': [...               king
# 2      [{'v': 'a', 'gdl_utf8': '𒀀', 'id': 'P224485.2....                 to
# 3      [{'det': 'semantic', 'pos': 'pre', 'seq': [{'n...                  1
# 4      [{'v': 'šul', 'gdl_utf8': '𒂄', 'id': 'P224485....       completeness
# 5      [{'v': 'ia', 'gdl_utf8': '𒅀', 'id': 'P224485.2...              to me
# 6      [{'v': 'šul', 'gdl_utf8': '𒂄', 'id': 'P224485....       completeness
# 7      [{'v': 'a', 'gdl_utf8': '𒀀', 'id': 'P224485.3....                 to
# 8      [{'gg': 'logo', 'gdl_type': 'logo', 'group': [...            Assyria
# 9      [{'gg': 'logo', 'gdl_type': 'logo', 'group': [...           interior
# 10     [{'v': 'lu', 'gdl_utf8': '𒇻', 'id': 'P224485.3...                may
# 11     [{'gg': 'logo', 'gdl_type': 'logo', 'group': [...               good
# 12     [{'v': 'ša', 'gdl_utf8': '𒊭', 'id': 'P224485.4...               that
# 13     [{'v': 'taš', 'gdl_utf8': '𒌨', 'id': 'P224485....               send
# 14     [{'v': 'ma', 'gdl_utf8': '𒈠', 'id': 'P224485.4...             saying
# 15     [{'gg': 'logo', 'gdl_type': 'logo', 'group': [...                son
# 16     [{'gg': 'logo', 'gdl_type': 'logo', 'group': [...            sending
# 17     [{'v': 'ša', 'gdl_utf8': '𒊭', 'id': 'P224485.4...                 of
# 18     [{'det': 'semantic', 'pos': 'pre', 'seq': [{'n...              Midas
# 19     [{'det': 'semantic', 'pos': 'pre', 'seq': [{'g...           Phrygian
# 20     [{'v': 'ina', 'gdl_utf8': '𒀸', 'id': 'P224485....                 in
# 21     [{'gg': 'logo', 'gdl_type': 'logo', 'group': [...              skull
# 22     [{'v': 'it', 'gdl_utf8': '𒀉', 'id': 'P224485.5...                 go
# 23     [{'v': 'ma', 'gdl_utf8': '𒈠', 'id': 'P224485.5...             saying
# 24     [{'n': 'n', 'sexified': '1(u) 4(diš)', 'form':...
# 25     [{'gg': 'logo', 'gdl_type': 'logo', 'group': [...             people
# 26     [{'det': 'semantic', 'pos': 'pre', 'seq': [{'g...          from Quwe
# 27     [{'v': 'ša', 'gdl_utf8': '𒊭', 'id': 'P224485.6...               that
# 28     [{'det': 'semantic', 'pos': 'pre', 'seq': [{'n...                  1
# 29     [{'v': 'a', 'gdl_utf8': '𒀀', 'id': 'P224485.6....                 to
# ...                                                  ...                ...
# 87586  [{'gg': 'logo', 'gdl_type': 'logo', 'group': [...                son
# 87587  [{'gg': 'ligature', 'gdl_type': 'ligature', 'g...
# 87588  [{'v': 'x', 'gdl_utf8': 'x', 'id': 'X900015.31...
# 87589  [{'v': 'x', 'gdl_utf8': 'x', 'id': 'X900015.31...
# 87590  [{'v': 'x', 'gdl_utf8': 'x', 'id': 'X900015.31...
# 87591  [{'v': 'x', 'gdl_utf8': 'x', 'id': 'X900015.31...
# 87592  [{'v': 'x', 'gdl_utf8': 'x', 'id': 'X900015.31...
# 87593  [{'v': 'la', 'gdl_utf8': '𒆷', 'id': 'X900015.3...                not
# 87594  [{'v': 'al', 'gdl_utf8': '𒀠', 'id': 'X900015.3...
# 87595  [{'v': 'x', 'gdl_utf8': 'x', 'id': 'X900015.32...
# 87596  [{'v': 'x', 'gdl_utf8': 'x', 'id': 'X900015.32...
# 87597  [{'v': 'x', 'gdl_utf8': 'x', 'id': 'X900015.32...
# 87598  [{'v': 'x', 'gdl_utf8': 'x', 'id': 'X900015.32...
# 87599  [{'v': 'ina', 'gdl_utf8': '𒀸', 'id': 'X900015....                 in
# 87600  [{'v': 'pa', 'gdl_utf8': '𒉺', 'id': 'X900015.3...              front
# 87601  [{'v': 'ma', 'gdl_utf8': '𒈠', 'id': 'X900015.3...             saying
# 87602  [{'v': 'x', 'gdl_utf8': 'x', 'id': 'X900015.33...
# 87603  [{'v': 'x', 'gdl_utf8': 'x', 'id': 'X900015.33...
# 87604  [{'v': 'la', 'gdl_utf8': '𒆷', 'id': 'X900015.3...                not
# 87605  [{'gg': 'logo', 'gdl_type': 'logo', 'group': [...                 go
# 87606  [{'gg': 'logo', 'gdl_type': 'logo', 'group': [...              horse
# 87607  [{'v': 'ni', 'gdl_utf8': '𒉌', 'id': 'X900015.3...               take
# 87608  [{'v': 'nu', 'gdl_utf8': '𒉡', 'id': 'X900015.3...              bring
# 87609  [{'v': 'kal', 'gdl_utf8': '𒆗', 'id': 'X900015....  express messenger
# 87610  [{'v': 'ša', 'gdl_utf8': '𒊭', 'id': 'X900015.3...                 of
# 87611  [{'det': 'semantic', 'pos': 'pre', 'seq': [{'n...                  1
# 87612  [{'v': 'ša', 'gdl_utf8': '𒊭', 'id': 'X900015.3...           supplies
# 87613  [{'v': 'ša', 'gdl_utf8': '𒊭', 'id': 'X900015.3...                 of
# 87614  [{'det': 'semantic', 'pos': 'pre', 'seq': [{'g...                  1
# 87615  [{'v': 'lu', 'gdl_utf8': '𒇻', 'id': 'X900015.3...        be on guard
#
#                           id_text          lang              norm  pos  \
# 0      saao/sargonletters/P224485  akk-x-neoass              abat    N
# 1      saao/sargonletters/P224485  akk-x-neoass             šarri    N
# 2      saao/sargonletters/P224485  akk-x-neoass               ana  PRP
# 3      saao/sargonletters/P224485  akk-x-neoass  Aššur-šarru-uṣur   PN
# 4      saao/sargonletters/P224485  akk-x-neoass             šulmu    N
# 5      saao/sargonletters/P224485  akk-x-neoass             ayāši   IP
# 6      saao/sargonletters/P224485  akk-x-neoass             šulmu    N
# 7      saao/sargonletters/P224485  akk-x-neoass               ana  PRP
# 8      saao/sargonletters/P224485  akk-x-neoass         Mat-Aššur   GN
# 9      saao/sargonletters/P224485  akk-x-neoass           libbaka    N
# 10     saao/sargonletters/P224485  akk-x-neoass                lū  MOD
# 11     saao/sargonletters/P224485  akk-x-neoass             ṭābka   AJ
# 12     saao/sargonletters/P224485  akk-x-neoass                ša  REL
# 13     saao/sargonletters/P224485  akk-x-neoass        tašpuranni    V
# 14     saao/sargonletters/P224485  akk-x-neoass                mā  PRP
# 15     saao/sargonletters/P224485  akk-x-neoass               mār    N
# 7                     to
# 8                Assyria
# 9                   mood
# 10                   may
# 11                  good
# 12                  what
# 13                 write
# 14                saying
# 15                   son
# 16               sending
# 17                    of
# 18                 Midas
# 19              Phrygian
# 20                    in
# 21                 skull
# 22                  come
# 23                saying
# 24
# 25                troops
# 26             from Quwe
# 27                   who
# 28                     1
# 29                   for
# ...                  ...
# 87586                son
# 87587
# 87588
# 87589
# 87590
# 87591
# 87592
# 87593                not
# 87594
# 87595
# 87596
# 87597
# 87598
# 87599                 in
# 87600              front
# 87601             saying
# 87602
# 87603
# 87604                not
# 87605               come
# 87606              horse
# 87607           purchase
# 87608              bring
# 87609  express messenger
# 87610                 of
# 87611                  1
# 87612           supplies
# 87613                 of
# 87614                  1
# 87615           be alert
#
# [87616 rows x 11 columns]

# %% [markdown]
# ## 3.1 Create a `lemma` column
# The following code combines the `cf` (Citation Form), `gw` (Guide Word), and `pos` (Part of Speech) columns to create a new `lemma` column with the format `cf[gw]pos`, for instance `šarru[king]N` or `lugal[king]N`. Unlemmatized words do not have `cf`, `gw`, or `pos` - they only have `form` (the transliteration). The function therefore has a condition: if `cf` is empty, the format should be `form[NA]NA`. Alternatively, one may leave out non-lemmatized words altogether and create the `lemma` column by simply adding up `cf`, `gw`, and `pos`, as follows:
#
# > `word_df = word_df[word_df['cf'] != '']`
#
# > `word_df['lemma'] = word_df['cf'] + '[' + word_df['gw'] + ']' + word_df['pos']`

# %%
word_df["lemma"] = word_df.apply(lambda r: (r["cf"] + '[' + r["gw"] + ']' + r["pos"]) if r["cf"] != '' 
                                 else r['form'] + '[NA]NA', axis=1)
word_df[['id_text', 'lemma']]

# %% [markdown]
# ## 3.2 Remove Spaces and Commas from the Lemma
# Spaces and commas in the Guide Word may cause trouble in computational methods in tokenization, or when saved in Comma Separated Values format. All spaces and commas are replaced by hyphens or nothing, respectively.

# %%
word_df.loc[:,'lemma'] = [x.replace(' ', '-') for x in word_df.loc[:,'lemma']]
word_df.loc[:,'lemma'] = [x.replace(',', '') for x in word_df.loc[:,'lemma']]
word_df

# %% [markdown]
# ## 3.3 Group by Textid
# Get all the lemmas that belong to a single text in one row (one row = one document). The `agg()` (aggregate) function, which works on the result of a `groupby()` process aggregates columns of the original dataframe. The function takes a dictionary in which the keys are column names and the values are functions to be used in the aggregation process. The example below has only one such function (`' '.join` will join all entries in the colum `lemma` with a space in between); one may specify (the same or different) functions for different columns, for instance:
# > word_df = word_df.groupby("textid").agg({"lemma": ' '.join, "base": ' '.join})

# %%
word_df = word_df.groupby("id_text").agg({"lemma": ' '.join})
word_df

# %% [markdown]
# ## 4 Save Results in CSV file
# The `.csv` file has the same name as the list of textid's that was used at the beginning of this notebook. In most computers, `csv` files open automatically in Excel. This spread sheet program does not deal well with `utf-8` encoding. If you intend to use the file in Excel, change `encoding ='utf-8'` to `encoding='utf-16'`. For usage in computational text analysis applications `utf-8` is usually preferred.

# %%
savefile =  filename[:-3] + 'csv'
with open('output/' + savefile, 'w') as w:
    word_df.to_csv(w, encoding = 'utf-8')
