# %% [markdown]
# # Extract Lemmatization from JSON: Basic Parser
# The code in this notebook will parse [ORACC](http://oracc.org) `JSON` files to extract lemmatization data for one or more texts. The resulting `csv` (Comma Separated Values) file has two fields: a Text ID (e.g. `dcclt/Q000039`) and a string of lemmas in the format `lugal[king]N` (or `šarru[king]N` for Akkadian texts).
#
# The Basic Parser downloads one `json` file a time from the [ORACC](http://oracc.org) server and then parses that file, continuing with the next file. This method is not ideal for large amounts of data (for instance if you intent to parse an entire project, or several projects at once). While going through a long list of files, the connection with the server may get reset (for instance when the computer goes to sleep, or if there is a brief period of bad connectivity) and the script will fail. The Advanced Parser will introduce a better way of doing that.
#
# The output of the Basic Parser does not recognize lines (all words/lemmas in a text are listed sequentially) and does not indicate breakage. These issues are of little consequence for [bag of words](https://en.wikipedia.org/wiki/Bag-of-words_model) techniques such as [topic modeling](https://en.wikipedia.org/wiki/Topic_model), but may become serious limitations for other types of computational approaches. The Advanced Parser will introduce techniques to extract such data.
#
# [ORACC](http://oracc.org) `json` files also include data on the sign level (reading, sign name, unicode number, function, etc). These data are not extracted in the parsers demonstrated here, but the example code should provide a model for how any type of data can be extracted.

# %%
import requests
import pandas as pd

# %% [markdown]
# ## 1.1 Input List of Text IDs
# Identify a list of text IDs (P, Q, and X numbers) in the directory `text_ids`. The IDs are six-digit P, Q, or X numbers preceded by a project abbreviation in the format 'PROJECT/P######' or 'PROJECT/SUBPROJECT/Q######'. For example:
# * dcclt/P117395
# * etcsri/Q001203
# * rinap/rinap1/Q003421
#
# The list should be created with a flat text editor such as Textedit or Emacs, and the filename should end in `.txt`.
#
# The P, Q, and X numbers available in a project are listed in the project's `corpus.json` at the address `http://oracc.org/[PROJECT]/corpus.json` (for instance http://oracc.org/saao/saa01/corpus.json).

# %%
filename = input('Filename: ')
# Out:
# Filename: saa_test.txt

# %% [markdown]
# ## 1.2 Open the List of Text IDs and Remove Spaces and Empty Lines

# %%
textids = 'text_ids/' + filename
with open(textids, 'r') as f:
    pqxnos = f.readlines()
pqxnos = [x.strip() for x in pqxnos]        # strip spaces left and right
pqxnos = [x for x in pqxnos if not x == ""] # strip empty lines

# %% [markdown]
# ## 2.1 The `parsejson()` function
# The `parsejson()` function will "digg into" the `json` file (transformed into a dictionary) until it finds the relevant data. The `json` file consists of a hierarchy of `cdl` nodes; only the lowest nodes contain lemmatization data. The function goes down this hierarchy by calling itself when another `cdl` node is encountered.
#
# The argument of `parsejson()` is a `JSON` object, a dictionary that initially contains the entire text data. The code takes the key `cdl` which contains an array (a list) of `JSON` objects. Iterating through these objects, if an object contains another `cdl` node, the function calls itself with this object as argument. This way the function digs deeper and deeper into the `JSON` tree, until it does not encounter a `cdl` key anymore. Here we are at the level of individual words. The code checks for a key `f`, if it exists it is appended to the list `lemm-l`. This list is defined outside of the function proper.

# %%
def parsejson(text):
    for JSONobject in text["cdl"]:
        if "cdl" in JSONobject: 
            parsejson(JSONobject)
        if "f" in JSONobject:
            lemm_l.append(JSONobject["f"])
    return

# %% [markdown]
# ## 2.2 Call the `parsejson()` function for every `JSON` file
# The code in this cell will read the list of text IDs identified above. Each text ID (e.g.`dcclt/Q000039`) is split into the ID number (`Q000039`) and the project designation (`dcclt`). These elements are used to build the `URL` for the `json` file on the [ORACC](http://oracc.org) server.
#
# The `json` file is downloaded with the `requests` library and transformed into a Python object (a dictionary) with the `json()` function of this same library.
#
# This dictionary, which is called `text` is now sent to the `parsejson()` function. The function returns a list of lemmata (lemm_text`

# %%
lemm_l = []
for id_text in pqxnos:
    project = id_text[:-8].lower()
    pqx = id_text[-7:].upper()
    url = "http://oracc.org/" + project + '/corpusjson/' + pqx + '.json'
    r = requests.get(url).json()
    try:
        print("parsing " + id_text)
        parsejson(r)
    except:
        print(id_text + ' is not available or not complete')
# Out:
# parsing saao/saa01/P224485
# parsing saao/saa01/P313915
# parsing saao/saa01/P313876
# parsing saao/saa01/P314243
# parsing saao/saa01/P334194
# parsing saao/saa01/P334190
# parsing saao/saa01/P313755
# parsing saao/saa01/P313644
# parsing saao/saa01/P314001
# parsing saao/saa01/P334195
# parsing saao/saa01/P313425
# parsing saao/saa01/P313458

# %%
word_df = pd.DataFrame(lemm_l).fillna('')
word_df
# Out:
#                     cf delim epos               form  \
# 0                awātu          N              a-bat
# 1                šarru          N              LUGAL
# 2                  ana        PRP               a-na
# 3     Aššur-šarru-uṣur         PN  {1}aš-šur-MAN-PAB
# 4                šulmu          N             šul-mu
# 5                yâšim         IP            ia-a-ši
# 6                šulmu          N             šul-mu
# 7                  ana        PRP               a-na
# 8            Mat-Aššur         GN     KUR-aš-šur{KI}
# 9                libbu          N             ŠA₃-ka
# 10                  lū        MOD                 lu
# 11                ṭābu         AJ         DUG₃.GA-ka
# 12                  ša        REL                 ša
# 13              šapāru          V      taš-pur-an-ni
# 14                  mā        PRP               ma-a
# 15                māru          N      {LU₂}A-šip-ri
# 16               šipru          N      {LU₂}A-šip-ri
# 17                  ša        DET                 ša
# 18                Mita         PN         {1}me-ta-a
# 19             Muskaya         EN    {KUR}mus-ka-a.a
# 20                 ina        PRP                ina
# 21               muhhu          N          UGU-hi-ia
# 22               alāku          V          it-tal-ka
# 23                  mā        PRP               ma-a
# 24                                                14
# 25                ṣābu          N           ERIM-MEŠ
# 26              Quwaya         EN      {KUR}qu-u-a.a
# 27                  ša        REL                 ša
# 28                Urik         PN        {1}u₂-ri-ik
# 29                 ana        PRP               a-na
# ...                ...   ...  ...                ...
# 2220                                         15-KAM₂
# 2221               ina        PRP                ina
# 2222              bītu          N          E₂-DINGIR
# 2223               ilu          N          E₂-DINGIR
# 2224             biātu          V           ni-bi-ad
# 2225                                               o
# 2226               ūma         AV            u₂-ma-a
# 2227               ina        PRP             im-mat
# 2228              mati         QP             im-mat
# 2229             šarru          N              LUGAL
# 2230              qabû          V      i-qab-bu-u-ni
# 2231                                               x
# 2232                                               x
# 2233                                               x
# 2234               ina        PRP                ina
# 2235             muhhu          N                UGU
# 2236            ramāku          N     ra-ma-ki-ša-KA
# 2237                ša        DET     ra-ma-ki-ša-KA
# 2238                pû          N     ra-ma-ki-ša-KA
# 2239                                            u₂-x
# 2240                                               x
# 2241                                               x
# 2242                                               x
# 2243                                        li-x-lik
# 2244               ina        PRP                ina
# 2245                                              pa
# 2246                                               x
# 2247                                               x
# 2248                                               x
# 2249                                               x
#
#                                                     gdl               gw  \
# 0     [{'v': 'a', 'gdl_utf8': '𒀀', 'id': 'P224485.2....             word
# 1     [{'s': 'LUGAL', 'gdl_utf8': '𒈗', 'id': 'P22448...             king
# 2     [{'v': 'a', 'gdl_utf8': '𒀀', 'id': 'P224485.2....               to
# 3     [{'det': 'semantic', 'pos': 'pre', 'seq': [{'n...                1
# 4     [{'v': 'šul', 'gdl_utf8': '𒂄', 'id': 'P224485....     completeness
# 5     [{'v': 'ia', 'gdl_utf8': '𒅀', 'id': 'P224485.2...            to me
# 6     [{'v': 'šul', 'gdl_utf8': '𒂄', 'id': 'P224485....     completeness
# 7     [{'v': 'a', 'gdl_utf8': '𒀀', 'id': 'P224485.3....               to
# 8     [{'s': 'KUR', 'gdl_utf8': '𒆳', 'id': 'P224485....          Assyria
# 9     [{'s': 'ŠA₃', 'gdl_utf8': '𒊮', 'id': 'P224485....         interior
# 10    [{'v': 'lu', 'gdl_utf8': '𒇻', 'id': 'P224485.3...              may
# 11    [{'gg': 'logo', 'gdl_type': 'logo', 'delim': '...             good
# 12    [{'v': 'ša', 'gdl_utf8': '𒊭', 'id': 'P224485.4...             that
# 13    [{'v': 'taš', 'gdl_utf8': '𒌨', 'id': 'P224485....             send
# 14    [{'v': 'ma', 'gdl_utf8': '𒈠', 'id': 'P224485.4...           saying
# 15    [{'det': 'semantic', 'pos': 'pre', 'seq': [{'f...              son
# 16    [{'det': 'semantic', 'pos': 'pre', 'seq': [{'f...          sending
# 17    [{'v': 'ša', 'gdl_utf8': '𒊭', 'id': 'P224485.4...               of
# 18    [{'det': 'semantic', 'pos': 'pre', 'seq': [{'n...            Midas
# 19    [{'det': 'semantic', 'pos': 'pre', 'seq': [{'s...         Phrygian
# 20    [{'v': 'ina', 'gdl_utf8': '𒀸', 'id': 'P224485....               in
# 21    [{'s': 'UGU', 'gdl_utf8': '𒌋𒅗', 'id': 'P224485...            skull
# 22    [{'v': 'it', 'gdl_utf8': '𒀉', 'id': 'P224485.5...               go
# 23    [{'v': 'ma', 'gdl_utf8': '𒈠', 'id': 'P224485.5...           saying
# 24    [{'n': 'n', 'sexified': '1(u) 4(diš)', 'form':...
# 25    [{'s': 'ERIM', 'gdl_utf8': '𒂟', 'id': 'P224485...           people
# 26    [{'det': 'semantic', 'pos': 'pre', 'seq': [{'s...        from Quwe
# 27    [{'v': 'ša', 'gdl_utf8': '𒊭', 'id': 'P224485.6...             that
# 28    [{'det': 'semantic', 'pos': 'pre', 'seq': [{'n...                1
# 29    [{'v': 'a', 'gdl_utf8': '𒀀', 'id': 'P224485.6....               to
# ...                                                 ...              ...
# 2220  [{'n': 'n', 'sexified': '1(u) 5(diš)', 'form':...
# 2221  [{'v': 'ina', 'gdl_utf8': '𒀸', 'id': 'P313458....               in
# 2222  [{'s': 'E₂', 'gdl_utf8': '𒂍', 'id': 'P313458.2...            house
# 2223  [{'s': 'E₂', 'gdl_utf8': '𒂍', 'id': 'P313458.2...              god
# 2224  [{'v': 'ni', 'gdl_utf8': '𒉌', 'id': 'P313458.2...  spend the night
# 2225  [{'v': 'o', 'gdl_utf8': 'o', 'id': 'P313458.27...
# 2226  [{'v': 'u₂', 'gdl_utf8': '𒌑', 'id': 'P313458.2...            today
# 2227  [{'v': 'im', 'gdl_utf8': '𒅎', 'id': 'P313458.2...               in
# 2228  [{'v': 'im', 'gdl_utf8': '𒅎', 'id': 'P313458.2...            when?
# 2229  [{'s': 'LUGAL', 'gdl_utf8': '𒈗', 'id': 'P31345...             king
# 2230  [{'v': 'i', 'gdl_utf8': '𒄿', 'id': 'P313458.28...              say
# 2231  [{'v': 'x', 'gdl_utf8': 'x', 'id': 'P313458.28...
# 2232  [{'v': 'x', 'gdl_utf8': 'x', 'id': 'P313458.28...
# 2233  [{'v': 'x', 'gdl_utf8': 'x', 'id': 'P313458.28...
# 2234  [{'v': 'ina', 'gdl_utf8': '𒀸', 'id': 'P313458....               in
# 2235  [{'s': 'UGU', 'gdl_utf8': '𒌋𒅗', 'id': 'P313458...            skull
# 2236  [{'v': 'ra', 'gdl_utf8': '𒊏', 'id': 'P313458.3...          bathing
# 2237  [{'v': 'ra', 'gdl_utf8': '𒊏', 'id': 'P313458.3...               of
# 2238  [{'v': 'ra', 'gdl_utf8': '𒊏', 'id': 'P313458.3...            mouth
# 2239  [{'v': 'u₂', 'gdl_utf8': '𒌑', 'id': 'P313458.3...
# 2240  [{'v': 'x', 'gdl_utf8': 'x', 'id': 'P313458.30...
# 2241  [{'v': 'x', 'gdl_utf8': 'x', 'id': 'P313458.30...
# 2242  [{'v': 'x', 'gdl_utf8': 'x', 'id': 'P313458.30...
# 2243  [{'form': 'li', 'gdl_utf8': '𒇷', 'id': 'P31345...
# 2244  [{'v': 'ina', 'gdl_utf8': '𒀸', 'id': 'P313458....               in
# 2245  [{'v': 'pa', 'gdl_utf8': '𒉺', 'id': 'P313458.3...
# 2246  [{'v': 'x', 'gdl_utf8': 'x', 'id': 'P313458.31...
# 2247  [{'v': 'x', 'gdl_utf8': 'x', 'id': 'P313458.31...
# 2248  [{'v': 'x', 'gdl_utf8': 'x', 'id': 'P313458.31...
# 2249  [{'v': 'x', 'gdl_utf8': 'x', 'id': 'P313458.31...
#
#               lang              norm  pos            sense
# 0     akk-x-neoass              abat    N             word
# 1     akk-x-neoass             šarri    N             king
# 2     akk-x-neoass               ana  PRP               to
# 3     akk-x-neoass  Aššur-šarru-uṣur   PN                1
# 4     akk-x-neoass             šulmu    N           health
# 5     akk-x-neoass             ayāši   IP               me
# 6     akk-x-neoass             šulmu    N           health
# 7     akk-x-neoass               ana  PRP               to
# 8     akk-x-neoass         Mat-Aššur   GN          Assyria
# 9     akk-x-neoass           libbaka    N             mood
# 10    akk-x-neoass                lū  MOD              may
# 11    akk-x-neoass             ṭābka   AJ             good
# 12    akk-x-neoass                ša  REL             what
# 13    akk-x-neoass        tašpuranni    V            write
# 14    akk-x-neoass                mā  PRP           saying
# 15    akk-x-neoass               mār    N              son
# 16    akk-x-neoass             šipri    N          sending
# 17    akk-x-neoass                ša  DET               of
# 18    akk-x-neoass              Meta   PN            Midas
# 19    akk-x-neoass           Muskaya   EN         Phrygian
# 20    akk-x-neoass               ina  PRP               in
# 21    akk-x-neoass           muhhīya    N            skull
# 22    akk-x-neoass           ittalka    V             come
# 23    akk-x-neoass                mā  PRP           saying
# 24    akk-x-neoass                      n
# 25    akk-x-neoass            ṣābāni    N           troops
# 26    akk-x-neoass            Quwaya   EN        from Quwe
# 27    akk-x-neoass                ša  REL              who
# 28    akk-x-neoass              Urik   PN                1
# 29    akk-x-neoass               ana  PRP              for
# ...            ...               ...  ...              ...
# 2220  akk-x-neoass                      n
# 2221  akk-x-neoass               ina  PRP               in
# 2222  akk-x-neoass               bēt    N            house
# 2223  akk-x-neoass               ili    N              god
# 2224  akk-x-neoass            nibīad    V  spend the night
# 2225  akk-x-neoass                      u
# 2226  akk-x-neoass               ūmâ   AV              now
# 2227  akk-x-neoass               ina  PRP               in
# 2228  akk-x-neoass               mat   QP            when?
# 2229  akk-x-neoass             šarru    N             king
# 2230  akk-x-neoass          iqabbûni    V              say
# 2231  akk-x-neoass                      u
# 2232  akk-x-neoass                      u
# 2233  akk-x-neoass                      u
# 2234  akk-x-neoass               ina  PRP               in
# 2235  akk-x-neoass             muhhi    N              top
# 2236  akk-x-neoass            ramāki    N          bathing
# 2237  akk-x-neoass                ša  DET               of
# 2238  akk-x-neoass                pî    N            mouth
# 2239  akk-x-neoass                      u
# 2240  akk-x-neoass                      u
# 2241  akk-x-neoass                      u
# 2242  akk-x-neoass                      u
# 2243  akk-x-neoass                      u
# 2244  akk-x-neoass               ina  PRP               in
# 2245  akk-x-neoass                      u
# 2246  akk-x-neoass                      u
# 2247  akk-x-neoass                      u
# 2248  akk-x-neoass                      u
# 2249  akk-x-neoass                      u
#
# [2250 rows x 10 columns]

# %% [markdown]
# ## 3.1 Create a `lemma` column
# The following code combines the `cf` (Citation Form), `gw` (Guide Word), and `pos` (Part of Speech) columns to create a new `lemma` column with the format `cf[gw]pos`, for instance `šarru[king]N` or `lugal[king]N`. Unlemmatized words do not have `cf`, `gw`, or `pos` - they only have `form` (the transliteration). The function therefore has a condition: if `cf` is empty, the format should be `form[NA]NA`. Alternatively, one may leave out non-lemmatized words altogether and create the `lemma` column by simply adding up `cf`, `gw`, and `pos`, as follows:
#
# > `word_df = word_df[word_df['cf'] != '']`
#
# > `word_df['lemma'] = word_df['cf'] + '[' + word_df['gw'] + ']' + word_df['pos']`

# %%
word_df["lemma"] = word_df.apply(lambda r: (r["cf"] + '[' + r["gw"] + ']' + r["pos"]) if r["cf"] != '' 
                                 else r['form'] + '[NA]NA', axis=1)
word_df[['textid', 'lemma']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-ff5ce5ee04ea> in <module>()
#       1 word_df["lemma"] = word_df.apply(lambda r: (r["cf"] + '[' + r["gw"] + ']' + r["pos"]) if r["cf"] != ''
#       2                                  else r['form'] + '[NA]NA', axis=1)
# ----> 3 word_df[['textid', 'lemma']]
#
# /Users/veldhuis/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2051         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2052             # either boolean or fancy integer index
# -> 2053             return self._getitem_array(key)
#    2054         elif isinstance(key, DataFrame):
#    2055             return self._getitem_frame(key)
#
# /Users/veldhuis/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2095             return self.take(indexer, axis=0, convert=False)
#    2096         else:
# -> 2097             indexer = self.ix._convert_to_indexer(key, axis=1)
#    2098             return self.take(indexer, axis=1, convert=True)
#    2099
#
# /Users/veldhuis/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1228                 mask = check == -1
#    1229                 if mask.any():
# -> 1230                     raise KeyError('%s not in index' % objarr[mask])
#    1231
#    1232                 return _values_from_object(indexer)
#
# KeyError: "['textid'] not in index"

# %% [markdown]
# ## 3.2 Remove Spaces and Commas from the Lemma
# Spaces and commas in the Guide Word may cause trouble in computational methods in tokenization, or when saved in Comma Separated Values format. All spaces and commas are replaced by hyphens or nothing, respectively.

# %%
word_df.loc[:,'lemma'] = [x.replace(' ', '-') for x in word_df.loc[:,'lemma']]
word_df.loc[:,'lemma'] = [x.replace(',', '') for x in word_df.loc[:,'lemma']]
word_df

# %% [markdown]
# ## 3.3 Group by Textid
# Get all the lemmas that belong to a single text in one row (one row = one document). The `agg()` (aggregate) function, which works on the result of a `groupby()` process aggregates columns of the original dataframe. The function takes a dictionary in which the keys are column names and the values are functions to be used in the aggregation process. The example below has only one such function (`' '.join` will join all entries in the colum `lemma` with a space in between); one may specify (the same or different) functions for different columns, for instance:
# > word_df = word_df.groupby("textid").agg({"lemma": ' '.join, "base": ' '.join})

# %%
word_df = word_df.groupby("textid").agg({"lemma": ' '.join})
word_df

# %% [markdown]
# ## 4 Save Results in CSV file
# The `.csv` file has the same name as the list of textid's that was used at the beginning of this notebook. In most computers, `csv` files open automatically in Excel. This spread sheet program does not deal well with `utf-8` encoding. If you intend to use the file in Excel, change `encoding ='utf-8'` to `encoding='utf-16'`. For usage in computational text analysis applications `utf-8` is usually preferred.

# %%
savefile =  filename[:-3] + 'csv'
with open('output/' + savefile, 'w') as w:
    word_df.to_csv(w, encoding = 'utf-8')
