# %% [markdown]
# # Extract Lemmatization from JSON: Basic Parser
# The code in this notebook will parse [ORACC](http://oracc.org) `JSON` files to extract lemmatization data for one or more texts. The resulting `csv` (Comma Separated Values) file has two fields: a Text ID (e.g. `dcclt/Q000039`) and a string of lemmas in the format `lugal[king]N` (or `šarru[king]N` for Akkadian texts).
#
# The Basic Parser downloads one `json` file a time from the [ORACC](http://oracc.org) server and then parses that file, continuing with the next file. This method is not ideal for large amounts of data (for instance if you intent to parse an entire project, or several projects at once). While going through a long list of files, the connection with the server may get reset (for instance when the computer goes to sleep, or if there is a brief period of bad connectivity) and the script will fail. The Advanced Parser will introduce a better way of doing that.
#
# The output of the Basic Parser does not recognize lines (all words/lemmas in a text are listed sequentially) and does not indicate breakage. These issues are of little consequence for [bag of words](https://en.wikipedia.org/wiki/Bag-of-words_model) techniques such as [topic modeling](https://en.wikipedia.org/wiki/Topic_model), but may become serious limitations for other types of computational approaches. The Advanced Parser will introduce techniques to extract such data.
#
# [ORACC](http://oracc.org) `JSON` files also include data on the sign level (reading, sign name, unicode number, function, etc). These data are not extracted in the parsers demonstrated here, but the example code should provide a model for how any type of data can be extracted.

# %%
import requests
import pandas as pd

# %% [markdown]
# ## 1.1 Input List of Text IDs
# Identify a list of text IDs (P, Q, and X numbers) in the directory `text_ids`. The IDs are six-digit P, Q, or X numbers preceded by a project abbreviation in the format 'PROJECT/P######' or 'PROJECT/SUBPROJECT/Q######'. For example:
# * dcclt/P117395
# * etcsri/Q001203
# * rinap/rinap1/Q003421
#
# The list should be created with a flat text editor such as Textedit or Emacs, and the filename should end in `.txt`.
#
# The P, Q, and X numbers available in a project are listed in the project's `corpus.json` at the address `http://oracc.org/[PROJECT]/corpus.json` (for instance http://oracc.org/saao/saa01/corpus.json).

# %%
filename = input('Filename: ')
# Out:
# Filename: test.txt

# %% [markdown]
# ## 1.2 Open the List of Text IDs and Remove Spaces and Empty Lines

# %%
textids = 'text_ids/' + filename
with open(textids, 'r') as f:
    pqxnos = f.readlines()
pqxnos = [x.strip() for x in pqxnos]        # strip spaces left and right
pqxnos = [x for x in pqxnos if not x == ""] # strip empty lines
pqxnos = [x.split()[0] for x in pqxnos]     # strip everything after the first space

# %% [markdown]
# ## 2.1 The `parsejson()` function
# The `parsejson()` function will "digg into" the `json` file (transformed into a dictionary) until it finds the relevant data. The `json` file consists of a hierarchy of `cdl` nodes; only the lowest nodes contain lemmatization data. The function goes down this hierarchy by calling itself when another `cdl` node is encountered.
#
# The argument of `parsejson()` is a `JSON` object, a dictionary that initially contains the entire text data. The code takes the key `cdl` which contains an array (a list) of `JSON` objects. Iterating through these objects, if an object contains another `cdl` node, the function calls itself with this object as argument. This way the function digs deeper and deeper into the `JSON` tree, until it does not encounter a `cdl` key anymore. Here we are at the level of individual words. The code checks for a key `f`, if it exists it is appended to the list `lemm_l`. This list is defined outside of the function proper. The key `f` is always accompanied by the a key `ref` which gives a word ID of the format `textID.lineID.wordID` (for instance `P282597.2.1`). The seven characters of this `ref` are added to each entry as the field `id_text`.

# %%
def parsejson(text, id_text):
    for JSONobject in text["cdl"]:
        if "cdl" in JSONobject: 
            parsejson(JSONobject, id_text)
        if "f" in JSONobject:
            lemm = JSONobject["f"]
            lemm["id_text"] = id_text
            lemm_l.append(lemm)
    return

# %% [markdown]
# ## 2.2 Call the `parsejson()` function for every `JSON` file
# The code in this cell will read the list of text IDs identified above. Each text ID (e.g.`dcclt/Q000039`) is split into the ID number (`Q000039`) and the project designation (`dcclt`). These elements are used to build the `URL` for the `json` file on the [ORACC](http://oracc.org) server.
#
# The `json` file is downloaded with the `requests` library and transformed into a Python object (a dictionary) with the `json()` function of this same library.
#
# This dictionary, which is called `text` is now sent to the `parsejson()` function. The function adds lemmata to the `lemm_l` list.

# %%
lemm_l = []
for id_text in pqxnos:
    project = id_text[:-8].lower()
    pqx = id_text[-7:].upper()
    url = "http://oracc.org/" + project + '/corpusjson/' + pqx + '.json'
    r = requests.get(url).json()
    try:
        print("parsing " + id_text)
        parsejson(r, id_text)
    except:
        print(id_text + ' is not available or not complete')
# Out:
# parsing blms/P282597
# parsing blms/P274259

# %%
word_df = pd.DataFrame(lemm_l).fillna('')
word_df
# Out:
#               base         cf     cont delim epos             form  \
# 0                                                      {d}utu-gin₇
# 1                                                            e₃-ta
# 2                                                          uru₂-zu
# 3                                                             e-NE
# 4                                                                x
# 5                        kīma                 PRP            ki-ma
# 6                       Šamaš                  DN       {d}ša₂-maš
# 7                        waṣû                   V         ṣa-am-ma
# 8                         ālu                   N           IRI-ka
# 9                       hiāṭu                   V          hi-i-ṭi
# 10                                                              am
# 11                                                         u-mu-un
# 12                                                            x-ga
# 13                                                     {d}utu-gin₇
# 14                                                           e₃-ta
# 15                                                            uru₂
# 16                                                               x
# 17                       rīmu                   N            ri-mu
# 18                       bēlu                   N            be-el
# 19                       nišu                   N            ni-ši
# 20                       kīma                 PRP            ki-ma
# 21                      Šamaš                  DN       {d}ša₂-maš
# 22                       waṣû                   V         ṣa-am-ma
# 23                        ālu                   N           IRI-ka
# 24                      hiāṭu                   V          hi-i-ṭi
# 25                                                     {d}mu-ul-li
# 26                                                         u-mu-un
# 27                                                      kur-kur-re
# 28                                                               x
# 29                      Ellil                  DN           {d}BAD
# ..             ...        ...      ...   ...  ...              ...
# 321             ak         ak                 V/t       na-an-ak-e
# 322                                                              x
# 323             ka        kag                   N            ka-zu
# 324                                                          nam-x
# 325                                                              x
# 326            gur        gur  -ra=r.a        V/t  nu-mu-un-gur-ra
# 327                                                              x
# 328                                                         x-RU-x
# 329                                                           x-ka
# 330                                                        uš-ta-x
# 331           šag₄        šag                   N          šag₄-zu
# 332        bal-bal       bala                 V/t    he₂-bal-bal-e
# 333                                                              x
# 334  niŋ₂-šag₄-hab  niŋšaghab                   N    niŋ₂-šag₄-hab
# 335         e₂-gal       egal                   N       e₂-gal-ke₄
# 336                                                              x
# 337                     nawru                  AJ       na-mir-tu₄
# 338                   hišihtu                   N       hi-ših-tu₄
# 339                    ēkallu                   N      E₂.GAL{+li}
# 340                                                              x
# 341                                                              x
# 342                                                              x
# 343                                                              x
# 344                                                            dub
# 345                                                          nu-zu
# 346                                                             PA
# 347                                                             UD
# 348                                                          {d}EN
# 349                                                              x
# 350                                                              x
#
#                                                    gdl           gw  \
# 0    [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...
# 1    [{'v': 'e₃', 'id': 'P282597.2.2.0', 'break': '...
# 2    [{'v': 'uru₂', 'id': 'P282597.2.3.0', 'break':...
# 3    [{'v': 'e', 'id': 'P282597.2.4.0', 'break': 'd...
# 4    [{'x': 'ellipsis', 'id': 'P282597.2.5.0', 'bre...
# 5    [{'v': 'ki', 'id': 'P282597.3.1.0', 'break': '...         like
# 6    [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...            1
# 7    [{'v': 'ṣa', 'id': 'P282597.3.3.0', 'delim': '...       go out
# 8    [{'s': 'IRI', 'id': 'P282597.3.4.0', 'role': '...         city
# 9    [{'v': 'hi', 'id': 'P282597.3.5.0', 'delim': '...    supervise
# 10   [{'v': 'am', 'id': 'P282597.5.1.0', 'breakStar...
# 11   [{'v': 'u', 'id': 'P282597.5.2.0', 'break': 'm...
# 12   [{'x': 'ellipsis', 'id': 'P282597.5.3.0', 'bre...
# 13   [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...
# 14   [{'v': 'e₃', 'id': 'P282597.5.5.0', 'delim': '...
# 15   [{'v': 'uru₂', 'id': 'P282597.5.6.0', 'break':...
# 16   [{'x': 'ellipsis', 'id': 'P282597.5.7.0', 'bre...
# 17   [{'v': 'ri', 'id': 'P282597.6.1.0', 'break': '...    wild bull
# 18   [{'v': 'be', 'id': 'P282597.6.2.0', 'break': '...         lord
# 19   [{'v': 'ni', 'id': 'P282597.6.3.0', 'delim': '...       people
# 20   [{'v': 'ki', 'id': 'P282597.6.4.0', 'delim': '...         like
# 21   [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...            1
# 22   [{'v': 'ṣa', 'id': 'P282597.6.6.0', 'delim': '...       go out
# 23   [{'s': 'IRI', 'id': 'P282597.6.7.0', 'role': '...         city
# 24   [{'v': 'hi', 'id': 'P282597.6.8.0', 'statusSta...    supervise
# 25   [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...
# 26   [{'v': 'u', 'id': 'P282597.8.2.0', 'delim': '-...
# 27   [{'v': 'kur', 'id': 'P282597.8.3.0', 'delim': ...
# 28   [{'x': 'ellipsis', 'id': 'P282597.8.5.0', 'bre...
# 29   [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...            1
# ..                                                 ...          ...
# 321  [{'v': 'na', 'id': 'P274259.27.4.0', 'delim': ...           do
# 322  [{'x': 'ellipsis', 'id': 'P274259.28.1.0', 'br...
# 323  [{'v': 'ka', 'id': 'P274259.28.2.0', 'delim': ...        mouth
# 324  [{'v': 'nam', 'id': 'P274259.28.3.0', 'delim':...
# 325  [{'x': 'ellipsis', 'id': 'P274259.29.1.0', 'br...
# 326  [{'v': 'nu', 'id': 'P274259.29.2.0', 'break': ...         turn
# 327  [{'x': 'ellipsis', 'id': 'P274259.30.1.0', 'br...
# 328  [{'v': 'x', 'id': 'P274259.30.2.0', 'break': '...
# 329  [{'x': 'ellipsis', 'id': 'P274259.31.1.0', 'br...
# 330  [{'v': 'uš', 'id': 'P274259.31.2.0', 'delim': ...
# 331  [{'v': 'šag₄', 'id': 'P274259.31.3.0', 'break'...        heart
# 332  [{'v': 'he₂', 'id': 'P274259.31.4.0', 'break':...         turn
# 333  [{'x': 'ellipsis', 'id': 'P274259.32.1.0', 'br...
# 334  [{'v': 'niŋ₂', 'id': 'P274259.32.2.0', 'break'...  requirement
# 335  [{'v': 'e₂', 'id': 'P274259.32.3.0', 'delim': ...       palace
# 336  [{'x': 'ellipsis', 'id': 'P274259.32.1195000.0...
# 337  [{'v': 'na', 'id': 'P274259.32.1195001.0', 'de...       bright
# 338  [{'v': 'hi', 'id': 'P274259.32.1195002.0', 'de...  requirement
# 339  [{'gg': 'logo', 'gdl_type': 'logo', 'group': [...       palace
# 340  [{'x': 'ellipsis', 'id': 'P274259.34.1.0', 'br...
# 341  [{'v': 'x', 'id': 'P274259.34.2.0', 'break': '...
# 342  [{'v': 'x', 'id': 'P274259.34.3.0', 'break': '...
# 343  [{'v': 'x', 'id': 'P274259.34.4.0', 'break': '...
# 344  [{'v': 'dub', 'id': 'P274259.34.5.0', 'queried...
# 345  [{'v': 'nu', 'id': 'P274259.34.6.0', 'delim': ...
# 346              [{'s': 'PA', 'id': 'P274259.34.7.0'}]
# 347              [{'s': 'UD', 'id': 'P274259.34.8.0'}]
# 348  [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...
# 349  [{'v': 'x', 'id': 'P274259.34.10.0', 'break': ...
# 350  [{'x': 'ellipsis', 'id': 'P274259.34.11.0', 'b...
#
#           id_text          lang        morph     norm          norm0  pos  \
# 0    blms/P282597           sux
# 1    blms/P282597           sux
# 2    blms/P282597           sux
# 3    blms/P282597           sux
# 4    blms/P282597           sux
# 5    blms/P282597  akk-x-stdbab                  kīma                 PRP
# 6    blms/P282597  akk-x-stdbab                 Šamaš                  DN
# 7    blms/P282597  akk-x-stdbab                 ṣâmma                   V
# 8    blms/P282597  akk-x-stdbab                  ālka                   N
# 9    blms/P282597  akk-x-stdbab                  hīṭi                   V
# 10   blms/P282597           sux
# 11   blms/P282597           sux
# 12   blms/P282597           sux
# 13   blms/P282597           sux
# 14   blms/P282597           sux
# 15   blms/P282597           sux
# 16   blms/P282597           sux
# 17   blms/P282597  akk-x-stdbab                  rīmu                   N
# 18   blms/P282597  akk-x-stdbab                   bēl                   N
# 19   blms/P282597  akk-x-stdbab                  nišī                   N
# 20   blms/P282597  akk-x-stdbab                  kīma                 PRP
# 21   blms/P282597  akk-x-stdbab                 Šamaš                  DN
# 22   blms/P282597  akk-x-stdbab                 ṣâmma                   V
# 23   blms/P282597  akk-x-stdbab                  ālka                   N
# 24   blms/P282597  akk-x-stdbab                  hīṭi                   V
# 25   blms/P282597           sux
# 26   blms/P282597           sux
# 27   blms/P282597           sux
# 28   blms/P282597           sux
# 29   blms/P282597  akk-x-stdbab                 Ellil                  DN
# ..            ...           ...          ...      ...            ...  ...
# 321  blms/P274259           sux     na.n:~;e               na.n:ak;e  V/t
# 322  blms/P274259           sux                                         u
# 323  blms/P274259           sux         ~,zu                  kag,zu    N
# 324  blms/P274259           sux                                         u
# 325  blms/P274259           sux                                         u
# 326  blms/P274259           sux  nu.mu.n:~;a           nu.mu.n:gur;a  V/t
# 327  blms/P274259           sux                                         u
# 328  blms/P274259           sux                                         u
# 329  blms/P274259  akk-x-stdbab                                         u
# 330  blms/P274259  akk-x-stdbab                                         u
# 331  blms/P274259           sux         ~,zu                  šag,zu    N
# 332  blms/P274259           sux     ha.V:~;e             ha.V:bala;e  V/t
# 333  blms/P274259           sux                                         u
# 334  blms/P274259           sux            ~               niŋšaghab    N
# 335  blms/P274259           sux       ~,ak.e               egal,ak.e    N
# 336  blms/P274259  akk-x-stdbab                                         u
# 337  blms/P274259  akk-x-stdbab               namirtu                  AJ
# 338  blms/P274259  akk-x-stdbab               hišihtu                   N
# 339  blms/P274259  akk-x-stdbab                ēkalli                   N
# 340  blms/P274259           sux                                         u
# 341  blms/P274259           sux                                         u
# 342  blms/P274259           sux                                         u
# 343  blms/P274259           sux                                         u
# 344  blms/P274259           sux                                         X
# 345  blms/P274259           sux                                         X
# 346  blms/P274259           sux                                         X
# 347  blms/P274259           sux                                         X
# 348  blms/P274259           sux                                         X
# 349  blms/P274259           sux                                         u
# 350  blms/P274259           sux                                         u
#
#            sense
# 0
# 1
# 2
# 3
# 4
# 5           like
# 6              1
# 7         go out
# 8           city
# 9          check
# 10
# 11
# 12
# 13
# 14
# 15
# 16
# 17     wild bull
# 18          lord
# 19        people
# 20          like
# 21             1
# 22        go out
# 23          city
# 24         check
# 25
# 26
# 27
# 28
# 29             1
# ..           ...
# 321           do
# 322
# 323        mouth
# 324
# 325
# 326         turn
# 327
# 328
# 329
# 330
# 331        heart
# 332         turn
# 333
# 334  requirement
# 335       palace
# 336
# 337       bright
# 338  requirement
# 339       palace
# 340
# 341
# 342
# 343
# 344
# 345
# 346
# 347
# 348
# 349
# 350
#
# [351 rows x 15 columns]

# %% [markdown]
# ## 3.1 Create a `lemma` column
# The following code combines the `cf` (Citation Form), `gw` (Guide Word), and `pos` (Part of Speech) columns to create a new `lemma` column with the format `cf[gw]pos`, for instance `šarru[king]N` or `lugal[king]N`. Unlemmatized words do not have `cf`, `gw`, or `pos` - they only have `form` (the transliteration). The function therefore has a condition: if `cf` is empty, the format should be `form[NA]NA`. Alternatively, one may leave out non-lemmatized words altogether and create the `lemma` column by simply adding up `cf`, `gw`, and `pos`, as follows:
#
# > `word_df = word_df[word_df['cf'] != '']`
#
# > `word_df['lemma'] = word_df['cf'] + '[' + word_df['gw'] + ']' + word_df['pos']`

# %%
word_df["lemma"] = word_df.apply(lambda r: (r["cf"] + '[' + r["gw"] + ']' + r["pos"]) if r["cf"] != '' 
                                 else r['form'] + '[NA]NA', axis=1)
word_df[['id_text', 'lemma']]
# Out:
#           id_text                    lemma
# 0    blms/P282597        {d}utu-gin₇[NA]NA
# 1    blms/P282597              e₃-ta[NA]NA
# 2    blms/P282597            uru₂-zu[NA]NA
# 3    blms/P282597               e-NE[NA]NA
# 4    blms/P282597                  x[NA]NA
# 5    blms/P282597            kīma[like]PRP
# 6    blms/P282597               Šamaš[1]DN
# 7    blms/P282597            waṣû[go out]V
# 8    blms/P282597               ālu[city]N
# 9    blms/P282597        hiāṭu[supervise]V
# 10   blms/P282597                 am[NA]NA
# 11   blms/P282597            u-mu-un[NA]NA
# 12   blms/P282597               x-ga[NA]NA
# 13   blms/P282597        {d}utu-gin₇[NA]NA
# 14   blms/P282597              e₃-ta[NA]NA
# 15   blms/P282597               uru₂[NA]NA
# 16   blms/P282597                  x[NA]NA
# 17   blms/P282597         rīmu[wild bull]N
# 18   blms/P282597              bēlu[lord]N
# 19   blms/P282597            nišu[people]N
# 20   blms/P282597            kīma[like]PRP
# 21   blms/P282597               Šamaš[1]DN
# 22   blms/P282597            waṣû[go out]V
# 23   blms/P282597               ālu[city]N
# 24   blms/P282597        hiāṭu[supervise]V
# 25   blms/P282597        {d}mu-ul-li[NA]NA
# 26   blms/P282597            u-mu-un[NA]NA
# 27   blms/P282597         kur-kur-re[NA]NA
# 28   blms/P282597                  x[NA]NA
# 29   blms/P282597               Ellil[1]DN
# ..            ...                      ...
# 321  blms/P274259                ak[do]V/t
# 322  blms/P274259                  x[NA]NA
# 323  blms/P274259              kag[mouth]N
# 324  blms/P274259              nam-x[NA]NA
# 325  blms/P274259                  x[NA]NA
# 326  blms/P274259             gur[turn]V/t
# 327  blms/P274259                  x[NA]NA
# 328  blms/P274259             x-RU-x[NA]NA
# 329  blms/P274259               x-ka[NA]NA
# 330  blms/P274259            uš-ta-x[NA]NA
# 331  blms/P274259              šag[heart]N
# 332  blms/P274259            bala[turn]V/t
# 333  blms/P274259                  x[NA]NA
# 334  blms/P274259  niŋšaghab[requirement]N
# 335  blms/P274259            egal[palace]N
# 336  blms/P274259                  x[NA]NA
# 337  blms/P274259          nawru[bright]AJ
# 338  blms/P274259    hišihtu[requirement]N
# 339  blms/P274259          ēkallu[palace]N
# 340  blms/P274259                  x[NA]NA
# 341  blms/P274259                  x[NA]NA
# 342  blms/P274259                  x[NA]NA
# 343  blms/P274259                  x[NA]NA
# 344  blms/P274259                dub[NA]NA
# 345  blms/P274259              nu-zu[NA]NA
# 346  blms/P274259                 PA[NA]NA
# 347  blms/P274259                 UD[NA]NA
# 348  blms/P274259              {d}EN[NA]NA
# 349  blms/P274259                  x[NA]NA
# 350  blms/P274259                  x[NA]NA
#
# [351 rows x 2 columns]

# %% [markdown]
# ## 3.2 Remove Spaces and Commas from the Lemma
# Spaces and commas in the Guide Word may cause trouble in computational methods in tokenization, or when saved in Comma Separated Values format. All spaces and commas are replaced by hyphens or nothing, respectively.

# %%
word_df.loc[:,'lemma'] = [x.replace(' ', '-') for x in word_df.loc[:,'lemma']]
word_df.loc[:,'lemma'] = [x.replace(',', '') for x in word_df.loc[:,'lemma']]
word_df
# Out:
#               base         cf     cont delim epos             form  \
# 0                                                      {d}utu-gin₇
# 1                                                            e₃-ta
# 2                                                          uru₂-zu
# 3                                                             e-NE
# 4                                                                x
# 5                        kīma                 PRP            ki-ma
# 6                       Šamaš                  DN       {d}ša₂-maš
# 7                        waṣû                   V         ṣa-am-ma
# 8                         ālu                   N           IRI-ka
# 9                       hiāṭu                   V          hi-i-ṭi
# 10                                                              am
# 11                                                         u-mu-un
# 12                                                            x-ga
# 13                                                     {d}utu-gin₇
# 14                                                           e₃-ta
# 15                                                            uru₂
# 16                                                               x
# 17                       rīmu                   N            ri-mu
# 18                       bēlu                   N            be-el
# 19                       nišu                   N            ni-ši
# 20                       kīma                 PRP            ki-ma
# 21                      Šamaš                  DN       {d}ša₂-maš
# 22                       waṣû                   V         ṣa-am-ma
# 23                        ālu                   N           IRI-ka
# 24                      hiāṭu                   V          hi-i-ṭi
# 25                                                     {d}mu-ul-li
# 26                                                         u-mu-un
# 27                                                      kur-kur-re
# 28                                                               x
# 29                      Ellil                  DN           {d}BAD
# ..             ...        ...      ...   ...  ...              ...
# 321             ak         ak                 V/t       na-an-ak-e
# 322                                                              x
# 323             ka        kag                   N            ka-zu
# 324                                                          nam-x
# 325                                                              x
# 326            gur        gur  -ra=r.a        V/t  nu-mu-un-gur-ra
# 327                                                              x
# 328                                                         x-RU-x
# 329                                                           x-ka
# 330                                                        uš-ta-x
# 331           šag₄        šag                   N          šag₄-zu
# 332        bal-bal       bala                 V/t    he₂-bal-bal-e
# 333                                                              x
# 334  niŋ₂-šag₄-hab  niŋšaghab                   N    niŋ₂-šag₄-hab
# 335         e₂-gal       egal                   N       e₂-gal-ke₄
# 336                                                              x
# 337                     nawru                  AJ       na-mir-tu₄
# 338                   hišihtu                   N       hi-ših-tu₄
# 339                    ēkallu                   N      E₂.GAL{+li}
# 340                                                              x
# 341                                                              x
# 342                                                              x
# 343                                                              x
# 344                                                            dub
# 345                                                          nu-zu
# 346                                                             PA
# 347                                                             UD
# 348                                                          {d}EN
# 349                                                              x
# 350                                                              x
#
#                                                    gdl           gw  \
# 0    [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...
# 1    [{'v': 'e₃', 'id': 'P282597.2.2.0', 'break': '...
# 2    [{'v': 'uru₂', 'id': 'P282597.2.3.0', 'break':...
# 3    [{'v': 'e', 'id': 'P282597.2.4.0', 'break': 'd...
# 4    [{'x': 'ellipsis', 'id': 'P282597.2.5.0', 'bre...
# 5    [{'v': 'ki', 'id': 'P282597.3.1.0', 'break': '...         like
# 6    [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...            1
# 7    [{'v': 'ṣa', 'id': 'P282597.3.3.0', 'delim': '...       go out
# 8    [{'s': 'IRI', 'id': 'P282597.3.4.0', 'role': '...         city
# 9    [{'v': 'hi', 'id': 'P282597.3.5.0', 'delim': '...    supervise
# 10   [{'v': 'am', 'id': 'P282597.5.1.0', 'breakStar...
# 11   [{'v': 'u', 'id': 'P282597.5.2.0', 'break': 'm...
# 12   [{'x': 'ellipsis', 'id': 'P282597.5.3.0', 'bre...
# 13   [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...
# 14   [{'v': 'e₃', 'id': 'P282597.5.5.0', 'delim': '...
# 15   [{'v': 'uru₂', 'id': 'P282597.5.6.0', 'break':...
# 16   [{'x': 'ellipsis', 'id': 'P282597.5.7.0', 'bre...
# 17   [{'v': 'ri', 'id': 'P282597.6.1.0', 'break': '...    wild bull
# 18   [{'v': 'be', 'id': 'P282597.6.2.0', 'break': '...         lord
# 19   [{'v': 'ni', 'id': 'P282597.6.3.0', 'delim': '...       people
# 20   [{'v': 'ki', 'id': 'P282597.6.4.0', 'delim': '...         like
# 21   [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...            1
# 22   [{'v': 'ṣa', 'id': 'P282597.6.6.0', 'delim': '...       go out
# 23   [{'s': 'IRI', 'id': 'P282597.6.7.0', 'role': '...         city
# 24   [{'v': 'hi', 'id': 'P282597.6.8.0', 'statusSta...    supervise
# 25   [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...
# 26   [{'v': 'u', 'id': 'P282597.8.2.0', 'delim': '-...
# 27   [{'v': 'kur', 'id': 'P282597.8.3.0', 'delim': ...
# 28   [{'x': 'ellipsis', 'id': 'P282597.8.5.0', 'bre...
# 29   [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...            1
# ..                                                 ...          ...
# 321  [{'v': 'na', 'id': 'P274259.27.4.0', 'delim': ...           do
# 322  [{'x': 'ellipsis', 'id': 'P274259.28.1.0', 'br...
# 323  [{'v': 'ka', 'id': 'P274259.28.2.0', 'delim': ...        mouth
# 324  [{'v': 'nam', 'id': 'P274259.28.3.0', 'delim':...
# 325  [{'x': 'ellipsis', 'id': 'P274259.29.1.0', 'br...
# 326  [{'v': 'nu', 'id': 'P274259.29.2.0', 'break': ...         turn
# 327  [{'x': 'ellipsis', 'id': 'P274259.30.1.0', 'br...
# 328  [{'v': 'x', 'id': 'P274259.30.2.0', 'break': '...
# 329  [{'x': 'ellipsis', 'id': 'P274259.31.1.0', 'br...
# 330  [{'v': 'uš', 'id': 'P274259.31.2.0', 'delim': ...
# 331  [{'v': 'šag₄', 'id': 'P274259.31.3.0', 'break'...        heart
# 332  [{'v': 'he₂', 'id': 'P274259.31.4.0', 'break':...         turn
# 333  [{'x': 'ellipsis', 'id': 'P274259.32.1.0', 'br...
# 334  [{'v': 'niŋ₂', 'id': 'P274259.32.2.0', 'break'...  requirement
# 335  [{'v': 'e₂', 'id': 'P274259.32.3.0', 'delim': ...       palace
# 336  [{'x': 'ellipsis', 'id': 'P274259.32.1195000.0...
# 337  [{'v': 'na', 'id': 'P274259.32.1195001.0', 'de...       bright
# 338  [{'v': 'hi', 'id': 'P274259.32.1195002.0', 'de...  requirement
# 339  [{'gg': 'logo', 'gdl_type': 'logo', 'group': [...       palace
# 340  [{'x': 'ellipsis', 'id': 'P274259.34.1.0', 'br...
# 341  [{'v': 'x', 'id': 'P274259.34.2.0', 'break': '...
# 342  [{'v': 'x', 'id': 'P274259.34.3.0', 'break': '...
# 343  [{'v': 'x', 'id': 'P274259.34.4.0', 'break': '...
# 344  [{'v': 'dub', 'id': 'P274259.34.5.0', 'queried...
# 345  [{'v': 'nu', 'id': 'P274259.34.6.0', 'delim': ...
# 346              [{'s': 'PA', 'id': 'P274259.34.7.0'}]
# 347              [{'s': 'UD', 'id': 'P274259.34.8.0'}]
# 348  [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...
# 349  [{'v': 'x', 'id': 'P274259.34.10.0', 'break': ...
# 350  [{'x': 'ellipsis', 'id': 'P274259.34.11.0', 'b...
#
#           id_text          lang        morph     norm          norm0  pos  \
# 0    blms/P282597           sux
# 1    blms/P282597           sux
# 2    blms/P282597           sux
# 3    blms/P282597           sux
# 4    blms/P282597           sux
# 5    blms/P282597  akk-x-stdbab                  kīma                 PRP
# 6    blms/P282597  akk-x-stdbab                 Šamaš                  DN
# 7    blms/P282597  akk-x-stdbab                 ṣâmma                   V
# 8    blms/P282597  akk-x-stdbab                  ālka                   N
# 9    blms/P282597  akk-x-stdbab                  hīṭi                   V
# 10   blms/P282597           sux
# 11   blms/P282597           sux
# 12   blms/P282597           sux
# 13   blms/P282597           sux
# 14   blms/P282597           sux
# 15   blms/P282597           sux
# 16   blms/P282597           sux
# 17   blms/P282597  akk-x-stdbab                  rīmu                   N
# 18   blms/P282597  akk-x-stdbab                   bēl                   N
# 19   blms/P282597  akk-x-stdbab                  nišī                   N
# 20   blms/P282597  akk-x-stdbab                  kīma                 PRP
# 21   blms/P282597  akk-x-stdbab                 Šamaš                  DN
# 22   blms/P282597  akk-x-stdbab                 ṣâmma                   V
# 23   blms/P282597  akk-x-stdbab                  ālka                   N
# 24   blms/P282597  akk-x-stdbab                  hīṭi                   V
# 25   blms/P282597           sux
# 26   blms/P282597           sux
# 27   blms/P282597           sux
# 28   blms/P282597           sux
# 29   blms/P282597  akk-x-stdbab                 Ellil                  DN
# ..            ...           ...          ...      ...            ...  ...
# 321  blms/P274259           sux     na.n:~;e               na.n:ak;e  V/t
# 322  blms/P274259           sux                                         u
# 323  blms/P274259           sux         ~,zu                  kag,zu    N
# 324  blms/P274259           sux                                         u
# 325  blms/P274259           sux                                         u
# 326  blms/P274259           sux  nu.mu.n:~;a           nu.mu.n:gur;a  V/t
# 327  blms/P274259           sux                                         u
# 328  blms/P274259           sux                                         u
# 329  blms/P274259  akk-x-stdbab                                         u
# 330  blms/P274259  akk-x-stdbab                                         u
# 331  blms/P274259           sux         ~,zu                  šag,zu    N
# 332  blms/P274259           sux     ha.V:~;e             ha.V:bala;e  V/t
# 333  blms/P274259           sux                                         u
# 334  blms/P274259           sux            ~               niŋšaghab    N
# 335  blms/P274259           sux       ~,ak.e               egal,ak.e    N
# 336  blms/P274259  akk-x-stdbab                                         u
# 337  blms/P274259  akk-x-stdbab               namirtu                  AJ
# 338  blms/P274259  akk-x-stdbab               hišihtu                   N
# 339  blms/P274259  akk-x-stdbab                ēkalli                   N
# 340  blms/P274259           sux                                         u
# 341  blms/P274259           sux                                         u
# 342  blms/P274259           sux                                         u
# 343  blms/P274259           sux                                         u
# 344  blms/P274259           sux                                         X
# 345  blms/P274259           sux                                         X
# 346  blms/P274259           sux                                         X
# 347  blms/P274259           sux                                         X
# 348  blms/P274259           sux                                         X
# 349  blms/P274259           sux                                         u
# 350  blms/P274259           sux                                         u
#
#            sense                    lemma
# 0                       {d}utu-gin₇[NA]NA
# 1                             e₃-ta[NA]NA
# 2                           uru₂-zu[NA]NA
# 3                              e-NE[NA]NA
# 4                                 x[NA]NA
# 5           like            kīma[like]PRP
# 6              1               Šamaš[1]DN
# 7         go out            waṣû[go-out]V
# 8           city               ālu[city]N
# 9          check        hiāṭu[supervise]V
# 10                               am[NA]NA
# 11                          u-mu-un[NA]NA
# 12                             x-ga[NA]NA
# 13                      {d}utu-gin₇[NA]NA
# 14                            e₃-ta[NA]NA
# 15                             uru₂[NA]NA
# 16                                x[NA]NA
# 17     wild bull         rīmu[wild-bull]N
# 18          lord              bēlu[lord]N
# 19        people            nišu[people]N
# 20          like            kīma[like]PRP
# 21             1               Šamaš[1]DN
# 22        go out            waṣû[go-out]V
# 23          city               ālu[city]N
# 24         check        hiāṭu[supervise]V
# 25                      {d}mu-ul-li[NA]NA
# 26                          u-mu-un[NA]NA
# 27                       kur-kur-re[NA]NA
# 28                                x[NA]NA
# 29             1               Ellil[1]DN
# ..           ...                      ...
# 321           do                ak[do]V/t
# 322                               x[NA]NA
# 323        mouth              kag[mouth]N
# 324                           nam-x[NA]NA
# 325                               x[NA]NA
# 326         turn             gur[turn]V/t
# 327                               x[NA]NA
# 328                          x-RU-x[NA]NA
# 329                            x-ka[NA]NA
# 330                         uš-ta-x[NA]NA
# 331        heart              šag[heart]N
# 332         turn            bala[turn]V/t
# 333                               x[NA]NA
# 334  requirement  niŋšaghab[requirement]N
# 335       palace            egal[palace]N
# 336                               x[NA]NA
# 337       bright          nawru[bright]AJ
# 338  requirement    hišihtu[requirement]N
# 339       palace          ēkallu[palace]N
# 340                               x[NA]NA
# 341                               x[NA]NA
# 342                               x[NA]NA
# 343                               x[NA]NA
# 344                             dub[NA]NA
# 345                           nu-zu[NA]NA
# 346                              PA[NA]NA
# 347                              UD[NA]NA
# 348                           {d}EN[NA]NA
# 349                               x[NA]NA
# 350                               x[NA]NA
#
# [351 rows x 16 columns]

# %% [markdown]
# ## 3.3 Group by Textid
# Get all the lemmas that belong to a single text in one row (one row = one document). The `agg()` (aggregate) function, which works on the result of a `groupby()` process aggregates columns of the original dataframe. The function takes a dictionary in which the keys are column names and the values are functions to be used in the aggregation process. The example below has only one such function (`' '.join` will join all entries in the colum `lemma` with a space in between); one may specify (the same or different) functions for different columns, for instance:
# > word_df = word_df.groupby("textid").agg({"lemma": ' '.join, "base": ' '.join})

# %%
word_df = word_df.groupby("id_text").agg({"lemma": ' '.join})
word_df
# Out:
#                                                           lemma
# id_text
# blms/P274259  x-x-šu₂[NA]NA x[NA]NA isqu[share]N x[NA]NA x[N...
# blms/P282597  {d}utu-gin₇[NA]NA e₃-ta[NA]NA uru₂-zu[NA]NA e-...

# %% [markdown]
# ## 4 Save Results in CSV file
# The `.csv` file has the same name as the list of textid's that was used at the beginning of this notebook. In most computers, `csv` files open automatically in Excel. This spread sheet program does not deal well with `utf-8` encoding. If you intend to use the file in Excel, change `encoding ='utf-8'` to `encoding='utf-16'`. For usage in computational text analysis applications `utf-8` is usually preferred.

# %%
savefile =  filename[:-3] + 'csv'
with open('output/' + savefile, 'w') as w:
    word_df.to_csv(w, encoding = 'utf-8')
