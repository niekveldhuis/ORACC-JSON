# %% [markdown]
# # Extract Lemmatization from JSON: Basic Parser
# The code in this notebook will parse [ORACC](http://oracc.org) `JSON` files to extract lemmatization data for one or more projects. The resulting `csv` (Comma Separated Values) file is named `parsed.csv` and has two fields: a Text ID (e.g. `dcclt/Q000039`) and a string of lemmas in the format `lugal[king]N` (or `šarru[king]N` for Akkadian texts).
#
# The output of the Basic Parser contains *only* text IDs and lemmas. This format is useful for so-called [bag of words](https://en.wikipedia.org/wiki/Bag-of-words_model) techniques such as word clouds or [topic modeling](https://en.wikipedia.org/wiki/Topic_model). The `JSON` files, however, contain a wealth of other data, including language (Sumerian, Akkadian, Emesal, etc.), orthographic form, morphology (currently only for Sumerian and Emesal), line numbers, breakage, meta-data, etc. These data are not extracted in the parser demonstrated here, but the example code should provide a model for how any type of data can be extracted.

# %%
import pandas as pd
import zipfile
import json
import tqdm
import requests
import errno
import os

# %% [markdown]
# ## 1.1 Input Project Names
# Provide a list of one or more project names, separated by commas. Note that subprojects must be listed separately, they are not included in the main project. For instance:
#
# `saao/saa01,saao/saa02,blms`

# %%
projects = input('Project(s): ').lower()
# Out:
# Project(s): rimanum,glass

# %% [markdown]
# ## 1.2 Split the List of Projects
# Split the list of projects and create a list of project names.

# %%
p = projects.split(',')               # split at each comma and make a list called `p`
p = [x.strip() for x in p]        # strip spaces left and right of each entry in `p`

# %% [markdown]
# # 1.3 Create Download Directory
# Create a directory called `jsonzip`. If the directory already exists, do nothing.
#
# For the code, see [Stack Overflow](http://stackoverflow.com/questions/18973418/os-mkdirpath-returns-oserror-when-directory-does-not-exist).

# %%
try:
    os.mkdir('jsonzip')
except OSError as exc:
    if exc.errno !=errno.EEXIST:
        raise
    pass

# %% [markdown]
# ## 1.4 Download the ZIP files
# For each project in the list download all the `json` files from `http://build-oracc.museum.upenn.edu/json/`. The file is called `PROJECT.zip` (for instance: `dcclt.zip`). For subprojects the file is called `PROJECT-SUBPROJECT.zip` (for instance `cams-gkab.zip`).
#
# For larger projects (such as [DCCLT](http://oracc.org/dcclt)) the `zip` file may be 25Mb or more. Downloading may take some time and it may be necessary to chunk the downloading process. The `iter_content()` function in the `requests` library takes care of that.
#
# If you have downloaded the files by hand (and put them in the `jsonzip` directory) you may skip this cell and jump directly to section [2.1 The Parsejson() function](head21).

# %%
CHUNK = 16 * 1024
for project in tqdm.tqdm(p):
    project = project.replace('/', '-')
    url = "http://build-oracc.museum.upenn.edu/json/" + project + ".zip"
    file = 'jsonzip/' + project + '.zip'
    r = requests.get(url)
    if r.status_code == 200:
        print("Downloading " + url + " saving as " + file)
        with open(file, 'wb') as f:
            for c in r.iter_content(chunk_size=CHUNK):
                f.write(c)
    else:
        print(url + " does not exist.")
# Out:
#   0%|                                                    | 0/2 [00:00<?, ?it/s]
# Downloading http://build-oracc.museum.upenn.edu/json/rimanum.zip saving as jsonzip/rimanum.zip
#  50%|██████████████████████                      | 1/2 [00:03<00:03,  3.58s/it]
# Downloading http://build-oracc.museum.upenn.edu/json/glass.zip saving as jsonzip/glass.zip
# 100%|████████████████████████████████████████████| 2/2 [00:05<00:00,  3.04s/it]

# %% [markdown]
# ## <a name="head21"></a>2.1 The `parsejson()` function
# The `parsejson()` function will "dig into" the `json` file (transformed into a dictionary) until it finds the relevant data. The `json` file consists of a hierarchy of `cdl` nodes; only the lowest nodes contain lemmatization data. The function goes down this hierarchy by calling itself when another `cdl` node is encountered. For nore information about the data hierarchy in the [ORACC](http://oracc.org) `json` files, see [ORACC Open Data](http://oracc.museum.upenn.edu/doc/opendata/index.html).
#
# The first argument of the `parsejson()` function is a `JSON` object, a dictionary that initially contains the entire contents of the original JSON file. The code takes the key `cdl` which itself contains an array (a list) of `JSON` objects. Iterating through these objects, if an object contains another `cdl` node, the function calls itself with this object as first argument. This way the function digs deeper and deeper into the `JSON` tree, until it does not encounter a `cdl` key anymore. Here we are at the level of individual words. The code checks for a key `f`, if it exists the value of that key is appended to the list `lemm_l`. This list is defined outside of the function proper.
#
# The field `id_text` is derived from the input list. It consists of a project abbreviation, such as `blms` or `cams/gkab` plus a text ID, in the format `cams/gkab/P338616` or `dcclt/Q000039`. The `id_text` is added as a second argument to the function and is added to the lemmatization data of every word.

# %%
def parsejson(text, id_text):
    for JSONobject in text["cdl"]:
        if "cdl" in JSONobject: 
            parsejson(JSONobject, id_text)
        if "f" in JSONobject:
            lemm = JSONobject["f"]
            lemm["id_text"] = id_text
            lemm_l.append(lemm)
    return

# %% [markdown]
# ## 2.2 Call the `parsejson()` function for every `JSON` file
# The code in this cell will iterate through the list of projects entered above (1.1). For each project the `JSON` zip file is located in the directory `jsonzip`, named PROJECT.zip. The `zip` file contains a file that is called `corpus.json` that contains a full list of all the text IDs available in that corpus (P, Q, and X numbers) under the key `members`. This list is used to identify the files that contain the text data and that will be parsed. The `zip` file contains a directory `corpusjson` that holds the text files - each one is called `P######.json` (or `Q######.json` or `X######.json`).
#
# Each of these files is extracted from the `zip` file and read with the command command `json.loads()`, which reads the json data and transforms it into a Python dictionary (a sequence of keys and values).
#
# This dictionary, which is called `text` is now sent to the `parsejson()` function, with the text ID as second argument. The function adds lemmata to the `lemm_l` list.

# %%
lemm_l = []
for project in p:
    file = "jsonzip/" + project.replace("/", "-") + ".zip"
    try:
        z = zipfile.ZipFile(file)                                                      # create a Zipfile object
    except:
        print(file + " does not exist or is not a proper ZIP file")
        continue
    corpus = z.read(project + "/corpus.json").decode("utf-8") # read and decode the file corpus.json
    cat = json.loads(corpus)["members"]                                  # select the key "members" 
                                                                                                 #that holds all the P, Q, and X numbers.
    for item in cat:                                                                     #iterate over the P, Q, and X numbers
        id_text = project + '/' + item
        try:
            file = project + "/corpusjson/" + item + '.json'
            text = z.read(file).decode('utf-8')                                 #read and decode the json file of one particular text
            data_json = json.loads(text)                                        # make it into a dictionary
            parsejson(data_json, id_text)                                       # and send to the parsejson() function
        except:
            print(id_text + ' is not available or not complete')

# %%
word_df = pd.DataFrame(lemm_l).fillna('')
word_df
# Out:
#            base            cf     cont delim epos                     form  \
# 0                                                                 2(BARIG)
# 1                        qēmu                   N                      ZI₃
# 2                         US₂                  AJ                      US₂
# 3                         ana                 PRP                     a-na
# 4                     tākultu                   N                   GEŠBUN
# 5                       awīlu                   N                      LU₂
# 6                      Kisura                  SN            KI.SUR.RA{ki}
# 7                       awīlu                   N                      LU₂
# 8                        Gutû                  GN                 gu-ti-um
# 9                           u                 CNJ                       u₃
# 10                      ahītu                   N               a-hi-a-tim
# 11                       ṣītu                   N                    ZI.GA
# 12                      libbu                   N                      ŠA₃
# 13                       bītu                   N                       E₂
# 14                      asīru                   N                  a-si-ri
# 15                         ša                                      NIG₂.ŠU
# 16                        qāt                                      NIG₂.ŠU
# 17                   Sîn-šeme                  PN           {d}EN.ZU-še-mi
# 18                      Elūlu                  MN       {iti}KIN.{d}INANNA
# 19                        ūmu                   N                       U₄
# 20                                                                  21-KAM
# 21           mu            mu                   N                       mu
# 22     ri-im-an      Rīm-Anum                  RN                 ri-im-an
# 23        lugal         lugal                   N                    lugal
# 24     unug{ki}          Uruk  -ga=g.a         SN              unug{ki}-ga
# 25           u₃             u                 CNJ                       u₃
# 26       a₂-dam          adam                   N                a₂-dam-bi
# 27                   Aha-arši                  PN         {m}a-ha-am-ar-ši
# 28               Marduk-nāṣir                  PN  {m}{d}AMAR.UTU-na-ṣi-ir
# 29                                                                       x
# ...         ...           ...      ...   ...  ...                      ...
# 16197                                                                    x
# 16198                                                             su-u₂-ni
# 16199                                                                    x
# 16200                    annû                  DP                 an-ne₂-e
# 16201                                                                   $A
# 16202                                                                    x
# 16203                  nakāru                   V                tu-na-kar
# 16204                                                                    x
# 16205                   nahlu                  AJ              na-ah-lu-te
# 16206                                                                    x
# 16207                  madādu                   V              ta-ma-da-ad
# 16208                                                                    x
# 16209                    ištu                 PRP                    iš-tu
# 16210                  ahāʾiš                   N                  a-ha-iš
# 16211                                                                    x
# 16212                      mû                   N                    A-MEŠ
# 16213                      kī                 PRP                     ki-i
# 16214                                                              ša-kin₂
# 16215                                                                    x
# 16216                     ina                 PRP                     i+na
# 16217                  mubêšu                   N                 mu-be-še
# 16218                  beʾēšu                   V                tu-be-aš₂
# 16219                                                                    x
# 16220                                                             a-tar-bu
# 16221                      kī                 PRP                     ki-i
# 16222                                                                    x
# 16223                                                                    x
# 16224                   išātu                   N                      IZI
# 16225                    ištu                 PRP                    iš-tu
# 16226                                                              ša-an-x
#
#                                                      gdl  \
# 0      [{'n': 'n', 'form': '2(BARIG)', 'id': 'P405287...
# 1      [{'s': 'ZI₃', 'id': 'P405287.3.2.0', 'logolang...
# 2      [{'ho': '1', 's': 'US₂', 'logolang': 'sux', 'r...
# 3      [{'ho': '1', 'break': 'damaged', 'v': 'a', 'id...
# 4      [{'s': 'GEŠBUN', 'logolang': 'sux', 'role': 'l...
# 5      [{'s': 'LU₂', 'id': 'P405287.5.1.0', 'logolang...
# 6      [{'gdl_type': 'logo', 'group': [{'delim': '.',...
# 7      [{'s': 'LU₂', 'id': 'P405287.6.1.0', 'logolang...
# 8      [{'delim': '-', 'v': 'gu', 'id': 'P405287.6.2....
# 9      [{'ho': '1', 'break': 'damaged', 'v': 'u₃', 'i...
# 10     [{'break': 'damaged', 'v': 'a', 'id': 'P405287...
# 11     [{'gdl_type': 'logo', 'group': [{'delim': '.',...
# 12     [{'s': 'ŠA₃', 'id': 'P405287.9.2.0', 'logolang...
# 13     [{'ho': '1', 's': 'E₂', 'logolang': 'sux', 'ro...
# 14     [{'break': 'damaged', 'v': 'a', 'id': 'P405287...
# 15     [{'gdl_type': 'logo', 'group': [{'ho': '1', 's...
# 16     [{'gdl_type': 'logo', 'group': [{'ho': '1', 's...
# 17     [{'pos': 'pre', 'seq': [{'v': 'd', 'id': 'P405...
# 18     [{'pos': 'pre', 'seq': [{'v': 'iti', 'id': 'P4...
# 19     [{'s': 'U₄', 'id': 'P405287.11.2.0', 'logolang...
# 20     [{'n': 'n', 'form': '21', 'delim': '-', 'seq':...
# 21                 [{'v': 'mu', 'id': 'P405287.12.1.0'}]
# 22     [{'delim': '-', 'v': 'ri', 'id': 'P405287.12.2...
# 23              [{'v': 'lugal', 'id': 'P405287.12.3.0'}]
# 24     [{'v': 'unug', 'id': 'P405287.13.1.0'}, {'pos'...
# 25                 [{'v': 'u₃', 'id': 'P405287.14.1.0'}]
# 26     [{'delim': '-', 'v': 'a₂', 'id': 'P405287.14.2...
# 27     [{'pos': 'pre', 'seq': [{'v': 'm', 'id': 'P296...
# 28     [{'pos': 'pre', 'seq': [{'v': 'm', 'id': 'P296...
# 29     [{'ho': '1', 'break': 'damaged', 'v': 'x', 'id...
# ...                                                  ...
# 16197               [{'v': 'x', 'id': 'P282617.93.2.0'}]
# 16198  [{'delim': '-', 'v': 'su', 'id': 'P282617.93.3...
# 16199  [{'o': ']', 'id': 'P282617.93.4.0', 'x': 'elli...
# 16200  [{'delim': '-', 'v': 'an', 'id': 'P282617.94.1...
# 16201  [{'s': 'A', 'id': 'P282617.94.2.0', 'role': 's...
# 16202  [{'o': ']', 'breakStart': '1', 'break': 'missi...
# 16203  [{'delim': '-', 'v': 'tu', 'id': 'P282617.95.1...
# 16204  [{'o': ']', 'breakStart': '1', 'break': 'missi...
# 16205  [{'delim': '-', 'v': 'na', 'id': 'P282617.96.1...
# 16206  [{'o': ']', 'breakStart': '1', 'break': 'missi...
# 16207  [{'delim': '-', 'v': 'ta', 'id': 'P282617.97.1...
# 16208  [{'o': ']', 'breakStart': '1', 'break': 'missi...
# 16209  [{'delim': '-', 'v': 'iš', 'id': 'P282617.98.1...
# 16210  [{'delim': '-', 'v': 'a', 'id': 'P282617.98.2....
# 16211  [{'o': ']', 'breakStart': '1', 'break': 'missi...
# 16212  [{'gdl_type': 'logo', 'group': [{'delim': '-',...
# 16213  [{'delim': '-', 'v': 'ki', 'id': 'P282617.99.2...
# 16214  [{'delim': '-', 'v': 'ša', 'id': 'P282617.99.3...
# 16215  [{'o': ']', 'breakStart': '1', 'break': 'missi...
# 16216  [{'gdl_type': 'ligature', 'group': [{'delim': ...
# 16217  [{'delim': '-', 'v': 'mu', 'id': 'P282617.100....
# 16218  [{'delim': '-', 'v': 'tu', 'id': 'P282617.100....
# 16219  [{'o': ']', 'id': 'P282617.100.4.0', 'x': 'ell...
# 16220  [{'delim': '-', 'v': 'a', 'id': 'P282617.101.1...
# 16221  [{'delim': '-', 'v': 'ki', 'id': 'P282617.101....
# 16222              [{'v': 'x', 'id': 'P282617.101.3.0'}]
# 16223  [{'o': ']', 'breakStart': '1', 'break': 'missi...
# 16224  [{'gdl_type': 'logo', 'group': [{'s': 'IZI', '...
# 16225  [{'delim': '-', 'v': 'iš', 'id': 'P282617.102....
# 16226  [{'delim': '-', 'v': 'ša', 'id': 'P282617.102....
#
#                            gw          id_text          lang morph  \
# 0                              rimanum/P405287  akk-x-oldbab
# 1                       flour  rimanum/P405287  akk-x-oldbab
# 2              lesser quality  rimanum/P405287  akk-x-oldbab
# 3                          to  rimanum/P405287  akk-x-oldbab
# 4               (cultic) meal  rimanum/P405287  akk-x-oldbab
# 5                         man  rimanum/P405287  akk-x-oldbab
# 6                           1  rimanum/P405287  akk-x-oldbab
# 7                         man  rimanum/P405287  akk-x-oldbab
# 8                           1  rimanum/P405287  akk-x-oldbab
# 9                         and  rimanum/P405287  akk-x-oldbab
# 10                    outside  rimanum/P405287  akk-x-oldbab
# 11                       exit  rimanum/P405287  akk-x-oldbab
# 12                 inner body  rimanum/P405287  akk-x-oldbab
# 13                      house  rimanum/P405287  akk-x-oldbab
# 14                    captive  rimanum/P405287  akk-x-oldbab
# 15                         of  rimanum/P405287  akk-x-oldbab
# 16                  authority  rimanum/P405287  akk-x-oldbab
# 17                         00  rimanum/P405287  akk-x-oldbab
# 18                          1  rimanum/P405287  akk-x-oldbab
# 19                        day  rimanum/P405287  akk-x-oldbab
# 20                             rimanum/P405287  akk-x-oldbab
# 21                       year  rimanum/P405287           sux     ~
# 22                          1  rimanum/P405287           sux     ~
# 23                       king  rimanum/P405287           sux     ~
# 24                          1  rimanum/P405287           sux  ~,ak
# 25                        and  rimanum/P405287           sux     ~
# 26                 habitation  rimanum/P405287           sux  ~,bi
# 27                         00  rimanum/P296277  akk-x-oldbab
# 28                         00  rimanum/P296277  akk-x-oldbab
# 29                             rimanum/P296277  akk-x-oldbab
# ...                       ...              ...           ...   ...
# 16197                            glass/P282617  akk-x-midass
# 16198                            glass/P282617  akk-x-midass
# 16199                            glass/P282617  akk-x-midass
# 16200                    this    glass/P282617  akk-x-midass
# 16201                            glass/P282617  akk-x-midass
# 16202                            glass/P282617  akk-x-midass
# 16203                  change    glass/P282617  akk-x-midass
# 16204                            glass/P282617  akk-x-midass
# 16205                  sieved    glass/P282617  akk-x-midass
# 16206                            glass/P282617  akk-x-midass
# 16207                 measure    glass/P282617  akk-x-midass
# 16208                            glass/P282617  akk-x-midass
# 16209                    from    glass/P282617  akk-x-midass
# 16210              each other    glass/P282617  akk-x-midass
# 16211                            glass/P282617  akk-x-midass
# 16212                   water    glass/P282617  akk-x-midass
# 16213                    like    glass/P282617  akk-x-midass
# 16214                            glass/P282617  akk-x-midass
# 16215                            glass/P282617  akk-x-midass
# 16216                      in    glass/P282617  akk-x-midass
# 16217  implement for stirring    glass/P282617  akk-x-midass
# 16218                    stir    glass/P282617  akk-x-midass
# 16219                            glass/P282617  akk-x-midass
# 16220                            glass/P282617  akk-x-midass
# 16221                    like    glass/P282617  akk-x-midass
# 16222                            glass/P282617  akk-x-midass
# 16223                            glass/P282617  akk-x-midass
# 16224                    fire    glass/P282617  akk-x-midass
# 16225                    from    glass/P282617  akk-x-midass
# 16226                            glass/P282617  akk-x-midass
#
#                norm     norm0  pos                   sense
# 0                                n
# 1              qēmu              N                   flour
# 2               US₂             AJ          lesser quality
# 3               ana            PRP                     for
# 4           tākulti              N              allocation
# 5              awīl              N                     man
# 6            Kisura             SN                       1
# 7              awīl              N                     man
# 8             Gutûm             GN                       1
# 9                 u            CNJ                     and
# 10          ahiātim              N                   other
# 11             ṣītu              N             expenditure
# 12            libbu              N                  inside
# 13              bīt              N                   house
# 14            asīrī              N         prisoner of war
# 15                             DET
# 16                               N
# 17         Sîn-šeme             PN                      00
# 18            Elūlu             MN                       1
# 19              ūmu              N                     day
# 20                               n
# 21                         mu    N                    year
# 22                   Rīm-Anum   RN                       1
# 23                      lugal    N                    king
# 24                    Uruk,ak   SN                       1
# 25                          u  CNJ                     and
# 26                    adam,bi    N              habitation
# 27        Aham-arši             PN                      00
# 28     Marduk-nāṣir             PN                      00
# 29                               u
# ...             ...       ...  ...                     ...
# 16197                            u
# 16198                            X
# 16199                            u
# 16200          annê             DP                    this
# 16201                            u
# 16202                            u
# 16203      tunakkar              V                  remove
# 16204                            u
# 16205       nahlūte             AJ                strained
# 16206                            u
# 16207      tamaddad              V                 measure
# 16208                            u
# 16209          ištu            PRP                    from
# 16210        ahāʾiš              N              each other
# 16211                            u
# 16212            mê              N                   water
# 16213            kī            PRP                    like
# 16214                            X
# 16215                            u
# 16216           ina            PRP                      in
# 16217        mubêše              N  implement for stirring
# 16218      tubeʾʾaš              V                    stir
# 16219                            u
# 16220                            X
# 16221            kī            PRP                    like
# 16222                            u
# 16223                            u
# 16224         išāti              N                    fire
# 16225          ištu            PRP                    from
# 16226                            u
#
# [16227 rows x 15 columns]

# %% [markdown]
# ## 3.1 Create a `lemma` column
# The following code combines the `cf` (Citation Form), `gw` (Guide Word), and `pos` (Part of Speech) columns to create a new `lemma` column with the format `cf[gw]pos`, for instance `šarru[king]N` or `lugal[king]N`. Unlemmatized words do not have `cf`, `gw`, or `pos` - they only have `form` (the transliteration). The function therefore has a condition: if `cf` is empty, the format should be `form[NA]NA`. Alternatively, one may leave out non-lemmatized words altogether and create the `lemma` column by simply adding up `cf`, `gw`, and `pos`, as follows:
# ```python
# word_df = word_df[word_df['cf'] != '']   # throw out rows with empty CF
# word_df['lemma'] = word_df['cf'] + '[' + word_df['gw'] + ']' + word_df['pos']
# ```

# %%
word_df["lemma"] = word_df.apply(lambda r: (r["cf"] + '[' + r["gw"] + ']' + r["pos"]) if r["cf"] != '' 
                                 else r['form'] + '[NA]NA', axis=1)
word_df[['id_text', 'lemma']]
# Out:
#                id_text                            lemma
# 0      rimanum/P405287                   2(BARIG)[NA]NA
# 1      rimanum/P405287                     qēmu[flour]N
# 2      rimanum/P405287            US₂[lesser quality]AJ
# 3      rimanum/P405287                       ana[to]PRP
# 4      rimanum/P405287          tākultu[(cultic) meal]N
# 5      rimanum/P405287                      awīlu[man]N
# 6      rimanum/P405287                      Kisura[1]SN
# 7      rimanum/P405287                      awīlu[man]N
# 8      rimanum/P405287                        Gutû[1]GN
# 9      rimanum/P405287                        u[and]CNJ
# 10     rimanum/P405287                  ahītu[outside]N
# 11     rimanum/P405287                      ṣītu[exit]N
# 12     rimanum/P405287               libbu[inner body]N
# 13     rimanum/P405287                     bītu[house]N
# 14     rimanum/P405287                  asīru[captive]N
# 15     rimanum/P405287                        ša[of]DET
# 16     rimanum/P405287                  qāt[authority]N
# 17     rimanum/P405287                   Sîn-šeme[00]PN
# 18     rimanum/P405287                       Elūlu[1]MN
# 19     rimanum/P405287                        ūmu[day]N
# 20     rimanum/P405287                     21-KAM[NA]NA
# 21     rimanum/P405287                        mu[year]N
# 22     rimanum/P405287                    Rīm-Anum[1]RN
# 23     rimanum/P405287                     lugal[king]N
# 24     rimanum/P405287                        Uruk[1]SN
# 25     rimanum/P405287                        u[and]CNJ
# 26     rimanum/P405287                adam[habitation]N
# 27     rimanum/P296277                   Aha-arši[00]PN
# 28     rimanum/P296277               Marduk-nāṣir[00]PN
# 29     rimanum/P296277                          x[NA]NA
# ...                ...                              ...
# 16197    glass/P282617                          x[NA]NA
# 16198    glass/P282617                   su-u₂-ni[NA]NA
# 16199    glass/P282617                          x[NA]NA
# 16200    glass/P282617                     annû[this]DP
# 16201    glass/P282617                         $A[NA]NA
# 16202    glass/P282617                          x[NA]NA
# 16203    glass/P282617                  nakāru[change]V
# 16204    glass/P282617                          x[NA]NA
# 16205    glass/P282617                  nahlu[sieved]AJ
# 16206    glass/P282617                          x[NA]NA
# 16207    glass/P282617                 madādu[measure]V
# 16208    glass/P282617                          x[NA]NA
# 16209    glass/P282617                    ištu[from]PRP
# 16210    glass/P282617              ahāʾiš[each other]N
# 16211    glass/P282617                          x[NA]NA
# 16212    glass/P282617                       mû[water]N
# 16213    glass/P282617                      kī[like]PRP
# 16214    glass/P282617                    ša-kin₂[NA]NA
# 16215    glass/P282617                          x[NA]NA
# 16216    glass/P282617                       ina[in]PRP
# 16217    glass/P282617  mubêšu[implement for stirring]N
# 16218    glass/P282617                    beʾēšu[stir]V
# 16219    glass/P282617                          x[NA]NA
# 16220    glass/P282617                   a-tar-bu[NA]NA
# 16221    glass/P282617                      kī[like]PRP
# 16222    glass/P282617                          x[NA]NA
# 16223    glass/P282617                          x[NA]NA
# 16224    glass/P282617                     išātu[fire]N
# 16225    glass/P282617                    ištu[from]PRP
# 16226    glass/P282617                    ša-an-x[NA]NA
#
# [16227 rows x 2 columns]

# %% [markdown]
# ## 3.2 Remove Spaces and Commas from the Lemma
# Spaces and commas in the Guide Word may cause trouble in computational methods in tokenization, or when saved in Comma Separated Values format. All spaces and commas are replaced by hyphens or nothing, respectively.

# %%
word_df.loc[:,'lemma'] = [x.replace(' ', '-') for x in word_df.loc[:,'lemma']]
word_df.loc[:,'lemma'] = [x.replace(',', '') for x in word_df.loc[:,'lemma']]
word_df
# Out:
#            base            cf     cont delim epos                     form  \
# 0                                                                 2(BARIG)
# 1                        qēmu                   N                      ZI₃
# 2                         US₂                  AJ                      US₂
# 3                         ana                 PRP                     a-na
# 4                     tākultu                   N                   GEŠBUN
# 5                       awīlu                   N                      LU₂
# 6                      Kisura                  SN            KI.SUR.RA{ki}
# 7                       awīlu                   N                      LU₂
# 8                        Gutû                  GN                 gu-ti-um
# 9                           u                 CNJ                       u₃
# 10                      ahītu                   N               a-hi-a-tim
# 11                       ṣītu                   N                    ZI.GA
# 12                      libbu                   N                      ŠA₃
# 13                       bītu                   N                       E₂
# 14                      asīru                   N                  a-si-ri
# 15                         ša                                      NIG₂.ŠU
# 16                        qāt                                      NIG₂.ŠU
# 17                   Sîn-šeme                  PN           {d}EN.ZU-še-mi
# 18                      Elūlu                  MN       {iti}KIN.{d}INANNA
# 19                        ūmu                   N                       U₄
# 20                                                                  21-KAM
# 21           mu            mu                   N                       mu
# 22     ri-im-an      Rīm-Anum                  RN                 ri-im-an
# 23        lugal         lugal                   N                    lugal
# 24     unug{ki}          Uruk  -ga=g.a         SN              unug{ki}-ga
# 25           u₃             u                 CNJ                       u₃
# 26       a₂-dam          adam                   N                a₂-dam-bi
# 27                   Aha-arši                  PN         {m}a-ha-am-ar-ši
# 28               Marduk-nāṣir                  PN  {m}{d}AMAR.UTU-na-ṣi-ir
# 29                                                                       x
# ...         ...           ...      ...   ...  ...                      ...
# 16197                                                                    x
# 16198                                                             su-u₂-ni
# 16199                                                                    x
# 16200                    annû                  DP                 an-ne₂-e
# 16201                                                                   $A
# 16202                                                                    x
# 16203                  nakāru                   V                tu-na-kar
# 16204                                                                    x
# 16205                   nahlu                  AJ              na-ah-lu-te
# 16206                                                                    x
# 16207                  madādu                   V              ta-ma-da-ad
# 16208                                                                    x
# 16209                    ištu                 PRP                    iš-tu
# 16210                  ahāʾiš                   N                  a-ha-iš
# 16211                                                                    x
# 16212                      mû                   N                    A-MEŠ
# 16213                      kī                 PRP                     ki-i
# 16214                                                              ša-kin₂
# 16215                                                                    x
# 16216                     ina                 PRP                     i+na
# 16217                  mubêšu                   N                 mu-be-še
# 16218                  beʾēšu                   V                tu-be-aš₂
# 16219                                                                    x
# 16220                                                             a-tar-bu
# 16221                      kī                 PRP                     ki-i
# 16222                                                                    x
# 16223                                                                    x
# 16224                   išātu                   N                      IZI
# 16225                    ištu                 PRP                    iš-tu
# 16226                                                              ša-an-x
#
#                                                      gdl  \
# 0      [{'n': 'n', 'form': '2(BARIG)', 'id': 'P405287...
# 1      [{'s': 'ZI₃', 'id': 'P405287.3.2.0', 'logolang...
# 2      [{'ho': '1', 's': 'US₂', 'logolang': 'sux', 'r...
# 3      [{'ho': '1', 'break': 'damaged', 'v': 'a', 'id...
# 4      [{'s': 'GEŠBUN', 'logolang': 'sux', 'role': 'l...
# 5      [{'s': 'LU₂', 'id': 'P405287.5.1.0', 'logolang...
# 6      [{'gdl_type': 'logo', 'group': [{'delim': '.',...
# 7      [{'s': 'LU₂', 'id': 'P405287.6.1.0', 'logolang...
# 8      [{'delim': '-', 'v': 'gu', 'id': 'P405287.6.2....
# 9      [{'ho': '1', 'break': 'damaged', 'v': 'u₃', 'i...
# 10     [{'break': 'damaged', 'v': 'a', 'id': 'P405287...
# 11     [{'gdl_type': 'logo', 'group': [{'delim': '.',...
# 12     [{'s': 'ŠA₃', 'id': 'P405287.9.2.0', 'logolang...
# 13     [{'ho': '1', 's': 'E₂', 'logolang': 'sux', 'ro...
# 14     [{'break': 'damaged', 'v': 'a', 'id': 'P405287...
# 15     [{'gdl_type': 'logo', 'group': [{'ho': '1', 's...
# 16     [{'gdl_type': 'logo', 'group': [{'ho': '1', 's...
# 17     [{'pos': 'pre', 'seq': [{'v': 'd', 'id': 'P405...
# 18     [{'pos': 'pre', 'seq': [{'v': 'iti', 'id': 'P4...
# 19     [{'s': 'U₄', 'id': 'P405287.11.2.0', 'logolang...
# 20     [{'n': 'n', 'form': '21', 'delim': '-', 'seq':...
# 21                 [{'v': 'mu', 'id': 'P405287.12.1.0'}]
# 22     [{'delim': '-', 'v': 'ri', 'id': 'P405287.12.2...
# 23              [{'v': 'lugal', 'id': 'P405287.12.3.0'}]
# 24     [{'v': 'unug', 'id': 'P405287.13.1.0'}, {'pos'...
# 25                 [{'v': 'u₃', 'id': 'P405287.14.1.0'}]
# 26     [{'delim': '-', 'v': 'a₂', 'id': 'P405287.14.2...
# 27     [{'pos': 'pre', 'seq': [{'v': 'm', 'id': 'P296...
# 28     [{'pos': 'pre', 'seq': [{'v': 'm', 'id': 'P296...
# 29     [{'ho': '1', 'break': 'damaged', 'v': 'x', 'id...
# ...                                                  ...
# 16197               [{'v': 'x', 'id': 'P282617.93.2.0'}]
# 16198  [{'delim': '-', 'v': 'su', 'id': 'P282617.93.3...
# 16199  [{'o': ']', 'id': 'P282617.93.4.0', 'x': 'elli...
# 16200  [{'delim': '-', 'v': 'an', 'id': 'P282617.94.1...
# 16201  [{'s': 'A', 'id': 'P282617.94.2.0', 'role': 's...
# 16202  [{'o': ']', 'breakStart': '1', 'break': 'missi...
# 16203  [{'delim': '-', 'v': 'tu', 'id': 'P282617.95.1...
# 16204  [{'o': ']', 'breakStart': '1', 'break': 'missi...
# 16205  [{'delim': '-', 'v': 'na', 'id': 'P282617.96.1...
# 16206  [{'o': ']', 'breakStart': '1', 'break': 'missi...
# 16207  [{'delim': '-', 'v': 'ta', 'id': 'P282617.97.1...
# 16208  [{'o': ']', 'breakStart': '1', 'break': 'missi...
# 16209  [{'delim': '-', 'v': 'iš', 'id': 'P282617.98.1...
# 16210  [{'delim': '-', 'v': 'a', 'id': 'P282617.98.2....
# 16211  [{'o': ']', 'breakStart': '1', 'break': 'missi...
# 16212  [{'gdl_type': 'logo', 'group': [{'delim': '-',...
# 16213  [{'delim': '-', 'v': 'ki', 'id': 'P282617.99.2...
# 16214  [{'delim': '-', 'v': 'ša', 'id': 'P282617.99.3...
# 16215  [{'o': ']', 'breakStart': '1', 'break': 'missi...
# 16216  [{'gdl_type': 'ligature', 'group': [{'delim': ...
# 16217  [{'delim': '-', 'v': 'mu', 'id': 'P282617.100....
# 16218  [{'delim': '-', 'v': 'tu', 'id': 'P282617.100....
# 16219  [{'o': ']', 'id': 'P282617.100.4.0', 'x': 'ell...
# 16220  [{'delim': '-', 'v': 'a', 'id': 'P282617.101.1...
# 16221  [{'delim': '-', 'v': 'ki', 'id': 'P282617.101....
# 16222              [{'v': 'x', 'id': 'P282617.101.3.0'}]
# 16223  [{'o': ']', 'breakStart': '1', 'break': 'missi...
# 16224  [{'gdl_type': 'logo', 'group': [{'s': 'IZI', '...
# 16225  [{'delim': '-', 'v': 'iš', 'id': 'P282617.102....
# 16226  [{'delim': '-', 'v': 'ša', 'id': 'P282617.102....
#
#                            gw          id_text          lang morph  \
# 0                              rimanum/P405287  akk-x-oldbab
# 1                       flour  rimanum/P405287  akk-x-oldbab
# 2              lesser quality  rimanum/P405287  akk-x-oldbab
# 3                          to  rimanum/P405287  akk-x-oldbab
# 4               (cultic) meal  rimanum/P405287  akk-x-oldbab
# 5                         man  rimanum/P405287  akk-x-oldbab
# 6                           1  rimanum/P405287  akk-x-oldbab
# 7                         man  rimanum/P405287  akk-x-oldbab
# 8                           1  rimanum/P405287  akk-x-oldbab
# 9                         and  rimanum/P405287  akk-x-oldbab
# 10                    outside  rimanum/P405287  akk-x-oldbab
# 11                       exit  rimanum/P405287  akk-x-oldbab
# 12                 inner body  rimanum/P405287  akk-x-oldbab
# 13                      house  rimanum/P405287  akk-x-oldbab
# 14                    captive  rimanum/P405287  akk-x-oldbab
# 15                         of  rimanum/P405287  akk-x-oldbab
# 16                  authority  rimanum/P405287  akk-x-oldbab
# 17                         00  rimanum/P405287  akk-x-oldbab
# 18                          1  rimanum/P405287  akk-x-oldbab
# 19                        day  rimanum/P405287  akk-x-oldbab
# 20                             rimanum/P405287  akk-x-oldbab
# 21                       year  rimanum/P405287           sux     ~
# 22                          1  rimanum/P405287           sux     ~
# 23                       king  rimanum/P405287           sux     ~
# 24                          1  rimanum/P405287           sux  ~,ak
# 25                        and  rimanum/P405287           sux     ~
# 26                 habitation  rimanum/P405287           sux  ~,bi
# 27                         00  rimanum/P296277  akk-x-oldbab
# 28                         00  rimanum/P296277  akk-x-oldbab
# 29                             rimanum/P296277  akk-x-oldbab
# ...                       ...              ...           ...   ...
# 16197                            glass/P282617  akk-x-midass
# 16198                            glass/P282617  akk-x-midass
# 16199                            glass/P282617  akk-x-midass
# 16200                    this    glass/P282617  akk-x-midass
# 16201                            glass/P282617  akk-x-midass
# 16202                            glass/P282617  akk-x-midass
# 16203                  change    glass/P282617  akk-x-midass
# 16204                            glass/P282617  akk-x-midass
# 16205                  sieved    glass/P282617  akk-x-midass
# 16206                            glass/P282617  akk-x-midass
# 16207                 measure    glass/P282617  akk-x-midass
# 16208                            glass/P282617  akk-x-midass
# 16209                    from    glass/P282617  akk-x-midass
# 16210              each other    glass/P282617  akk-x-midass
# 16211                            glass/P282617  akk-x-midass
# 16212                   water    glass/P282617  akk-x-midass
# 16213                    like    glass/P282617  akk-x-midass
# 16214                            glass/P282617  akk-x-midass
# 16215                            glass/P282617  akk-x-midass
# 16216                      in    glass/P282617  akk-x-midass
# 16217  implement for stirring    glass/P282617  akk-x-midass
# 16218                    stir    glass/P282617  akk-x-midass
# 16219                            glass/P282617  akk-x-midass
# 16220                            glass/P282617  akk-x-midass
# 16221                    like    glass/P282617  akk-x-midass
# 16222                            glass/P282617  akk-x-midass
# 16223                            glass/P282617  akk-x-midass
# 16224                    fire    glass/P282617  akk-x-midass
# 16225                    from    glass/P282617  akk-x-midass
# 16226                            glass/P282617  akk-x-midass
#
#                norm     norm0  pos                   sense  \
# 0                                n
# 1              qēmu              N                   flour
# 2               US₂             AJ          lesser quality
# 3               ana            PRP                     for
# 4           tākulti              N              allocation
# 5              awīl              N                     man
# 6            Kisura             SN                       1
# 7              awīl              N                     man
# 8             Gutûm             GN                       1
# 9                 u            CNJ                     and
# 10          ahiātim              N                   other
# 11             ṣītu              N             expenditure
# 12            libbu              N                  inside
# 13              bīt              N                   house
# 14            asīrī              N         prisoner of war
# 15                             DET
# 16                               N
# 17         Sîn-šeme             PN                      00
# 18            Elūlu             MN                       1
# 19              ūmu              N                     day
# 20                               n
# 21                         mu    N                    year
# 22                   Rīm-Anum   RN                       1
# 23                      lugal    N                    king
# 24                    Uruk,ak   SN                       1
# 25                          u  CNJ                     and
# 26                    adam,bi    N              habitation
# 27        Aham-arši             PN                      00
# 28     Marduk-nāṣir             PN                      00
# 29                               u
# ...             ...       ...  ...                     ...
# 16197                            u
# 16198                            X
# 16199                            u
# 16200          annê             DP                    this
# 16201                            u
# 16202                            u
# 16203      tunakkar              V                  remove
# 16204                            u
# 16205       nahlūte             AJ                strained
# 16206                            u
# 16207      tamaddad              V                 measure
# 16208                            u
# 16209          ištu            PRP                    from
# 16210        ahāʾiš              N              each other
# 16211                            u
# 16212            mê              N                   water
# 16213            kī            PRP                    like
# 16214                            X
# 16215                            u
# 16216           ina            PRP                      in
# 16217        mubêše              N  implement for stirring
# 16218      tubeʾʾaš              V                    stir
# 16219                            u
# 16220                            X
# 16221            kī            PRP                    like
# 16222                            u
# 16223                            u
# 16224         išāti              N                    fire
# 16225          ištu            PRP                    from
# 16226                            u
#
#                                  lemma
# 0                       2(BARIG)[NA]NA
# 1                         qēmu[flour]N
# 2                US₂[lesser-quality]AJ
# 3                           ana[to]PRP
# 4              tākultu[(cultic)-meal]N
# 5                          awīlu[man]N
# 6                          Kisura[1]SN
# 7                          awīlu[man]N
# 8                            Gutû[1]GN
# 9                            u[and]CNJ
# 10                     ahītu[outside]N
# 11                         ṣītu[exit]N
# 12                  libbu[inner-body]N
# 13                        bītu[house]N
# 14                     asīru[captive]N
# 15                           ša[of]DET
# 16                     qāt[authority]N
# 17                      Sîn-šeme[00]PN
# 18                          Elūlu[1]MN
# 19                           ūmu[day]N
# 20                        21-KAM[NA]NA
# 21                           mu[year]N
# 22                       Rīm-Anum[1]RN
# 23                        lugal[king]N
# 24                           Uruk[1]SN
# 25                           u[and]CNJ
# 26                   adam[habitation]N
# 27                      Aha-arši[00]PN
# 28                  Marduk-nāṣir[00]PN
# 29                             x[NA]NA
# ...                                ...
# 16197                          x[NA]NA
# 16198                   su-u₂-ni[NA]NA
# 16199                          x[NA]NA
# 16200                     annû[this]DP
# 16201                         $A[NA]NA
# 16202                          x[NA]NA
# 16203                  nakāru[change]V
# 16204                          x[NA]NA
# 16205                  nahlu[sieved]AJ
# 16206                          x[NA]NA
# 16207                 madādu[measure]V
# 16208                          x[NA]NA
# 16209                    ištu[from]PRP
# 16210              ahāʾiš[each-other]N
# 16211                          x[NA]NA
# 16212                       mû[water]N
# 16213                      kī[like]PRP
# 16214                    ša-kin₂[NA]NA
# 16215                          x[NA]NA
# 16216                       ina[in]PRP
# 16217  mubêšu[implement-for-stirring]N
# 16218                    beʾēšu[stir]V
# 16219                          x[NA]NA
# 16220                   a-tar-bu[NA]NA
# 16221                      kī[like]PRP
# 16222                          x[NA]NA
# 16223                          x[NA]NA
# 16224                     išātu[fire]N
# 16225                    ištu[from]PRP
# 16226                    ša-an-x[NA]NA
#
# [16227 rows x 16 columns]

# %% [markdown]
# ## 3.3 Group by Textid
# Get all the lemmas that belong to a single text in one row (one row = one document). The `agg()` (aggregate) function, which works on the result of a `groupby()` process aggregates columns of the original dataframe. The function takes a dictionary in which the keys are column names and the values are functions to be used in the aggregation process. The example below has only one such function (`' '.join` will join all entries in the colum `lemma` with a space in between); one may specify (the same or different) functions for different columns, for instance:
# > word_df = word_df.groupby("textid").agg({"lemma": ' '.join, "base": ' '.join})

# %%
word_df = word_df.groupby("id_text").agg({"lemma": ' '.join})
word_df.reset_index()
# Out:
#              id_text                                              lemma
# 0      glass/P282518  x[NA]NA ahāzu[take]V x[NA]NA nabalkutu[cross-o...
# 1      glass/P282519  x[NA]NA ruqqû[process-oil]V lu-x-x[NA]NA x[NA]...
# 2      glass/P282520  šumma[if]MOD šamnu[oil]N ša[of]DET asanītu[(an...
# 3      glass/P282611  kalû[totality]N x[NA]NA ša[of]DET x[NA]NA mû[w...
# 4      glass/P282617  šumma[if]MOD 2(BAN₂)[NA]NA šamnu[oil]N qanû[re...
# 5      glass/P282618  x[NA]NA ina[in]PRP 2[NA]NA ūmu[day]N ina[in]PR...
# 6      glass/P393786  inūma[when]SBJ uššu[foundation(s)]N kūru[kiln]...
# 7      glass/P394484  inūma[when]SBJ uššu[foundation(s)]N kūru[kiln]...
# 8      glass/P395291  x[NA]NA x-ša-x[NA]NA x[NA]NA ina[in]PRP utūnu[...
# 9      glass/P395468  x[NA]NA x[NA]NA x[NA]NA x[NA]NA x[NA]NA zakû[p...
# 10     glass/P395469  x-x[NA]NA 1[NA]NA ammatu[unit]N x[NA]NA adi[un...
# 11     glass/P396602  x[NA]NA ṣâdu[melt-(down)]V x[NA]NA x[NA]NA elû...
# 12     glass/P396900  3[NA]NA kisal[(a-weight)]N x[NA]NA kiṣru[knot]...
# 13     glass/P396928  inūma[when]SBJ uššu[foundation(s)]N kūru[kiln]...
# 14     glass/P397046  x[NA]NA epēšu[do]V x[NA]NA kutpû[black-frit]N ...
# 15     glass/P397390  x[NA]NA x[NA]NA išātu[fire]N ṣâdu[melt-(down)]...
# 16     glass/P398181  werû[copper]N x-x[NA]NA abnu[stone]N u[and]CNJ...
# 17     glass/P398442  šumma[if]MOD būṣu[(a-type-of-glass)]N ana[to]P...
# 18     glass/P399221  x[NA]NA lā[not]MOD qa-ti-x-x[NA]NA x[NA]NA šar...
# 19     glass/P400231  ana[to]PRP x-x[NA]NA ša[of]DET tukkannu[(leath...
# 20   rimanum/P295625  5(BAN₂)[NA]NA 6(SILA₃)[NA]NA qēmu[flour]N kuru...
# 21   rimanum/P296047  x[NA]NA x[NA]NA x[NA]NA x{ki}[NA]NA x[NA]NA x{...
# 22   rimanum/P296277  Aha-arši[00]PN Marduk-nāṣir[00]PN x[NA]NA 2[NA...
# 23   rimanum/P296278  Sîn-išmeanni[00]PN Abisu[00]PN Hāpiru[00]PN x-...
# 24   rimanum/P296414  Saggal-šamhat[00]PN Ahātu[00]PN 2[NA]NA amtu[m...
# 25   rimanum/P297038  ṣehru[small-one]N Kalab-Šamaš[00]PN libbu[inne...
# 26   rimanum/P311964  x[NA]NA libbu[inner-body]N bītu[house]N asīru[...
# 27   rimanum/P368396  x[NA]NA x[NA]NA x[NA]NA {m}x[NA]NA hu[NA]NA x[...
# 28   rimanum/P368398  Bēltani[00]PN aššatu[wife]N Ipqu-Arahtu[00]PN ...
# 29   rimanum/P372766  Arrak[00]PN Adad-šarru[00]PN Simtaligeš[00]PN ...
# ..               ...                                                ...
# 368  rimanum/P405439  1(BARIG)[NA]NA 4(BAN₂)[NA]NA mundu[a-type-of-f...
# 369  rimanum/P405440  2(BARIG)[NA]NA qēmu[flour]N US₂[lesser-quality...
# 370  rimanum/P405441  4(BAN₂)[NA]NA 2(SILA₃)[NA]NA qēmu[flour]N kuru...
# 371  rimanum/P405442  x[NA]NA u[and]CNJ ahītu[outside]N ṣītu[exit]N ...
# 372  rimanum/P405443  1(BARIG)[NA]NA qēmu[flour]N ana[to]PRP tākultu...
# 373  rimanum/P405444  1(BARIG)[NA]NA 4(BAN₂)[NA]NA qēmu[flour]N ana[...
# 374  rimanum/P405445  Warad-Ištar[00]PN rēdûtu[status-or-service-of-...
# 375  rimanum/P405446  2(BARIG)[NA]NA qēmu[flour]N ana[to]PRP tākultu...
# 376  rimanum/P405447  Ēreš-Šamaš[00]PN x[NA]NA x[NA]NA Šamaš-iddina[...
# 377  rimanum/P405448  x[NA]NA namhartu[receipt(s)]N Iddin-Adad[00]PN...
# 378  rimanum/P405449  Tarīš-mātu[00]PN Rībatu[00]PN Bēlet-ilī-ummī[0...
# 379  rimanum/P450684  40[NA]NA {giš}x[NA]NA x[NA]NA x[NA]NA x[NA]NA ...
# 380  rimanum/P450685  Marduk-nāṣir[00]PN Ibni-Kabta[00]PN 2[NA]NA mā...
# 381  rimanum/P450686  5(BAN₂)[NA]NA qēmu[flour]N kurummatu[food-allo...
# 382  rimanum/P450687  2(BARIG)[NA]NA qēmu[flour]N ana[to]PRP kurumma...
# 383  rimanum/P450688  x[NA]NA qēmu[flour]N x[NA]NA mār[son]N šipri[s...
# 384  rimanum/P450689  2(BARIG)[NA]NA qēmu[flour]N ana[to]PRP x[NA]NA...
# 385  rimanum/P450690  2(BARIG)[NA]NA qēmu[flour]N ana[to]PRP tākultu...
# 386  rimanum/P450691  1(BARIG)[NA]NA 3(BAN₂)[NA]NA qēmu[flour]N ana[...
# 387  rimanum/P450692  2(BARIG)[NA]NA qēmu[flour]N ana[to]PRP kurumma...
# 388  rimanum/P450693  x[NA]NA qēmu[flour]N ana[to]PRP tākultu[(culti...
# 389  rimanum/P450694  x[NA]NA qēmu[flour]N US₂[lesser-quality]AJ ana...
# 390  rimanum/P450695  3(BAN₂)[NA]NA qēmu[flour]N piqittu[allocation]...
# 391  rimanum/P450696  x[NA]NA qēmu[flour]N ana[to]PRP kurummatu[food...
# 392  rimanum/P450697  4(BAN₂)[NA]NA 8(SILA₃)[NA]NA qēmu[flour]N kuru...
# 393  rimanum/P450698  1(BARIG)[NA]NA 2(BAN₂)[NA]NA 6(SILA₃)[NA]NA ku...
# 394  rimanum/P450699  4(BAN₂)[NA]NA 9(SILA₃)[NA]NA ZI₃.DA[NA]NA a-na...
# 395  rimanum/P450700  1(BARIG)[NA]NA qēmu[flour]N ana[to]PRP tākultu...
# 396  rimanum/P450701  x[NA]NA qēmu[flour]N ana[to]PRP tākultu[(culti...
# 397  rimanum/P450702  2(BARIG)[NA]NA 3(BAN₂)[NA]NA qēmu[flour]N namh...
#
# [398 rows x 2 columns]

# %% [markdown]
# ## 4 Save Results in CSV file
# The output file is called `parsed.csv` and is to be found in the directory `output`. In most computers, `csv` files open automatically in Excel. This program does not deal well with `utf-8` encoding. If you intend to use the file in Excel, change `encoding ='utf-8'` to `encoding='utf-16'`. For usage in computational text analysis applications `utf-8` is usually preferred.
#
# (Alternatively, use the instructions [here](https://www.itg.ias.edu/content/how-import-csv-file-uses-utf-8-character-encoding-0) to import a `utf-8` file into Excel).

# %%
savefile =  'parsed.csv'
with open('output/' + savefile, 'w', encoding="utf-8") as w:
    word_df.to_csv(w)
