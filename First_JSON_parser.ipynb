# %% [markdown]
# # Extract Lemmatization from JSON: Basic Parser
# The code in this notebook will parse [ORACC](http://oracc.org) `JSON` files to extract lemmatization data for one or more texts. The resulting `csv` (Comma Separated Values) file has two fields: a Text ID (e.g. `dcclt/Q000039`) and a string of lemmas in the format `lugal[king]N` (or `šarru[king]N` for Akkadian texts).
#
# The Basic Parser downloads one `json` file a time from the [ORACC](http://oracc.org) server and then parses that file, continuing with the next file. This method is not ideal for large amounts of data (for instance if you intent to parse an entire project, or several projects at once). While going through a long list of files, the connection with the server may get reset (for instance when the computer goes to sleep, or if there is a brief period of bad connectivity) and the script will fail. The Advanced Parser will introduce a better way of doing that.
#
# The output of the Basic Parser does not recognize lines (all words/lemmas in a text are listed sequentially) and does not indicate breakage. These issues are of little consequence for [bag of words](https://en.wikipedia.org/wiki/Bag-of-words_model) techniques such as [topic modeling](https://en.wikipedia.org/wiki/Topic_model), but may become serious limitations for other types of computational approaches. The Advanced Parser will introduce techniques to extract such data.
#
# [ORACC](http://oracc.org) `json` files also include data on the sign level (reading, sign name, unicode number, function, etc). These data are not extracted in the parsers demonstrated here, but the example code should provide a model for how any type of data can be extracted.

# %%
import requests
import pandas as pd

# %% [markdown]
# ## 1.1 Input List of Text IDs
# Identify a list of text IDs (P, Q, and X numbers) in the directory `text_ids`. The IDs are six-digit P, Q, or X numbers preceded by a project abbreviation in the format 'PROJECT/P######' or 'PROJECT/SUBPROJECT/Q######'. For example:
# * dcclt/P117395
# * etcsri/Q001203
# * rinap/rinap1/Q003421
#
# The list should be created with a flat text editor such as Textedit or Emacs, and the filename should end in `.txt`.
#
# The P, Q, and X numbers available in a project are listed in the project's `corpus.json` at the address `http://oracc.org/[PROJECT]/corpus.json` (for instance http://oracc.org/saao/saa01/corpus.json).

# %%
filename = input('Filename: ')
# Out:
# Filename: ob_lists_wood.txt

# %% [markdown]
# ## 1.2 Open the List of Text IDs and Remove Spaces and Empty Lines

# %%
textids = 'text_ids/' + filename
with open(textids, 'r') as f:
    pqxnos = f.readlines()
pqxnos = [x.strip() for x in pqxnos]        # strip spaces left and right
pqxnos = [x for x in pqxnos if not x == ""] # strip empty lines

# %% [markdown]
# ## 2.1 The `parsejson()` function
# The `parsejson()` function will "digg into" the `json` file (transformed into a dictionary) until it finds the relevant data. The `json` file consists of a hierarchy of `cdl` nodes; only the lowest nodes contain lemmatization data. The function goes down this hierarchy by calling itself when another `cdl` node is encountered.
#
# The first argument of `parsejson()` is a dictionary (derived from `JSON`), the second a list of lemmatization data that is being built while the function iterates through the dictionary. When initially called, the second argument is supposed to be empty. For the code to run properly, the default value of the second argument must be `None`; see the [blog post](http://effbot.org/zone/default-values.htm) by Fredrik Lundh.

# %%
def parsejson(text, lemm_l = None):
    if lemm_l == None:
        lemm_l = []
    for dictionary in text["cdl"]:
        if "cdl" in dictionary: 
            parsejson(dictionary, lemm_l)
        elif "f" in dictionary:
            lemm_l.append(dictionary["f"])
    return lemm_l

# %% [markdown]
# ## 2.2 Call the `parsejson()` function for every `JSON` file
# The code in this cell will read the list of text IDs identified above. Each text ID (e.g.`dcclt/Q000039`) is split into the ID number (`Q000039`) and the project designation (`dcclt`). These elements are used to build the `URL` for the `json` file on the [ORACC](http://oracc.org) server.
#
# The `json` file is downloaded with the `requests` library and transformed into a Python object (a dictionary) with the `json()` function of this same library.
#
# This dictionary, which is called `text` is now sent to the `parsejson()` function. The function returns a list of lemmata (lemm_text`

# %%
word_l = []
for id_text in pqxnos:
    project = id_text[:-8].lower()
    pqx = id_text[-7:].upper()
    url = "http://oracc.org/" + project + '/corpusjson/' + pqx + '.json'
    r = requests.get(url)
    try:
        text = r.json()
        print("parsing " + id_text)
        lemm_text = parsejson(text)
        for lemm in lemm_text:
            lemm['textid'] = id_text
        word_l.extend(lemm_text)
    except:
        print(id_text + ' is not available or not complete')
# Out:
# parsing dcclt/Q000039
# parsing dcclt/P117395
# parsing dcclt/P117404
# parsing dcclt/P128345
# parsing dcclt/P224980
# parsing dcclt/P224986
# parsing dcclt/P224994
# parsing dcclt/P224996
# parsing dcclt/P225006
# parsing dcclt/P225023
# parsing dcclt/P225033
# parsing dcclt/P225059
# parsing dcclt/P225062
# parsing dcclt/P225065
# parsing dcclt/P225086
# parsing dcclt/P225109
# parsing dcclt/P225126
# parsing dcclt/P225132
# parsing dcclt/P229426
# parsing dcclt/P230069
# parsing dcclt/P235262
# parsing dcclt/P247543
# parsing dcclt/P247864
# parsing dcclt/P249383
# parsing dcclt/P250361
# parsing dcclt/P250362
# parsing dcclt/P250363
# parsing dcclt/P250364
# parsing dcclt/P250368
# parsing dcclt/P250369
# parsing dcclt/P250370
# parsing dcclt/P250371
# parsing dcclt/P251495
# parsing dcclt/P251649
# parsing dcclt/P251686
# parsing dcclt/P251778
# parsing dcclt/P251867
# parsing dcclt/P253228
# parsing dcclt/P253230
# parsing dcclt/P253233
# parsing dcclt/P253238
# parsing dcclt/P253245
# parsing dcclt/P253863
# parsing dcclt/P253866
# parsing dcclt/P253874
# parsing dcclt/P253887
# parsing dcclt/P253896
# parsing dcclt/P253899
# parsing dcclt/P253923
# parsing dcclt/P253927
# parsing dcclt/P254360
# parsing dcclt/P272532
# parsing dcclt/P273706
# parsing dcclt/P273712
# parsing dcclt/P273880
# parsing dcclt/P296528
# parsing dcclt/P297185
# parsing dcclt/P297194
# parsing dcclt/P297195
# parsing dcclt/P299494
# parsing dcclt/P299509
# parsing dcclt/P303955
# parsing dcclt/P312012
# parsing dcclt/P345549
# parsing dcclt/P346714
# parsing dcclt/P346865
# parsing dcclt/P346866
# parsing dcclt/P346867
# parsing dcclt/P346868
# parsing dcclt/P346869
# parsing dcclt/P346872
# parsing dcclt/P346897
# parsing dcclt/P347516
# parsing dcclt/P347814
# parsing dcclt/P347815
# parsing dcclt/P349171
# parsing dcclt/P349173
# parsing dcclt/P369718
# parsing dcclt/P370399
# parsing dcclt/P382665
# parsing dcclt/P388265
# parsing dcclt/P388330
# parsing dcclt/P388563
# parsing dcclt/P389437
# parsing dcclt/P389511
# parsing dcclt/P423759
# parsing dcclt/P432448
# parsing dcclt/P433291
# parsing dcclt/P447996
# parsing dcclt/P459216
# parsing dcclt/P459217
# parsing dcclt/P459218
# parsing dcclt/P459219
# parsing dcclt/P459220
# parsing dcclt/P459221
# parsing dcclt/P459222
# parsing dcclt/P459223
# parsing dcclt/P459224
# parsing dcclt/P459225
# parsing dcclt/P459226
# parsing dcclt/P459227
# parsing dcclt/P459228
# parsing dcclt/P459230
# parsing dcclt/P459231
# parsing dcclt/P459784
# parsing dcclt/P492330

# %%
word_df = pd.DataFrame(word_l).fillna('')
word_df
# Out:
#                         base            cf     cont delim epos  \
# 0              {ŋeš}taškarin      taškarin                   N
# 1                   {ŋeš}esi           esi                   N
# 2                   ŋeš-nu₁₁         ŋešnu                   N
# 3             {ŋeš}ha-lu-ub₂         halub                   N
# 4              {ŋeš}šag₄-kal        šagkal                   N
# 5                   ŋeš-kin₂       ŋešgana                   N
# 6                   ŋeš-kin₂       ŋešgana                   N
# 7                     babbar        babbar                 V/i
# 8                   ŋeš-kin₂       ŋešgana                   N
# 9                      giggi         giggi                 V/i
# 10                       ŋeš           ŋeš                   N
# 11                     giggi         giggi                 V/i
# 12               {ŋeš}ŋeštin        ŋeštin                   N
# 13          {ŋeš}ŋeštin-kir₄    ŋeštinkira                   N
# 14         {ŋeš}ŋeštin-ka₅-a    ŋeštinkaʾa                   N
# 15      {ŋeš}ŋeštin-gurum-ma  ŋeštinguruma                   N
# 16                 {ŋeš}peš₃           peš                   N
# 17               {ŋeš}hašhur        hašhur                   N
# 18               {ŋeš}hašhur        hašhur                   N
# 19                       kur           kur  -ra=r.a          N
# 20              {ŋeš}še-dug₃         šedug                   N
# 21                {ŋeš}še-nu          šenu                   N
# 22                {ŋeš}še-še          šeše                   N
# 23                {ŋeš}šinig         šinig                   N
# 24                {ŋeš}šinig         šinig                   N
# 25                      dili          dili                 V/i
# 26                {ŋeš}šinig         šinig                   N
# 27                       kur           kur  -ra=r.a          N
# 28    {ŋeš}šarₓ(NE)-ša₄-bid₃      šaršabid                   N
# 29                  {ŋeš}mes           mes                   N
# ...                      ...           ...      ...   ...  ...
# 8516
# 8517
# 8518
# 8519
# 8520
# 8521
# 8522
# 8523
# 8524            {ŋeš}dib-dib        dibdib                   N
# 8525
# 8526
# 8527
# 8528
# 8529
# 8530
# 8531
# 8532
# 8533
# 8534
# 8535
# 8536
# 8537
# 8538
# 8539
# 8540
# 8541
# 8542                               napharu                   N
# 8543
# 8544                                  šūši                  NU
# 8545
#
#                         form  \
# 0              {ŋeš}taškarin
# 1                   {ŋeš}esi
# 2                  {ŋeš}nu₁₁
# 3             {ŋeš}ha-lu-ub₂
# 4              {ŋeš}šag₄-kal
# 5                   ŋeš-kin₂
# 6                   ŋeš-kin₂
# 7                     babbar
# 8                   ŋeš-kin₂
# 9                      giggi
# 10                       ŋeš
# 11                     giggi
# 12               {ŋeš}ŋeštin
# 13          {ŋeš}ŋeštin-kir₄
# 14         {ŋeš}ŋeštin-ka₅-a
# 15        {ŋeš}ŋeštin-GAM-ma
# 16                 {ŋeš}peš₃
# 17               {ŋeš}hašhur
# 18               {ŋeš}hašhur
# 19                    kur-ra
# 20              {ŋeš}še-dug₃
# 21                {ŋeš}še-nu
# 22                {ŋeš}še-še
# 23                {ŋeš}šinig
# 24                {ŋeš}šinig
# 25                      dili
# 26                {ŋeš}šinig
# 27                    kur-ra
# 28    {ŋeš}šarₓ(NE)-ša₄-bid₃
# 29                  {ŋeš}mes
# ...                      ...
# 8516             {ŋeš}eš-bar
# 8517                       x
# 8518                  {ŋeš}x
# 8519                       x
# 8520              {ŋeš}GAR-x
# 8521                       x
# 8522              {ŋeš}AMA-x
# 8523                       x
# 8524            {ŋeš}dib-dib
# 8525                       x
# 8526             {ŋeš}kar₂-x
# 8527                       x
# 8528              {ŋeš}saŋ-x
# 8529                       x
# 8530                  {ŋeš}x
# 8531                       x
# 8532                {ŋeš}a-x
# 8533                       x
# 8534             {ŋeš}KA-x-x
# 8535                       x
# 8536                  {ŋeš}x
# 8537                       x
# 8538                       x
# 8539                me-e-x-x
# 8540                     x-x
# 8541                li-i-rum
# 8542                ŠU.NIGIN
# 8543                       2
# 8544                   šu-ši
# 8545                      28
#
#                                                     gdl          gw  \
# 0     [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...     boxwood
# 1     [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...        tree
# 2     [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...        tree
# 3     [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...        tree
# 4     [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...        tree
# 5     [{'v': 'ŋeš', 'id': 'Q000039.6.1.0', 'delim': ...        tree
# 6     [{'v': 'ŋeš', 'id': 'Q000039.7.1.0', 'delim': ...        tree
# 7              [{'v': 'babbar', 'id': 'Q000039.7.2.0'}]       white
# 8     [{'v': 'ŋeš', 'id': 'Q000039.8.1.0', 'delim': ...        tree
# 9               [{'v': 'giggi', 'id': 'Q000039.8.2.0'}]       black
# 10                [{'v': 'ŋeš', 'id': 'Q000039.9.1.0'}]        tree
# 11              [{'v': 'giggi', 'id': 'Q000039.9.2.0'}]       black
# 12    [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...        vine
# 13    [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...       berry
# 14    [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...       grape
# 15    [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...       ~vine
# 16    [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...         fig
# 17    [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...       apple
# 18    [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...       apple
# 19    [{'v': 'kur', 'id': 'Q000039.16.2.0', 'delim':...    mountain
# 20    [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...        tree
# 21    [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...        tree
# 22    [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...        tree
# 23    [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...    tamarisk
# 24    [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...    tamarisk
# 25              [{'v': 'dili', 'id': 'Q000039.21.2.0'}]      single
# 26    [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...    tamarisk
# 27    [{'v': 'kur', 'id': 'Q000039.22.2.0', 'delim':...    mountain
# 28    [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...        tree
# 29    [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...        tree
# ...                                                 ...         ...
# 8516  [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...
# 8517  [{'x': 'ellipsis', 'id': 'P492330.27.2.0', 'br...
# 8518  [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...
# 8519  [{'x': 'ellipsis', 'id': 'P492330.31.2.0', 'br...
# 8520  [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...
# 8521  [{'x': 'ellipsis', 'id': 'P492330.32.2.0', 'br...
# 8522  [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...
# 8523  [{'x': 'ellipsis', 'id': 'P492330.33.2.0', 'br...
# 8524  [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...  waterclock
# 8525  [{'x': 'ellipsis', 'id': 'P492330.34.2.0', 'br...
# 8526  [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...
# 8527  [{'x': 'ellipsis', 'id': 'P492330.35.2.0', 'br...
# 8528  [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...
# 8529  [{'x': 'ellipsis', 'id': 'P492330.36.2.0', 'br...
# 8530  [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...
# 8531  [{'x': 'ellipsis', 'id': 'P492330.37.2.0', 'br...
# 8532  [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...
# 8533  [{'x': 'ellipsis', 'id': 'P492330.38.2.0', 'br...
# 8534  [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...
# 8535  [{'x': 'ellipsis', 'id': 'P492330.39.2.0', 'br...
# 8536  [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...
# 8537  [{'x': 'ellipsis', 'id': 'P492330.40.2.0', 'br...
# 8538  [{'x': 'ellipsis', 'id': 'P492330.43.1.0', 'br...
# 8539  [{'v': 'me', 'id': 'P492330.43.2.0', 'break': ...
# 8540  [{'x': 'ellipsis', 'id': 'P492330.44.1.0', 'br...
# 8541  [{'v': 'li', 'id': 'P492330.44.2.0', 'delim': ...
# 8542  [{'gg': 'logo', 'gdl_type': 'logo', 'group': [...       total
# 8543  [{'n': 'n', 'sexified': '2(diš)', 'form': '2',...
# 8544  [{'v': 'šu', 'id': 'P492330.46.3.0', 'delim': ...       sixty
# 8545  [{'n': 'n', 'sexified': '2(u) 8(diš)', 'form':...
#
#               lang morph    norm         norm0  pos  \
# 0              sux     ~              taškarin    N
# 1              sux     ~                   esi    N
# 2              sux     ~                 ŋešnu    N
# 3              sux     ~                 halub    N
# 4              sux     ~                šagkal    N
# 5              sux     ~               ŋešgana    N
# 6              sux     ~               ŋešgana    N
# 7              sux     ~                babbar  V/i
# 8              sux     ~               ŋešgana    N
# 9              sux     ~                 giggi  V/i
# 10             sux     ~                   ŋeš    N
# 11             sux     ~                 giggi  V/i
# 12             sux     ~                ŋeštin    N
# 13             sux     ~            ŋeštinkira    N
# 14             sux     ~            ŋeštinkaʾa    N
# 15             sux     ~          ŋeštinguruma    N
# 16             sux     ~                   peš    N
# 17             sux     ~                hašhur    N
# 18             sux     ~                hašhur    N
# 19             sux  ~,ak                kur,ak    N
# 20             sux     ~                 šedug    N
# 21             sux     ~                  šenu    N
# 22             sux     ~                  šeše    N
# 23             sux     ~                 šinig    N
# 24             sux     ~                 šinig    N
# 25             sux     ~                  dili  V/i
# 26             sux     ~                 šinig    N
# 27             sux  ~,ak                kur,ak    N
# 28             sux     ~              šaršabid    N
# 29             sux     ~                   mes    N
# ...            ...   ...     ...           ...  ...
# 8516           sux                                X
# 8517  akk-x-oldbab                                u
# 8518           sux                                u
# 8519  akk-x-oldbab                                u
# 8520           sux                                u
# 8521  akk-x-oldbab                                u
# 8522           sux                                u
# 8523  akk-x-oldbab                                u
# 8524           sux     ~                dibdib    N
# 8525  akk-x-oldbab                                u
# 8526           sux                                u
# 8527  akk-x-oldbab                                u
# 8528           sux                                u
# 8529  akk-x-oldbab                                u
# 8530           sux                                u
# 8531  akk-x-oldbab                                u
# 8532           sux                                u
# 8533  akk-x-oldbab                                u
# 8534           sux                                u
# 8535  akk-x-oldbab                                u
# 8536           sux                                u
# 8537  akk-x-oldbab                                u
# 8538           sux                                u
# 8539  akk-x-oldbab                                u
# 8540           sux                                u
# 8541  akk-x-oldbab                                X
# 8542  akk-x-oldbab        naphar                  N
# 8543  akk-x-oldbab                                n
# 8544  akk-x-oldbab          šūši                 NU
# 8545  akk-x-oldbab                                n
#
#                              sense         textid
# 0                box tree, boxwood  dcclt/Q000039
# 1                            ebony  dcclt/Q000039
# 2                             tree  dcclt/Q000039
# 3                             tree  dcclt/Q000039
# 4                             tree  dcclt/Q000039
# 5                             tree  dcclt/Q000039
# 6                             tree  dcclt/Q000039
# 7                    (to be) white  dcclt/Q000039
# 8                             tree  dcclt/Q000039
# 9                    (to be) black  dcclt/Q000039
# 10                            tree  dcclt/Q000039
# 11                   (to be) black  dcclt/Q000039
# 12                            vine  dcclt/Q000039
# 13                           berry  dcclt/Q000039
# 14                         a grape  dcclt/Q000039
# 15                           ~vine  dcclt/Q000039
# 16                             fig  dcclt/Q000039
# 17                    apple (tree)  dcclt/Q000039
# 18                    apple (tree)  dcclt/Q000039
# 19                        mountain  dcclt/Q000039
# 20                          a tree  dcclt/Q000039
# 21                            tree  dcclt/Q000039
# 22                          a tree  dcclt/Q000039
# 23                        tamarisk  dcclt/Q000039
# 24                        tamarisk  dcclt/Q000039
# 25    (to be) single, unique, sole  dcclt/Q000039
# 26                        tamarisk  dcclt/Q000039
# 27                        mountain  dcclt/Q000039
# 28                            tree  dcclt/Q000039
# 29                          a tree  dcclt/Q000039
# ...                            ...            ...
# 8516                                dcclt/P492330
# 8517                                dcclt/P492330
# 8518                                dcclt/P492330
# 8519                                dcclt/P492330
# 8520                                dcclt/P492330
# 8521                                dcclt/P492330
# 8522                                dcclt/P492330
# 8523                                dcclt/P492330
# 8524                    waterclock  dcclt/P492330
# 8525                                dcclt/P492330
# 8526                                dcclt/P492330
# 8527                                dcclt/P492330
# 8528                                dcclt/P492330
# 8529                                dcclt/P492330
# 8530                                dcclt/P492330
# 8531                                dcclt/P492330
# 8532                                dcclt/P492330
# 8533                                dcclt/P492330
# 8534                                dcclt/P492330
# 8535                                dcclt/P492330
# 8536                                dcclt/P492330
# 8537                                dcclt/P492330
# 8538                                dcclt/P492330
# 8539                                dcclt/P492330
# 8540                                dcclt/P492330
# 8541                                dcclt/P492330
# 8542                         total  dcclt/P492330
# 8543                                dcclt/P492330
# 8544                         sixty  dcclt/P492330
# 8545                                dcclt/P492330
#
# [8546 rows x 15 columns]

# %% [markdown]
# ## 3.1 Create a `lemma` column
# The following code combines the `cf` (Citation Form), `gw` (Guide Word), and `pos` (Part of Speech) columns to create a new `lemma` column with the format `cf[gw]pos`, for instance `šarru[king]N` or `lugal[king]N`. Unlemmatized words do not have `cf`, `gw`, or `pos` - they only have `form` (the transliteration). The function therefore has a condition: if `cf` is empty, the format should be `form[NA]NA`. Alternatively, one may leave out non-lemmatized words altogether and create the `lemma` column by simply adding up `cf`, `gw`, and `pos`, as follows:
#
# > `word_df = word_df[word_df['cf'] != '']`
#
# > `word_df['lemma'] = word_df['cf'] + '[' + word_df['gw'] + ']' + word_df['pos']`

# %%
word_df["lemma"] = word_df.apply(lambda r: (r["cf"] + '[' + r["gw"] + ']' + r["pos"]) if r["cf"] != '' 
                                 else r['form'] + '[NA]NA', axis=1)
word_df[['textid', 'lemma']]
# Out:
#              textid                 lemma
# 0     dcclt/Q000039    taškarin[boxwood]N
# 1     dcclt/Q000039            esi[tree]N
# 2     dcclt/Q000039          ŋešnu[tree]N
# 3     dcclt/Q000039          halub[tree]N
# 4     dcclt/Q000039         šagkal[tree]N
# 5     dcclt/Q000039        ŋešgana[tree]N
# 6     dcclt/Q000039        ŋešgana[tree]N
# 7     dcclt/Q000039      babbar[white]V/i
# 8     dcclt/Q000039        ŋešgana[tree]N
# 9     dcclt/Q000039       giggi[black]V/i
# 10    dcclt/Q000039            ŋeš[tree]N
# 11    dcclt/Q000039       giggi[black]V/i
# 12    dcclt/Q000039         ŋeštin[vine]N
# 13    dcclt/Q000039    ŋeštinkira[berry]N
# 14    dcclt/Q000039    ŋeštinkaʾa[grape]N
# 15    dcclt/Q000039  ŋeštinguruma[~vine]N
# 16    dcclt/Q000039             peš[fig]N
# 17    dcclt/Q000039        hašhur[apple]N
# 18    dcclt/Q000039        hašhur[apple]N
# 19    dcclt/Q000039        kur[mountain]N
# 20    dcclt/Q000039          šedug[tree]N
# 21    dcclt/Q000039           šenu[tree]N
# 22    dcclt/Q000039           šeše[tree]N
# 23    dcclt/Q000039      šinig[tamarisk]N
# 24    dcclt/Q000039      šinig[tamarisk]N
# 25    dcclt/Q000039       dili[single]V/i
# 26    dcclt/Q000039      šinig[tamarisk]N
# 27    dcclt/Q000039        kur[mountain]N
# 28    dcclt/Q000039       šaršabid[tree]N
# 29    dcclt/Q000039            mes[tree]N
# ...             ...                   ...
# 8516  dcclt/P492330     {ŋeš}eš-bar[NA]NA
# 8517  dcclt/P492330               x[NA]NA
# 8518  dcclt/P492330          {ŋeš}x[NA]NA
# 8519  dcclt/P492330               x[NA]NA
# 8520  dcclt/P492330      {ŋeš}GAR-x[NA]NA
# 8521  dcclt/P492330               x[NA]NA
# 8522  dcclt/P492330      {ŋeš}AMA-x[NA]NA
# 8523  dcclt/P492330               x[NA]NA
# 8524  dcclt/P492330   dibdib[waterclock]N
# 8525  dcclt/P492330               x[NA]NA
# 8526  dcclt/P492330     {ŋeš}kar₂-x[NA]NA
# 8527  dcclt/P492330               x[NA]NA
# 8528  dcclt/P492330      {ŋeš}saŋ-x[NA]NA
# 8529  dcclt/P492330               x[NA]NA
# 8530  dcclt/P492330          {ŋeš}x[NA]NA
# 8531  dcclt/P492330               x[NA]NA
# 8532  dcclt/P492330        {ŋeš}a-x[NA]NA
# 8533  dcclt/P492330               x[NA]NA
# 8534  dcclt/P492330     {ŋeš}KA-x-x[NA]NA
# 8535  dcclt/P492330               x[NA]NA
# 8536  dcclt/P492330          {ŋeš}x[NA]NA
# 8537  dcclt/P492330               x[NA]NA
# 8538  dcclt/P492330               x[NA]NA
# 8539  dcclt/P492330        me-e-x-x[NA]NA
# 8540  dcclt/P492330             x-x[NA]NA
# 8541  dcclt/P492330        li-i-rum[NA]NA
# 8542  dcclt/P492330       napharu[total]N
# 8543  dcclt/P492330               2[NA]NA
# 8544  dcclt/P492330         šūši[sixty]NU
# 8545  dcclt/P492330              28[NA]NA
#
# [8546 rows x 2 columns]

# %% [markdown]
# ## 3.2 Remove Spaces and Commas from the Lemma
# Spaces and commas in the Guide Word may cause trouble in computational methods in tokenization, or when saved in Comma Separated Values format. All spaces and commas are replaced by hyphens or nothing, respectively.

# %%
word_df.loc[:,'lemma'] = [x.replace(' ', '-') for x in word_df.loc[:,'lemma']]
word_df.loc[:,'lemma'] = [x.replace(',', '') for x in word_df.loc[:,'lemma']]
word_df
# Out:
#                         base            cf     cont delim epos  \
# 0              {ŋeš}taškarin      taškarin                   N
# 1                   {ŋeš}esi           esi                   N
# 2                   ŋeš-nu₁₁         ŋešnu                   N
# 3             {ŋeš}ha-lu-ub₂         halub                   N
# 4              {ŋeš}šag₄-kal        šagkal                   N
# 5                   ŋeš-kin₂       ŋešgana                   N
# 6                   ŋeš-kin₂       ŋešgana                   N
# 7                     babbar        babbar                 V/i
# 8                   ŋeš-kin₂       ŋešgana                   N
# 9                      giggi         giggi                 V/i
# 10                       ŋeš           ŋeš                   N
# 11                     giggi         giggi                 V/i
# 12               {ŋeš}ŋeštin        ŋeštin                   N
# 13          {ŋeš}ŋeštin-kir₄    ŋeštinkira                   N
# 14         {ŋeš}ŋeštin-ka₅-a    ŋeštinkaʾa                   N
# 15      {ŋeš}ŋeštin-gurum-ma  ŋeštinguruma                   N
# 16                 {ŋeš}peš₃           peš                   N
# 17               {ŋeš}hašhur        hašhur                   N
# 18               {ŋeš}hašhur        hašhur                   N
# 19                       kur           kur  -ra=r.a          N
# 20              {ŋeš}še-dug₃         šedug                   N
# 21                {ŋeš}še-nu          šenu                   N
# 22                {ŋeš}še-še          šeše                   N
# 23                {ŋeš}šinig         šinig                   N
# 24                {ŋeš}šinig         šinig                   N
# 25                      dili          dili                 V/i
# 26                {ŋeš}šinig         šinig                   N
# 27                       kur           kur  -ra=r.a          N
# 28    {ŋeš}šarₓ(NE)-ša₄-bid₃      šaršabid                   N
# 29                  {ŋeš}mes           mes                   N
# ...                      ...           ...      ...   ...  ...
# 8516
# 8517
# 8518
# 8519
# 8520
# 8521
# 8522
# 8523
# 8524            {ŋeš}dib-dib        dibdib                   N
# 8525
# 8526
# 8527
# 8528
# 8529
# 8530
# 8531
# 8532
# 8533
# 8534
# 8535
# 8536
# 8537
# 8538
# 8539
# 8540
# 8541
# 8542                               napharu                   N
# 8543
# 8544                                  šūši                  NU
# 8545
#
#                         form  \
# 0              {ŋeš}taškarin
# 1                   {ŋeš}esi
# 2                  {ŋeš}nu₁₁
# 3             {ŋeš}ha-lu-ub₂
# 4              {ŋeš}šag₄-kal
# 5                   ŋeš-kin₂
# 6                   ŋeš-kin₂
# 7                     babbar
# 8                   ŋeš-kin₂
# 9                      giggi
# 10                       ŋeš
# 11                     giggi
# 12               {ŋeš}ŋeštin
# 13          {ŋeš}ŋeštin-kir₄
# 14         {ŋeš}ŋeštin-ka₅-a
# 15        {ŋeš}ŋeštin-GAM-ma
# 16                 {ŋeš}peš₃
# 17               {ŋeš}hašhur
# 18               {ŋeš}hašhur
# 19                    kur-ra
# 20              {ŋeš}še-dug₃
# 21                {ŋeš}še-nu
# 22                {ŋeš}še-še
# 23                {ŋeš}šinig
# 24                {ŋeš}šinig
# 25                      dili
# 26                {ŋeš}šinig
# 27                    kur-ra
# 28    {ŋeš}šarₓ(NE)-ša₄-bid₃
# 29                  {ŋeš}mes
# ...                      ...
# 8516             {ŋeš}eš-bar
# 8517                       x
# 8518                  {ŋeš}x
# 8519                       x
# 8520              {ŋeš}GAR-x
# 8521                       x
# 8522              {ŋeš}AMA-x
# 8523                       x
# 8524            {ŋeš}dib-dib
# 8525                       x
# 8526             {ŋeš}kar₂-x
# 8527                       x
# 8528              {ŋeš}saŋ-x
# 8529                       x
# 8530                  {ŋeš}x
# 8531                       x
# 8532                {ŋeš}a-x
# 8533                       x
# 8534             {ŋeš}KA-x-x
# 8535                       x
# 8536                  {ŋeš}x
# 8537                       x
# 8538                       x
# 8539                me-e-x-x
# 8540                     x-x
# 8541                li-i-rum
# 8542                ŠU.NIGIN
# 8543                       2
# 8544                   šu-ši
# 8545                      28
#
#                                                     gdl          gw  \
# 0     [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...     boxwood
# 1     [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...        tree
# 2     [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...        tree
# 3     [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...        tree
# 4     [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...        tree
# 5     [{'v': 'ŋeš', 'id': 'Q000039.6.1.0', 'delim': ...        tree
# 6     [{'v': 'ŋeš', 'id': 'Q000039.7.1.0', 'delim': ...        tree
# 7              [{'v': 'babbar', 'id': 'Q000039.7.2.0'}]       white
# 8     [{'v': 'ŋeš', 'id': 'Q000039.8.1.0', 'delim': ...        tree
# 9               [{'v': 'giggi', 'id': 'Q000039.8.2.0'}]       black
# 10                [{'v': 'ŋeš', 'id': 'Q000039.9.1.0'}]        tree
# 11              [{'v': 'giggi', 'id': 'Q000039.9.2.0'}]       black
# 12    [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...        vine
# 13    [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...       berry
# 14    [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...       grape
# 15    [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...       ~vine
# 16    [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...         fig
# 17    [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...       apple
# 18    [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...       apple
# 19    [{'v': 'kur', 'id': 'Q000039.16.2.0', 'delim':...    mountain
# 20    [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...        tree
# 21    [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...        tree
# 22    [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...        tree
# 23    [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...    tamarisk
# 24    [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...    tamarisk
# 25              [{'v': 'dili', 'id': 'Q000039.21.2.0'}]      single
# 26    [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...    tamarisk
# 27    [{'v': 'kur', 'id': 'Q000039.22.2.0', 'delim':...    mountain
# 28    [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...        tree
# 29    [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...        tree
# ...                                                 ...         ...
# 8516  [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...
# 8517  [{'x': 'ellipsis', 'id': 'P492330.27.2.0', 'br...
# 8518  [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...
# 8519  [{'x': 'ellipsis', 'id': 'P492330.31.2.0', 'br...
# 8520  [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...
# 8521  [{'x': 'ellipsis', 'id': 'P492330.32.2.0', 'br...
# 8522  [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...
# 8523  [{'x': 'ellipsis', 'id': 'P492330.33.2.0', 'br...
# 8524  [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...  waterclock
# 8525  [{'x': 'ellipsis', 'id': 'P492330.34.2.0', 'br...
# 8526  [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...
# 8527  [{'x': 'ellipsis', 'id': 'P492330.35.2.0', 'br...
# 8528  [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...
# 8529  [{'x': 'ellipsis', 'id': 'P492330.36.2.0', 'br...
# 8530  [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...
# 8531  [{'x': 'ellipsis', 'id': 'P492330.37.2.0', 'br...
# 8532  [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...
# 8533  [{'x': 'ellipsis', 'id': 'P492330.38.2.0', 'br...
# 8534  [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...
# 8535  [{'x': 'ellipsis', 'id': 'P492330.39.2.0', 'br...
# 8536  [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...
# 8537  [{'x': 'ellipsis', 'id': 'P492330.40.2.0', 'br...
# 8538  [{'x': 'ellipsis', 'id': 'P492330.43.1.0', 'br...
# 8539  [{'v': 'me', 'id': 'P492330.43.2.0', 'break': ...
# 8540  [{'x': 'ellipsis', 'id': 'P492330.44.1.0', 'br...
# 8541  [{'v': 'li', 'id': 'P492330.44.2.0', 'delim': ...
# 8542  [{'gg': 'logo', 'gdl_type': 'logo', 'group': [...       total
# 8543  [{'n': 'n', 'sexified': '2(diš)', 'form': '2',...
# 8544  [{'v': 'šu', 'id': 'P492330.46.3.0', 'delim': ...       sixty
# 8545  [{'n': 'n', 'sexified': '2(u) 8(diš)', 'form':...
#
#               lang morph    norm         norm0  pos  \
# 0              sux     ~              taškarin    N
# 1              sux     ~                   esi    N
# 2              sux     ~                 ŋešnu    N
# 3              sux     ~                 halub    N
# 4              sux     ~                šagkal    N
# 5              sux     ~               ŋešgana    N
# 6              sux     ~               ŋešgana    N
# 7              sux     ~                babbar  V/i
# 8              sux     ~               ŋešgana    N
# 9              sux     ~                 giggi  V/i
# 10             sux     ~                   ŋeš    N
# 11             sux     ~                 giggi  V/i
# 12             sux     ~                ŋeštin    N
# 13             sux     ~            ŋeštinkira    N
# 14             sux     ~            ŋeštinkaʾa    N
# 15             sux     ~          ŋeštinguruma    N
# 16             sux     ~                   peš    N
# 17             sux     ~                hašhur    N
# 18             sux     ~                hašhur    N
# 19             sux  ~,ak                kur,ak    N
# 20             sux     ~                 šedug    N
# 21             sux     ~                  šenu    N
# 22             sux     ~                  šeše    N
# 23             sux     ~                 šinig    N
# 24             sux     ~                 šinig    N
# 25             sux     ~                  dili  V/i
# 26             sux     ~                 šinig    N
# 27             sux  ~,ak                kur,ak    N
# 28             sux     ~              šaršabid    N
# 29             sux     ~                   mes    N
# ...            ...   ...     ...           ...  ...
# 8516           sux                                X
# 8517  akk-x-oldbab                                u
# 8518           sux                                u
# 8519  akk-x-oldbab                                u
# 8520           sux                                u
# 8521  akk-x-oldbab                                u
# 8522           sux                                u
# 8523  akk-x-oldbab                                u
# 8524           sux     ~                dibdib    N
# 8525  akk-x-oldbab                                u
# 8526           sux                                u
# 8527  akk-x-oldbab                                u
# 8528           sux                                u
# 8529  akk-x-oldbab                                u
# 8530           sux                                u
# 8531  akk-x-oldbab                                u
# 8532           sux                                u
# 8533  akk-x-oldbab                                u
# 8534           sux                                u
# 8535  akk-x-oldbab                                u
# 8536           sux                                u
# 8537  akk-x-oldbab                                u
# 8538           sux                                u
# 8539  akk-x-oldbab                                u
# 8540           sux                                u
# 8541  akk-x-oldbab                                X
# 8542  akk-x-oldbab        naphar                  N
# 8543  akk-x-oldbab                                n
# 8544  akk-x-oldbab          šūši                 NU
# 8545  akk-x-oldbab                                n
#
#                              sense         textid                 lemma
# 0                box tree, boxwood  dcclt/Q000039    taškarin[boxwood]N
# 1                            ebony  dcclt/Q000039            esi[tree]N
# 2                             tree  dcclt/Q000039          ŋešnu[tree]N
# 3                             tree  dcclt/Q000039          halub[tree]N
# 4                             tree  dcclt/Q000039         šagkal[tree]N
# 5                             tree  dcclt/Q000039        ŋešgana[tree]N
# 6                             tree  dcclt/Q000039        ŋešgana[tree]N
# 7                    (to be) white  dcclt/Q000039      babbar[white]V/i
# 8                             tree  dcclt/Q000039        ŋešgana[tree]N
# 9                    (to be) black  dcclt/Q000039       giggi[black]V/i
# 10                            tree  dcclt/Q000039            ŋeš[tree]N
# 11                   (to be) black  dcclt/Q000039       giggi[black]V/i
# 12                            vine  dcclt/Q000039         ŋeštin[vine]N
# 13                           berry  dcclt/Q000039    ŋeštinkira[berry]N
# 14                         a grape  dcclt/Q000039    ŋeštinkaʾa[grape]N
# 15                           ~vine  dcclt/Q000039  ŋeštinguruma[~vine]N
# 16                             fig  dcclt/Q000039             peš[fig]N
# 17                    apple (tree)  dcclt/Q000039        hašhur[apple]N
# 18                    apple (tree)  dcclt/Q000039        hašhur[apple]N
# 19                        mountain  dcclt/Q000039        kur[mountain]N
# 20                          a tree  dcclt/Q000039          šedug[tree]N
# 21                            tree  dcclt/Q000039           šenu[tree]N
# 22                          a tree  dcclt/Q000039           šeše[tree]N
# 23                        tamarisk  dcclt/Q000039      šinig[tamarisk]N
# 24                        tamarisk  dcclt/Q000039      šinig[tamarisk]N
# 25    (to be) single, unique, sole  dcclt/Q000039       dili[single]V/i
# 26                        tamarisk  dcclt/Q000039      šinig[tamarisk]N
# 27                        mountain  dcclt/Q000039        kur[mountain]N
# 28                            tree  dcclt/Q000039       šaršabid[tree]N
# 29                          a tree  dcclt/Q000039            mes[tree]N
# ...                            ...            ...                   ...
# 8516                                dcclt/P492330     {ŋeš}eš-bar[NA]NA
# 8517                                dcclt/P492330               x[NA]NA
# 8518                                dcclt/P492330          {ŋeš}x[NA]NA
# 8519                                dcclt/P492330               x[NA]NA
# 8520                                dcclt/P492330      {ŋeš}GAR-x[NA]NA
# 8521                                dcclt/P492330               x[NA]NA
# 8522                                dcclt/P492330      {ŋeš}AMA-x[NA]NA
# 8523                                dcclt/P492330               x[NA]NA
# 8524                    waterclock  dcclt/P492330   dibdib[waterclock]N
# 8525                                dcclt/P492330               x[NA]NA
# 8526                                dcclt/P492330     {ŋeš}kar₂-x[NA]NA
# 8527                                dcclt/P492330               x[NA]NA
# 8528                                dcclt/P492330      {ŋeš}saŋ-x[NA]NA
# 8529                                dcclt/P492330               x[NA]NA
# 8530                                dcclt/P492330          {ŋeš}x[NA]NA
# 8531                                dcclt/P492330               x[NA]NA
# 8532                                dcclt/P492330        {ŋeš}a-x[NA]NA
# 8533                                dcclt/P492330               x[NA]NA
# 8534                                dcclt/P492330     {ŋeš}KA-x-x[NA]NA
# 8535                                dcclt/P492330               x[NA]NA
# 8536                                dcclt/P492330          {ŋeš}x[NA]NA
# 8537                                dcclt/P492330               x[NA]NA
# 8538                                dcclt/P492330               x[NA]NA
# 8539                                dcclt/P492330        me-e-x-x[NA]NA
# 8540                                dcclt/P492330             x-x[NA]NA
# 8541                                dcclt/P492330        li-i-rum[NA]NA
# 8542                         total  dcclt/P492330       napharu[total]N
# 8543                                dcclt/P492330               2[NA]NA
# 8544                         sixty  dcclt/P492330         šūši[sixty]NU
# 8545                                dcclt/P492330              28[NA]NA
#
# [8546 rows x 16 columns]

# %% [markdown]
# ## 3.3 Group by Textid
# Get all the lemmas that belong to a single text in one row (one row = one document). The `agg()` (aggregate) function, which works on the result of a `groupby()` process aggregates columns of the original dataframe. The function takes a dictionary in which the keys are column names and the values are functions to be used in the aggregation process. The example below has only one such function (`' '.join` will join all entries in the colum `lemma` with a space in between); one may specify (the same or different) functions for different columns, for instance:
# > word_df = word_df.groupby("textid").agg({"lemma": ' '.join, "base": ' '.join})

# %%
word_df = word_df.groupby("textid").agg({"lemma": ' '.join})
word_df
# Out:
#                                                            lemma
# textid
# dcclt/P117395             ŋešed[key]N pakud[~tree]N raba[clamp]N
# dcclt/P117404  ig[door]N eren[cedar]N ig[door]N dib[board]N i...
# dcclt/P128345  garig[comb]N siki[hair]N garig[comb]N siki-sik...
# dcclt/P224980  gigir[chariot]N e[house]N gigir[chariot]N e[ho...
# dcclt/P224986  guza[chair]N anše[equid]N guza[chair]N kaskal[...
# dcclt/P224994     {ŋeš}x-x[NA]NA {ŋeš}SI-x[NA]NA {ŋeš}šu-x[NA]NA
# dcclt/P224996  guza[chair]N guza[chair]N gid[long]V/i guza[ch...
# dcclt/P225006  ig[door]N suku[pole]N ig[door]N zara[pivot]N i...
# dcclt/P225023  {ŋeš}x[NA]NA emerah[jug]N x[NA]NA emerah[jug]N...
# dcclt/P225033           targul[pole]N targul[pole]N garig[comb]N
# dcclt/P225059  emerah[jug]N emerah[jug]N x[NA]NA emerah[jug]N...
# dcclt/P225062      allanum[oak]N zumdianum[tree]N tiʾarum[tree]N
# dcclt/P225065                ig[door]N x[NA]NA ig[door]N x[NA]NA
# dcclt/P225086     usuh[tree]N niŋ[thing]N x[NA]NA kišig[acacia]N
# dcclt/P225109  margida[cart]N KI.KAL[bottom]N margida[cart]N ...
# dcclt/P225126                             ma[ship]N {ŋeš}x[NA]NA
# dcclt/P225132  e[house]N ma[ship]N x[NA]NA si[horn]N ma[ship]...
# dcclt/P229426  la[hang]V/t la-a[NA]NA LA₂[NA]NA usur[suspend]...
# dcclt/P230069  guza[chair]N zag[side]N us[follow]V/t guza[cha...
# dcclt/P235262  ŋeštinkira[berry]N ŋeštin[vine]N kaʾa[fox]N ŋe...
# dcclt/P247543  ma[ship]N u[ten]NU gur[unit]N ma[ship]N x[NA]N...
# dcclt/P247864  eren[cedar]N šurmen[cypress]N zabalum[juniper]...
# dcclt/P249383  e[house]N gigir[chariot]N e[house]N usan[whip]...
# dcclt/P250361  saŋ[head]N ŋešnud[bed]N {ŋeš}x[NA]NA zid[right...
# dcclt/P250362  ba[tool]N šab[cut]V/t ba[tool]N še[barley]N {ŋ...
# dcclt/P250363  ig[door]N miriza[plank]N ig[door]N šu-ur₂-tum[...
# dcclt/P250364  gigir[chariot]N e[house]N gigir[chariot]N e[ho...
# dcclt/P250368  mud[stump]N ŋešnimbar[palm]N mud[stump]N gaz[k...
# dcclt/P250369  peš[frond]N ŋešnimbar[palm]N pešmur[~palm]N ŋe...
# dcclt/P250370  ad[bush]N kišig[acacia]N kišighar[accacia]N ki...
# ...                                                          ...
# dcclt/P369718  šudul[yoke]N margida[cart]N gag[nail]N šudul[y...
# dcclt/P370399  x[NA]NA ŋešnimbar[palm]N x[NA]NA ŋešnimbar[pal...
# dcclt/P382665          šenu[tree]N šedug[tree]N šinig[tamarisk]N
# dcclt/P388265  mes[tree]N babbar[white]V/i mes[tree]N giggi[b...
# dcclt/P388330  hašhur[apple]N hašhur[apple]N kur[mountain]N h...
# dcclt/P388563  dubla[tower]N apin[plow]N anzam[vessel]N apin[...
# dcclt/P389437  ŋeš[tree]N u[ten]NU giŋ[unit]N ŋeš[tree]N ya[f...
# dcclt/P389511  ŋešaʾabak[tree]N ŋešaʾabak[tree]N Meluhha[1]GN...
# dcclt/P423759  gag[nail]N sala[~plow]N apin[plow]N nig[~plow]...
# dcclt/P432448  taškarin[boxwood]N esi[tree]N ŋešnu[tree]N hal...
# dcclt/P433291                  lam[tree]N eš[tree]N lamgal[nut]N
# dcclt/P447996  x-tu[NA]NA x-tu[NA]NA lamgal[nut]N lamtur[nut]...
# dcclt/P459216  taškarin[boxwood]N esi[tree]N ŋešnu[tree]N ŋeš...
# dcclt/P459217  ŋeštin[vine]N ŋeštinkira[berry]N {ŋeš}ŋeštin-H...
# dcclt/P459218  ig[door]N sah[mat]N ig[door]N maštab[twin]N ig...
# dcclt/P459219  {ŋeš}GIR₂[NA]NA x[NA]NA umbin[wheel]N x[NA]NA ...
# dcclt/P459220  ig[door]N ig[door]N gal[big]V/i ig[door]N i[oil]N
# dcclt/P459221  dilim[spoon]N dilim[spoon]N gal[big]V/i dilimb...
# dcclt/P459222  damga[~plow]N apin[plow]N ŋušur[harrow]N ŋušur...
# dcclt/P459223  ušub[brick-mold]N ab[window]N ušub[brick-mold]...
# dcclt/P459224  ŋešdi[rung]N ŋešnud[bed]N saŋ[head]N ŋešnud[be...
# dcclt/P459225  {ŋeš}x[NA]NA pana[bow]N gagsisa[arrow]N e[hous...
# dcclt/P459226  {ŋeš}x[NA]NA halub[tree]N šagkal[tree]N ŋešgan...
# dcclt/P459227  x-KA[NA]NA x-lu₂[NA]NA x-AGA[NA]NA gagsila[har...
# dcclt/P459228           lamgal[nut]N lamtur[nut]N šerhazum[nut]N
# dcclt/P459230  ma[ship]N Ninurta[1]DN ma[ship]N sig[weak]V/i ...
# dcclt/P459231  {ŋeš}x-x[NA]NA gigir[chariot]N ŋirigub[footsto...
# dcclt/P459784  {ŋeš}x[NA]NA šenu[tree]N šedug[tree]N šeše[tre...
# dcclt/P492330  saŋ[head]N GU-bu-ul-lum[NA]NA saŋkul[bolt]N la...
# dcclt/Q000039  taškarin[boxwood]N esi[tree]N ŋešnu[tree]N hal...
#
# [106 rows x 1 columns]

# %% [markdown]
# ## 4 Save Results in CSV file
# The `.csv` file has the same name as the list of textid's that was used at the beginning of this notebook. In most computers, `csv` files open automatically in Excel. This spread sheet program does not deal well with `utf-8` encoding. If you intend to use the file in Excel, change `encoding ='utf-8'` to `encoding='utf-16'`. For usage in computational text analysis applications `utf-8` is usually preferred.

# %%
savefile =  filename[:-3] + 'csv'
with open('output/' + savefile, 'w') as w:
    word_df.to_csv(w, encoding = 'utf-8')
