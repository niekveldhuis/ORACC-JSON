# %% [markdown]
# # Retrieve Catalog Data from `catalogue.json`
#
# The file `catalogue.json` contains all the catalog data for an [ORACC](http://oracc.org) project (for general information, see the [Oracc Open Data](http://oracc.org/doc/opendata) page). The `zip` that contains all JSON files of a particular project can be found at `http://build-oracc.museum.upenn.edu/json/[PROJECT].zip`. In the URL replace [PROJECT] with your project or sub-project name (e.g. `dcclt` or `cams/gkab`).
#
# The main node in a `catalogue.json` file is called `members`. This node contains the information of all the fields and all the entries in the project catalog.

# %%
import pandas as pd
import zipfile
import json
import requests
import errno
import os
import tqdm

# %% [markdown]
# ## 0 Create Directories, if Necessary
# The two directories needed for this script are `jsonzip` and `output`. If they do not exist they are created, else: do nothing.
#
# For the code, see [Stack Overflow](http://stackoverflow.com/questions/18973418/os-mkdirpath-returns-oserror-when-directory-does-not-exist).

# %%
directories = ['jsonzip', 'output']
for d in directories:
    try:
        os.mkdir(d)
    except OSError as exc:
        if exc.errno !=errno.EEXIST:
            raise
        pass

# %% [markdown]
# ## 1.1 Input Project Name
# We will download and manipulate one catalog file at a time. Different [ORACC](http://oracc.org) projects use different fields in their catalogs, the catalogs are not mutually compatible.
#
# Provide a project name. Note that subprojects must be processed separately, they are not included in the main project. A subproject is named `[PROJECT]/[SUBPROJECT]`, for instance `saao/saa01`.

# %%
projects = input('Project(s): ').lower().strip() # lowercase user input and strip accidental spaces
# Out:
# Project(s): fout, blms, saao/saa17

# %% [markdown]
# ## 1.2 Split the List of Projects
# Split the list of projects and create a list of project names.

# %%
p = projects.split(',')               # split at each comma and make a list called `p`
p = [x.strip() for x in p]        # strip spaces left and right of each entry in `p`

# %% [markdown]
# ## 1.2 Download the ZIP files
# Download all the `json` files from `http://build-oracc.museum.upenn.edu/json/`. The file is called `[PROJECT].zip` (for instance: `dcclt.zip`). For subprojects the file is called `[PROJECT-SUBPROJECT].zip` (for instance `cams-gkab.zip`).
#
# For larger projects (such as [DCCLT](http://oracc.org/dcclt)) the `zip` file may be 25Mb or more. Downloading may take some time and it may be necessary to chunk the downloading process. The `iter_content()` function in the `requests` library takes care of that. For the chunking code see [this page](https://www.smallsurething.com/how-to-read-a-file-properly-in-python/).
#
# If you have downloaded the files by hand (and put them in the `jsonzip` directory) you may skip this cell and jump directly to section ...

# %%
non_existent = []
CHUNK = 16 * 1024
for project in tqdm.tqdm(p):
    project = project.replace('/', '-')
    url = "http://build-oracc.museum.upenn.edu/json/" + project + ".zip"
    file = 'jsonzip/' + project + '.zip'
    r = requests.get(url)
    if r.status_code == 200:
        print("Downloading " + url + " saving as " + file)
        with open(file, 'wb') as f:
            for c in r.iter_content(chunk_size=CHUNK):
                f.write(c)
    else:
        print(url + " does not exist.")
        non_existent.append(project)
p = [i for i in p if i not in non_existent] # remove non-existing project names from list
# Out:
#   0%|                                                    | 0/3 [00:00<?, ?it/s]
# http://build-oracc.museum.upenn.edu/json/fout.zip does not exist.
#  33%|██████████████▋                             | 1/3 [00:00<00:00,  2.95it/s]
# Downloading http://build-oracc.museum.upenn.edu/json/blms.zip saving as jsonzip/blms.zip
#  67%|█████████████████████████████▎              | 2/3 [00:05<00:01,  1.70s/it]
# Downloading http://build-oracc.museum.upenn.edu/json/saao-saa17.zip saving as jsonzip/saao-saa17.zip
# 100%|████████████████████████████████████████████| 3/3 [00:07<00:00,  2.01s/it]

# %% [markdown]
# ## 2 Extract Catalogue Data from `JSON` files
# The code in this cell will iterate through the list of projects entered above (1.1). For each project the `JSON` zip file, named `[PROJECT].zip` is located in the directory `jsonzip`. Each of these `zip` files includes a file called `catalogue.json`. This file is extracted and read with the command `json.loads()`, which reads the json data and transforms it into a JSON object - a sequence of names and values.
#
# The JSON object is transformed into a Pandas Dataframe. The dataframe needs to be transposed (`.T`), so that the P, Q, and X numbers become indexes or row names (rather than column names), and each column represents a field in the catalog.  The individual dataframes (one for each project requested) are concatenated. Since individual [ORACC](http://oracc.org) project catalogs may have different fields, the dataframes may have different column names. By default Pandas concatenation uses an `outer join` so that all column names of all the catalogs are preserved.

# %%
df = pd.DataFrame() # create an empty dataframe
for project in p:
    file = "jsonzip/" + project.replace("/", "-") + ".zip"
    try:
        z = zipfile.ZipFile(file)       # create a Zipfile object
    except:
        print(file + " does not exist or is not a proper ZIP file")
        continue
    try:
        st = z.read(project + '/catalogue.json').decode('utf-8')  #read and decode the catalogue.json file of one project
                                                                # the result is a string object
    except:
        print(project + '/catalogue.json' + ' is not available or not complete')
        continue
    cat = json.loads(st)
    cat = cat['members']  # select the 'members' node 
    for item in cat.values():
        item["project"] = project # add project name as separate field
    cat_df = pd.DataFrame(cat).T
    df = pd.concat([df, cat_df])

# %% [markdown]
# ## Create Dataframe
#  Creating a Dataframe is not necessary, one may also manipulate the dictionary directly, but for demonstration purposes the Dataframe is a handy format. In manipulating the dictionary directly it is important to keep in mind that not all catalog fields have data for all entries, which means that not all dictionary keys are available for each P, Q, or X number.
#
# The function `fillna('')` will put a blank (instead of `NaN`) in all fields that have no entry.
#
# Example code for slicing the dictionary to select all entries that have `provenience = 'Ur'`:
# > `urcat = {key:value for key, value in d.items() if 'provenience' in d[key] and d[key]['provenience'] == 'Ur'}

# %%
df = df.fillna('')
df
# Out:
#                                               accession_no  \
# P223387
# P223392
# P223434
# P223478
# P231196
# P236940                                   1880-07-19, 0160
# P237029                                   1881-02-04, 0440
# P237069                                            K 21079
# P237082                                    1881-07-27, 075
# P237100                                   1881-07-27, 0261
# P237104                                   1881-07-27, 0282
# P237110                                   1882-03-23, 0007
# P237115                                   1882-03-23, 0059
# P237118                                   1882-03-23, 0088
# P237217                                   1882-05-22, 0565
# P237353                                  1883-01-18, 00490
# P237354                                  1883-01-18, 00492
# P237460                        K 09008 + 1883-01-18, 00141
# P237530  K 08689 + Ki 1904-10-09, 0002 + Ki 1904-10-09,...
# P237586                                Th 1905-04-09, 0091
# P237587                                Th 1905-04-09, 0093
# P237632                                Th 1905-04-09, 0245
# P237717                                             DT 038
# P237742                                             DT 255
# P237747                                             DT 297
# P237751  K 02542 + K 02772 + K 02991 + K 03300 + K 0603...
# P237782  K 00111 + K 02754 + K 05227 + K 05295 + K 0752...
# P237792                                  K 00157 + K 02788
# P238069                                           K 01401b
# P238170  K 02437 + K 05177 + K 08212 + K 09096 + K 0944...
# ...                                                    ...
# P239428
# P239449
# P239463
# P239466
# P239468
# P239878
# P239973
# P240131
# P240133
# P240148
# P240149
# P240177
# P240182
# P240184
# P240213
# P240217
# P240228
# P240255
# P240261
# P240284
# P240285
# P240308
# P240311
# P240360
# P240426
# P240432
# P334701
# P334712
# P334717
# P336156
#
#         acquisition_history            ancient_author               ark  \
# P223387
# P223392                                                21198/zz001s7hkd
# P223434
# P223478                                                21198/zz001s91nk
# P231196                                                21198/zz001rcjtw
# P236940
# P237029
# P237069
# P237082
# P237100
# P237104
# P237110
# P237115
# P237118
# P237217
# P237353
# P237354
# P237460
# P237530
# P237586
# P237587
# P237632
# P237717                                                21198/zz001sfsdc
# P237742                                                21198/zz001t36r8
# P237747
# P237751
# P237782
# P237792
# P238069
# P238170
# ...                     ...                       ...               ...
# P239428                               Nabu-šuma-lišir
# P239449                                  (unassigned)
# P239463                                  Qišti-Marduk
# P239466                                  (unassigned)
# P239468                                Aqar-Bel-lumur
# P239878                                   [...]-eššir
# P239973                                  (unassigned)
# P240131                                  (unassigned)
# P240133                               Nabu-šar-ahhešu
# P240148                                    Abi-yaqiya
# P240149                               Nabu-ahhe-lumur
# P240177                                     Bel-iqiša
# P240182                                      Bel-ibni
# P240184                                      Nabu-ili
# P240213                               Ana-Nabu-taklak
# P240217                                      Bel-ibni
# P240228                                  (unassigned)
# P240255                                        Marduk
# P240261                                 Ina-teši-eṭir
# P240284                                Aqar-Bel-lumur
# P240285                      The šandabakku of Nippur
# P240308                                  (unassigned)
# P240311                                     Bel-iqiša
# P240360                               Nabu-šumu-lišir
# P240426                                         Lanše
# P240432                                  Nabu-ušallim
# P334701                                  Nabu-ušallim
# P334712                                  (unassigned)
# P334717                                      Naṣib-il
# P336156                                  (unassigned)
#
#         ark_number atf_source atf_up                    author  \
# P223387                               van Dijk, Johannes J. A.
# P223392                               van Dijk, Johannes J. A.
# P223434                               van Dijk, Johannes J. A.
# P223478                               van Dijk, Johannes J. A.
# P231196
# P236940
# P237029                                     Geller, Markham J.
# P237069
# P237082                                     Geller, Markham J.
# P237100
# P237104
# P237110
# P237115
# P237118                                     Geller, Markham J.
# P237217
# P237353
# P237354
# P237460                                    Lambert, Wilfred G.
# P237530                                     Geller, Markham J.
# P237586
# P237587                                     Meek, Theophile J.
# P237632                                     Meek, Theophile J.
# P237717                                      Schramm, Wolfgang
# P237742                                      Schramm, Wolfgang
# P237747                                     Geller, Markham J.
# P237751                                    Langdon, Stephen H.
# P237782                           no     Thompson, R. Campbell
# P237792                                       Caplice, Richard
# P238069                                          Borger, Rykle
# P238170                                          Borger, Rykle
# ...            ...        ...    ...                       ...
# P239428
# P239449
# P239463
# P239466
# P239468
# P239878
# P239973
# P240131
# P240133
# P240148
# P240149
# P240177
# P240182
# P240184
# P240213
# P240217
# P240228
# P240255
# P240261
# P240284
# P240285
# P240308
# P240311
# P240360
# P240426
# P240432
# P334701
# P334712
# P334717
# P336156
#
#         bibliography__book_title bibliography__id_biblio   ...     \
# P223387                                                    ...
# P223392                                                    ...
# P223434                                                    ...
# P223478                                                    ...
# P231196                                                    ...
# P236940                                                    ...
# P237029                                                    ...
# P237069                                                    ...
# P237082                                                    ...
# P237100                                                    ...
# P237104                                                    ...
# P237110                                                    ...
# P237115                                                    ...
# P237118                                                    ...
# P237217                                                    ...
# P237353                                                    ...
# P237354                                                    ...
# P237460                                                    ...
# P237530                                                    ...
# P237586                                                    ...
# P237587                                                    ...
# P237632                                                    ...
# P237717                                                    ...
# P237742                                                    ...
# P237747                                                    ...
# P237751                                                    ...
# P237782                                                    ...
# P237792                                                    ...
# P238069                                                    ...
# P238170                                                    ...
# ...                          ...                     ...   ...
# P239428                                                    ...
# P239449                                                    ...
# P239463                                                    ...
# P239466                                                    ...
# P239468                                                    ...
# P239878                                                    ...
# P239973                                                    ...
# P240131                                                    ...
# P240133                                                    ...
# P240148                                                    ...
# P240149                                                    ...
# P240177                                                    ...
# P240182                                                    ...
# P240184                                                    ...
# P240213                                                    ...
# P240217                                                    ...
# P240228                                                    ...
# P240255                                                    ...
# P240261                                                    ...
# P240284                                                    ...
# P240285                                                    ...
# P240308                                                    ...
# P240311                                                    ...
# P240360                                                    ...
# P240426                                                    ...
# P240432                                                    ...
# P334701                                                    ...
# P334712                                                    ...
# P334717                                                    ...
# P336156                                                    ...
#
#                                                      title trans translit_ed  \
# P223387
# P223392                                                     [en]
# P223434
# P223478                                                     [en]
# P231196
# P236940
# P237029
# P237069
# P237082
# P237100
# P237104
# P237110
# P237115
# P237118
# P237217
# P237353
# P237354
# P237460
# P237530
# P237586
# P237587
# P237632
# P237717                                                     [en]
# P237742                                                     [en]
# P237747
# P237751
# P237782
# P237792
# P238069
# P238170
# ...                                                    ...   ...         ...
# P239428                                 Report on a Temple  [en]
# P239449               Fragment Mentioning Merodach-Baladan  [en]
# P239463                                         (no title)  [en]
# P239466                    Fragment Mentioning Nabu-taklak  [en]
# P239468  The Wife of the Son of Yakin is Dead; King has...  [en]
# P239878               Fragment Mentioning Merodach-Baladan  [en]
# P239973                                         (no title)  [en]
# P240131                 Pardoning the Offences of Borsippa  [en]
# P240133           Keeping Guard in Borsippa, Rebels Killed  [en]
# P240148                           Natannu’s Escape to Elam  [en]
# P240149       ‘Golden Heaven’ Removed from Esaggil; Famine  [en]
# P240177                                Carrying Out a Task  [en]
# P240182                         Report on Merodach-Baladan  [en]
# P240184                                  The Throne of Bel  [en]
# P240213                        Partial Duplicate of No. 64  [en]
# P240217    Report on Merodach-Baladan; Troops to Bab-bitqa  [en]
# P240228   Fragment Mentioning Esaggil and Merodach-Baladan  [en]
# P240255                                  Presents to Ezida  [en]
# P240261                 Kissing the King’s Feet in Babylon  [en]
# P240284                Affairs of Hanana and Belet-taddina  [en]
# P240285                                         (no title)  [en]
# P240308               Fragment Mentioning Merodach-Baladan  [en]
# P240311        Please Return my Sons and People from Calah  [en]
# P240360                         A Royal Eunuch Should Come  [en]
# P240426                                         (no title)  [en]
# P240432              Messengers of Son of Zeriya in Kissik  [en]
# P334701        Puqudeans in the Marshes Should be Deported  [en]
# P334712                Aššur-bel-taqqin Visited in Babylon  [en]
# P334717                     Sending City Lords to the King  [en]
# P336156                                         (no title)  [en]
#
#         uploaded                           uri user  \
# P223387           http://cdli.ucla.edu/P223387
# P223392           http://cdli.ucla.edu/P223392
# P223434           http://cdli.ucla.edu/P223434
# P223478           http://cdli.ucla.edu/P223478
# P231196           http://cdli.ucla.edu/P231196
# P236940           http://cdli.ucla.edu/P236940
# P237029           http://cdli.ucla.edu/P237029
# P237069           http://cdli.ucla.edu/P237069
# P237082           http://cdli.ucla.edu/P237082
# P237100           http://cdli.ucla.edu/P237100
# P237104           http://cdli.ucla.edu/P237104
# P237110           http://cdli.ucla.edu/P237110
# P237115           http://cdli.ucla.edu/P237115
# P237118           http://cdli.ucla.edu/P237118
# P237217           http://cdli.ucla.edu/P237217
# P237353           http://cdli.ucla.edu/P237353
# P237354           http://cdli.ucla.edu/P237354
# P237460           http://cdli.ucla.edu/P237460
# P237530           http://cdli.ucla.edu/P237530
# P237586           http://cdli.ucla.edu/P237586
# P237587           http://cdli.ucla.edu/P237587
# P237632           http://cdli.ucla.edu/P237632
# P237717           http://cdli.ucla.edu/P237717
# P237742           http://cdli.ucla.edu/P237742
# P237747           http://cdli.ucla.edu/P237747
# P237751           http://cdli.ucla.edu/P237751
# P237782           http://cdli.ucla.edu/P237782
# P237792           http://cdli.ucla.edu/P237792
# P238069           http://cdli.ucla.edu/P238069
# P238170           http://cdli.ucla.edu/P238170
# ...          ...                           ...  ...
# P239428
# P239449
# P239463
# P239466
# P239468
# P239878
# P239973
# P240131
# P240133
# P240148
# P240149
# P240177
# P240182
# P240184
# P240213
# P240217
# P240228
# P240255
# P240261
# P240284
# P240285
# P240308
# P240311
# P240360
# P240426
# P240432
# P334701
# P334712
# P334717
# P336156
#
#                                                  vol_title  volume width  \
# P223387
# P223392                                                                ?
# P223434
# P223478                                                                ?
# P231196                                                                ?
# P236940
# P237029
# P237069
# P237082
# P237100
# P237104
# P237110
# P237115
# P237118
# P237217
# P237353
# P237354
# P237460
# P237530
# P237586
# P237587
# P237632
# P237717                                                                ?
# P237742                                                                ?
# P237747
# P237751
# P237782
# P237792
# P238069
# P238170
# ...                                                    ...     ...   ...
# P239428  The Neo-Babylonian Correspondence of Sargon an...  SAA 17
# P239449  The Neo-Babylonian Correspondence of Sargon an...  SAA 17
# P239463  The Neo-Babylonian Correspondence of Sargon an...  SAA 17
# P239466  The Neo-Babylonian Correspondence of Sargon an...  SAA 17
# P239468  The Neo-Babylonian Correspondence of Sargon an...  SAA 17
# P239878  The Neo-Babylonian Correspondence of Sargon an...  SAA 17
# P239973  The Neo-Babylonian Correspondence of Sargon an...  SAA 17
# P240131  The Neo-Babylonian Correspondence of Sargon an...  SAA 17
# P240133  The Neo-Babylonian Correspondence of Sargon an...  SAA 17
# P240148  The Neo-Babylonian Correspondence of Sargon an...  SAA 17
# P240149  The Neo-Babylonian Correspondence of Sargon an...  SAA 17
# P240177  The Neo-Babylonian Correspondence of Sargon an...  SAA 17
# P240182  The Neo-Babylonian Correspondence of Sargon an...  SAA 17
# P240184  The Neo-Babylonian Correspondence of Sargon an...  SAA 17
# P240213  The Neo-Babylonian Correspondence of Sargon an...  SAA 17
# P240217  The Neo-Babylonian Correspondence of Sargon an...  SAA 17
# P240228  The Neo-Babylonian Correspondence of Sargon an...  SAA 17
# P240255  The Neo-Babylonian Correspondence of Sargon an...  SAA 17
# P240261  The Neo-Babylonian Correspondence of Sargon an...  SAA 17
# P240284  The Neo-Babylonian Correspondence of Sargon an...  SAA 17
# P240285  The Neo-Babylonian Correspondence of Sargon an...  SAA 17
# P240308  The Neo-Babylonian Correspondence of Sargon an...  SAA 17
# P240311  The Neo-Babylonian Correspondence of Sargon an...  SAA 17
# P240360  The Neo-Babylonian Correspondence of Sargon an...  SAA 17
# P240426  The Neo-Babylonian Correspondence of Sargon an...  SAA 17
# P240432  The Neo-Babylonian Correspondence of Sargon an...  SAA 17
# P334701  The Neo-Babylonian Correspondence of Sargon an...  SAA 17
# P334712  The Neo-Babylonian Correspondence of Sargon an...  SAA 17
# P334717  The Neo-Babylonian Correspondence of Sargon an...  SAA 17
# P336156  The Neo-Babylonian Correspondence of Sargon an...  SAA 17
#
#         xproject
# P223387     CDLI
# P223392     CDLI
# P223434     CDLI
# P223478     CDLI
# P231196     CDLI
# P236940     CDLI
# P237029     CDLI
# P237069     CDLI
# P237082     CDLI
# P237100     CDLI
# P237104     CDLI
# P237110     CDLI
# P237115     CDLI
# P237118     CDLI
# P237217     CDLI
# P237353     CDLI
# P237354     CDLI
# P237460     CDLI
# P237530     CDLI
# P237586     CDLI
# P237587     CDLI
# P237632     CDLI
# P237717     CDLI
# P237742     CDLI
# P237747     CDLI
# P237751     CDLI
# P237782     CDLI
# P237792     CDLI
# P238069     CDLI
# P238170     CDLI
# ...          ...
# P239428
# P239449
# P239463
# P239466
# P239468
# P239878
# P239973
# P240131
# P240133
# P240148
# P240149
# P240177
# P240182
# P240184
# P240213
# P240217
# P240228
# P240255
# P240261
# P240284
# P240285
# P240308
# P240311
# P240360
# P240426
# P240432
# P334701
# P334712
# P334717
# P336156
#
# [1998 rows x 95 columns]

# %% [markdown]
# ## Select Relevant Fields
# [ORACC](http://oracc.org) catalogs may have custom fields, the only fields that are obligatory are `id_text` (the P, Q, or X number that identifies the text, for instance "P243546") and `designation` (the human-readable reference, for instance "VS 17, 012"). In order to find out which fields are available one may list the column names of the DataFrame.
#
# First display all available fields, then select the ones that are relevant for the task at hand.

# %%
df.columns
# Out:
# Index(['accession_no', 'acquisition_history', 'ancient_author', 'ark',
#        'ark_number', 'atf_source', 'atf_up', 'author',
#        'bibliography__book_title', 'bibliography__id_biblio',
#        'bibliography__journal_title', 'bibliography__shortref',
#        'bibliography__volume_number', 'ch_name', 'ch_no', 'ch_num_name',
#        'checked', 'collection', 'collection_copyright',
#        'condition_description', 'credits', 'date_entered', 'date_of_origin',
#        'date_remarks', 'date_updated', 'dates_referenced', 'db_source',
#        'designation', 'display_name', 'editor', 'excavation_no', 'external_id',
#        'findspot_remarks', 'findspot_square', 'funder', 'genre',
#        'google_earth_collection', 'height', 'id', 'id_text', 'id_text_int',
#        'images', 'join_information', 'langs', 'language', 'language_remarks',
#        'last_mod_by', 'last_modified', 'lemmed', 'lineart_up', 'material',
#        'museum_no', 'object_preservation', 'object_remarks', 'object_type',
#        'owner', 'period', 'period_remarks', 'photo_up', 'pleaides_id',
#        'pleiades_coord', 'pleiades_id', 'pr_joins__pages',
#        'primary_publication', 'principal', 'project', 'proof-read',
#        'proof-reader', 'provenience', 'provenience_remarks', 'public',
#        'publication_date', 'publication_history', 'record_id', 'repository',
#        'script', 'script_remarks', 'script_type', 'short_title',
#        'stratigraphic_level', 'subgenre', 'subgenre_remarks', 'supergenre',
#        'text_remarks', 'thickness', 'title', 'trans', 'translit_ed',
#        'uploaded', 'uri', 'user', 'vol_title', 'volume', 'width', 'xproject'],
#       dtype='object')

# %%
df1 = df[['designation', 'period', 'provenience',
        'museum_no', 'project']]
df1
# Out:
#                         designation          period provenience  \
# P223387     TIM 09, 056 (IM 003225)  Old Babylonian       Assur
# P223392     TIM 09, 057 (IM 003263)  Neo-Babylonian   uncertain
# P223434                 TIM 09, 062  Old Babylonian   uncertain
# P223478     TIM 09, 032 (IM 058080)     Hellenistic        Uruk
# P231196                      N 4950  Neo-Babylonian      Nippur
# P236940            1880-07-19, 0160    Neo-Assyrian     Nineveh
# P237029            1881-02-04, 0440    Neo-Assyrian     Nineveh
# P237069                     K 21079    Neo-Assyrian     Nineveh
# P237082             1881-07-27, 075    Neo-Assyrian     Nineveh
# P237100            1881-07-27, 0261    Neo-Assyrian     Nineveh
# P237104            1881-07-27, 0282    Neo-Assyrian     Nineveh
# P237110            1882-03-23, 0007    Neo-Assyrian     Nineveh
# P237115            1882-03-23, 0059    Neo-Assyrian     Nineveh
# P237118            1882-03-23, 0088    Neo-Assyrian     Nineveh
# P237217            1882-05-22, 0565    Neo-Assyrian     Nineveh
# P237353           1883-01-18, 00490    Neo-Assyrian     Nineveh
# P237354           1883-01-18, 00492    Neo-Assyrian     Nineveh
# P237460     Fs. de Liagre Böhl, 278    Neo-Assyrian     Nineveh
# P237530           Fs Lambert 2, 241    Neo-Assyrian     Nineveh
# P237586                   BM 098585    Neo-Assyrian     Nineveh
# P237587          AJSL 35.3, 141-142    Neo-Assyrian      Sippar
# P237632              AJSL 35.3, 142  Neo-Babylonian      Sippar
# P237717  GAAL 2, pl. 04-06 (DT 038)    Neo-Assyrian     Nineveh
# P237742     GAAL 2, pl. 11 (DT 255)    Neo-Assyrian     Nineveh
# P237747                      DT 297    Neo-Assyrian     Nineveh
# P237751                   BE 31, 60    Neo-Assyrian     Nineveh
# P237782     CT 16, 42-49, K 00111 +    Neo-Assyrian     Nineveh
# P237792   OrNS 40, Tab. 3-4 (photo)    Neo-Assyrian     Nineveh
# P238069     BiOr 30, 163-176, pl. 4    Neo-Assyrian     Nineveh
# P238170      BiOr 30, pl. 3 (photo)    Neo-Assyrian     Nineveh
# ...                             ...             ...         ...
# P239428                  SAA 17 037    Neo-Assyrian     Nineveh
# P239449                  SAA 17 196    Neo-Assyrian     Nineveh
# P239463                  SAA 17 041    Neo-Assyrian     Nineveh
# P239466                  SAA 17 197    Neo-Assyrian     Nineveh
# P239468                  SAA 17 112    Neo-Assyrian     Nineveh
# P239878                  SAA 17 138    Neo-Assyrian     Nineveh
# P239973                  SAA 17 207    Neo-Assyrian     Nineveh
# P240131                  SAA 17 083    Neo-Assyrian     Nineveh
# P240133                  SAA 17 075    Neo-Assyrian     Nineveh
# P240148                  SAA 17 149    Neo-Assyrian     Nineveh
# P240149                  SAA 17 008    Neo-Assyrian     Nineveh
# P240177                  SAA 17 026    Neo-Assyrian     Nineveh
# P240182                  SAA 17 055    Neo-Assyrian     Nineveh
# P240184                  SAA 17 160    Neo-Assyrian     Nineveh
# P240213                  SAA 17 065    Neo-Assyrian     Nineveh
# P240217                  SAA 17 056    Neo-Assyrian     Nineveh
# P240228                  SAA 17 199    Neo-Assyrian     Nineveh
# P240255                  SAA 17 077    Neo-Assyrian     Nineveh
# P240261                  SAA 17 033    Neo-Assyrian     Nineveh
# P240284                  SAA 17 114    Neo-Assyrian     Nineveh
# P240285                  SAA 17 091    Neo-Assyrian     Nineveh
# P240308                  SAA 17 198    Neo-Assyrian     Nineveh
# P240311                  SAA 17 029    Neo-Assyrian     Nineveh
# P240360                  SAA 17 123    Neo-Assyrian     Nineveh
# P240426                  SAA 17 100    Neo-Assyrian     Nineveh
# P240432                  SAA 17 143    Neo-Assyrian     Nineveh
# P334701                  SAA 17 142    Neo-Assyrian     Nineveh
# P334712                  SAA 17 169    Neo-Assyrian     Nineveh
# P334717                  SAA 17 162    Neo-Assyrian     Nineveh
# P336156                  SAA 17 180    Neo-Assyrian     Nineveh
#
#                      museum_no     project
# P223387              IM 003225        blms
# P223392              IM 003263        blms
# P223434           IM 021180,01        blms
# P223478              IM 058080        blms
# P231196                 N 4950        blms
# P236940                               blms
# P237029                               blms
# P237069                               blms
# P237082                               blms
# P237100                               blms
# P237104                               blms
# P237110                               blms
# P237115                               blms
# P237118                               blms
# P237217                               blms
# P237353                               blms
# P237354                               blms
# P237460                               blms
# P237530  BM 098973 + BM 099180        blms
# P237586              BM 098585        blms
# P237587              BM 098587        blms
# P237632              BM 098739        blms
# P237717                   BM —        blms
# P237742                   BM —        blms
# P237747                               blms
# P237751                               blms
# P237782                               blms
# P237792                               blms
# P238069                               blms
# P238170                               blms
# ...                        ...         ...
# P239428                K 16133  saao/saa17
# P239449                K 16581  saao/saa17
# P239463                K 16605  saao/saa17
# P239466                K 16610  saao/saa17
# P239468               Sm 2158+  saao/saa17
# P239878                K 19564  saao/saa17
# P239973                K 20570  saao/saa17
# P240131                Rm 0064  saao/saa17
# P240133                Rm 0078  saao/saa17
# P240148                Rm 0215  saao/saa17
# P240149                Rm 0217  saao/saa17
# P240177                Rm 0563  saao/saa17
# P240182                Rm 0925  saao/saa17
# P240184                Rm 0948  saao/saa17
# P240213              Rm 2,0457  saao/saa17
# P240217              Rm 2,0495  saao/saa17
# P240228              Rm 2,0596  saao/saa17
# P240255                Sm 0267  saao/saa17
# P240261                Sm 0346  saao/saa17
# P240284               Sm 1213+  saao/saa17
# P240285               Sm 2169+  saao/saa17
# P240308                Sm 0740  saao/saa17
# P240311               Sm 1650+  saao/saa17
# P240360                Sm 1243  saao/saa17
# P240426                Sm 1919  saao/saa17
# P240432                Sm 1975  saao/saa17
# P334701                Sm 0501  saao/saa17
# P334712                Sm 1915  saao/saa17
# P334717                Rm 0054  saao/saa17
# P336156                K 07527  saao/saa17
#
# [1998 rows x 5 columns]

# %% [markdown]
# ## Manipulate
# The Dataframe may now be manipulated with standard Pandas methods. The example code selects the texts from Ur.
# > `ur = df1[df1.provenience == "Ur"]`

# %% [markdown]
# ## Save
# Save the resulting data set as a `csv` file. `UTF-8` encoding is the encoding with the widest support in text analysis (and also the encoding used by [ORACC](http://oracc.org)). If you intend to use the catalog file in Excel, however, it is better to use `utf-16` encoding.

# %%
filename = 'catalog.csv'
with open('output/' + filename, 'w', encoding='utf-8') as w:
    df1.to_csv(w)
