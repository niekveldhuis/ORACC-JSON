# %% [markdown]
# # Retrieve Catalog Data from `catalogue.json`
#
# The file `catalogue.json` contains all the catalog data for an [ORACC](http://oracc.org) project (for general information, see the [Oracc Open Data](http://oracc.org/doc/opendata) page). The file can be found at `http://oracc.org/[PROJECT]/catalogue.json`. In the URL replace [PROJECT] with your project or sub-project name (e.g. `dcclt` or `cams/gkab`).
#
# The file `catalogue.json` of each project is also included in the file `PROJECT.zip` in https://github.com/oracc/json/.
#
# The main item in a `catalogue.json` file is called `members`, which contains the information about all the items in the project catalog.

# %%
import requests
import pandas as pd

# %% [markdown]
# ## Select Project
# Select the project or subproject of interest. Subprojects are indicated as `[PROJECT]/[SUBPROJECT]` or `[PROJECT]/[SUBPROJECT]/[SUBPROJECT]`.

# %%
project = input('Project or subproject abbreviation: ')
project = project.strip().lower()
# Out:
# Project or subproject abbreviation: rimanum

# %% [markdown]
# ## Access File and Create Dataframe
# The `requests` library creates a Python `dictionary` out of a JSON file with the `.json()` function. The JSON catalogue file has all the P, Q, and X numbers of a project under the key `members`.
#
# The resulting dictionary `d` has the text ID numbers (P, Q, and X numbers) as keys, the value is another dictionary where each key is a field (`provenience`, `primary_publication`, etc) and the value is the content of that field.

# %%
url = 'http://oracc.org/' + project + '/catalogue.json'
f = requests.get(url, timeout = 3)
d = f.json()
d = d['members']

# %% [markdown]
# ## Create Dataframe
# After the dictionary is transformed into a Pandas Dataframe, it needs to be transposed, so that the P, Q, and X numbers become indexes or row names (rather than column names), and each column represents a field in the catalog.
#
# Creating a Dataframe is not necessary, one may also manipulate the dictionary directly, but for demonstration purposes the Dataframe is a handy format. In manipulating the dictionary directly it is important to keep in mind that not all catalog fields have data for all entries, which means that not all dictionary keys are available for each P, Q, or X number.
#
# Example code for slicing the dictionary to select all entries that have `provenience = 'Ur'`:
# > `urcat = {key:value for key, value in d.items() if 'provenience' in d[key] and d[key]['provenience'] == 'Ur'}

# %%
df = pd.DataFrame(d).T.fillna('')
df
# Out:
#         accession_no        ark_number    atf_source        atf_up  \
# P295625               21198/zz001wkcn7
# P296047               21198/zz001wk2cr
# P296277               21198/zz001wwhh4
# P296278               21198/zz001wwhjn
# P296414               21198/zz001x50db
# P297038               21198/zz001wg725
# P311964               21198/zz002084qg
# P368396               21198/zz001zzv7j  Seri, Andrea  20130125.atf
# P368398               21198/zz001zzv9k  Seri, Andrea  20130125.atf
# P372766               21198/zz00222mwz
# P372788               21198/zz0021wtnk
# P372789               21198/zz0021wtp3
# P372790               21198/zz0021wtqm
# P372791               21198/zz0021wtr4
# P372792               21198/zz0021wtsn
# P372793               21198/zz0021wtt5
# P372794               21198/zz0021wtvp
# P372795               21198/zz0021wtw6
# P372796               21198/zz0021wtxq
# P372797               21198/zz0021wtz7
# P372798               21198/zz00226x0n
# P372799               21198/zz00226x15
# P372800               21198/zz00226x2p
# P372801               21198/zz00226x36
# P372802               21198/zz00226x4q
# P372803               21198/zz00226x57
# P372804               21198/zz00226x6r
# P372805               21198/zz00226x78
# P372806               21198/zz00226x8s
# P373740               21198/zz00226zrh
# ...              ...               ...           ...           ...
# P405439               21198/zz0022tfkr
# P405440               21198/zz0022tfm8
# P405441               21198/zz0022tfns
# P405442               21198/zz0022tfp9
# P405443               21198/zz0022tfqt
# P405444               21198/zz0022tfrb
# P405445               21198/zz0022tfsv
# P405446               21198/zz0022tftc
# P405447               21198/zz00201101
# P405448               21198/zz0020111j
# P405449               21198/zz00201122
# P450684               21198/zz002h4rw5
# P450685               21198/zz002h4rnj
# P450686               21198/zz002h4rp2
# P450687               21198/zz002h4rqk
# P450688               21198/zz002h4rr3
# P450689               21198/zz002h4rxp
# P450690               21198/zz002h4s8b
# P450691               21198/zz002h4s7t
# P450692               21198/zz002h4s5s
# P450693               21198/zz002h4s69
# P450694               21198/zz002h4s3r
# P450695               21198/zz002h4s48
# P450696               21198/zz002h4s1q
# P450697               21198/zz002h4s27
# P450698               21198/zz002h4rz6
# P450699               21198/zz002h4s06
# P450700               21198/zz002h4htr
# P450701               21198/zz002h4hv8
# P450702               21198/zz002h4hrq
#
#                            author    author_remarks  \
# P295625       Simmons, Stephen D.
# P296047       Simmons, Stephen D.
# P296277       Simmons, Stephen D.
# P296278       Simmons, Stephen D.
# P296414       Simmons, Stephen D.
# P297038       Simmons, Stephen D.
# P311964       Simmons, Stephen D.
# P368396              Seri, Andrea         bit asari
# P368398              Seri, Andrea     female slaves
# P372766          Figulla, Hugo H.
# P372788          Figulla, Hugo H.
# P372789          Figulla, Hugo H.
# P372790          Figulla, Hugo H.
# P372791          Figulla, Hugo H.
# P372792          Figulla, Hugo H.
# P372793          Figulla, Hugo H.
# P372794          Figulla, Hugo H.
# P372795          Figulla, Hugo H.
# P372796          Figulla, Hugo H.
# P372797          Figulla, Hugo H.
# P372798          Figulla, Hugo H.
# P372799          Figulla, Hugo H.
# P372800          Figulla, Hugo H.
# P372801          Figulla, Hugo H.
# P372802          Figulla, Hugo H.
# P372803          Figulla, Hugo H.
# P372804          Figulla, Hugo H.
# P372805          Figulla, Hugo H.
# P372806          Figulla, Hugo H.
# P373740          Figulla, Hugo H.
# ...                           ...               ...
# P405439            Loretz, Oswald
# P405440            Loretz, Oswald
# P405441            Loretz, Oswald
# P405442            Loretz, Oswald
# P405443            Loretz, Oswald
# P405444            Loretz, Oswald
# P405445            Loretz, Oswald
# P405446            Loretz, Oswald
# P405447  Sanati-M\xFCller, Shirin
# P405448  Sanati-M\xFCller, Shirin
# P405449
# P450684  Sanati-M\xFCller, Shirin
# P450685              Seri, Andrea
# P450686              Seri, Andrea  Flour allocation
# P450687      Rositani, Annunziata
# P450688      Rositani, Annunziata
# P450689      Rositani, Annunziata
# P450690      Rositani, Annunziata
# P450691      Rositani, Annunziata
# P450692      Rositani, Annunziata
# P450693      Rositani, Annunziata
# P450694      Rositani, Annunziata
# P450695      Rositani, Annunziata
# P450696      Rositani, Annunziata
# P450697      Rositani, Annunziata
# P450698      Rositani, Annunziata
# P450699      Rositani, Annunziata
# P450700      Rositani, Annunziata
# P450701      Rositani, Annunziata
# P450702      Rositani, Annunziata
#
#         cdli_remarks_internal_only                    citation  \
# P295625
# P296047  MLC 01297 is the tablet ?
# P296277
# P296278
# P296414
# P297038
# P311964                             CBCY 04, p. 231, YBC 11995
# P368396
# P368398
# P372766
# P372788
# P372789
# P372790
# P372791
# P372792
# P372793
# P372794
# P372795
# P372796
# P372797
# P372798
# P372799
# P372800
# P372801
# P372802
# P372803
# P372804
# P372805
# P372806
# P373740
# ...                            ...                         ...
# P405439
# P405440
# P405441
# P405442
# P405443
# P405444
# P405445
# P405446
# P405447
# P405448
# P405449
# P450684
# P450685
# P450686
# P450687
# P450688
# P450689
# P450690
# P450691
# P450692
# P450693
# P450694
# P450695
# P450696
# P450697
# P450698
# P450699
# P450700
# P450701
# P450702
#
#                                                 collection  \
# P295625  J. Pierpont Morgan Library Collection, Yale Ba...
# P296047  J. Pierpont Morgan Library Collection, Yale Ba...
# P296277  J. Pierpont Morgan Library Collection, Yale Ba...
# P296278  J. Pierpont Morgan Library Collection, Yale Ba...
# P296414  J. Pierpont Morgan Library Collection, Yale Ba...
# P297038  J. Pierpont Morgan Library Collection, Yale Ba...
# P311964  Yale Babylonian Collection, New Haven, Connect...
# P368396  Kalamazoo Valley Museum, Kalamazoo, Michigan, USA
# P368398  Kalamazoo Valley Museum, Kalamazoo, Michigan, USA
# P372766          Vorderasiatisches Museum, Berlin, Germany
# P372788          Vorderasiatisches Museum, Berlin, Germany
# P372789          Vorderasiatisches Museum, Berlin, Germany
# P372790          Vorderasiatisches Museum, Berlin, Germany
# P372791          Vorderasiatisches Museum, Berlin, Germany
# P372792          Vorderasiatisches Museum, Berlin, Germany
# P372793          Vorderasiatisches Museum, Berlin, Germany
# P372794          Vorderasiatisches Museum, Berlin, Germany
# P372795          Vorderasiatisches Museum, Berlin, Germany
# P372796          Vorderasiatisches Museum, Berlin, Germany
# P372797          Vorderasiatisches Museum, Berlin, Germany
# P372798          Vorderasiatisches Museum, Berlin, Germany
# P372799          Vorderasiatisches Museum, Berlin, Germany
# P372800          Vorderasiatisches Museum, Berlin, Germany
# P372801          Vorderasiatisches Museum, Berlin, Germany
# P372802          Vorderasiatisches Museum, Berlin, Germany
# P372803          Vorderasiatisches Museum, Berlin, Germany
# P372804          Vorderasiatisches Museum, Berlin, Germany
# P372805          Vorderasiatisches Museum, Berlin, Germany
# P372806          Vorderasiatisches Museum, Berlin, Germany
# P373740          Vorderasiatisches Museum, Berlin, Germany
# ...                                                    ...
# P405439                         British Museum, London, UK
# P405440                         British Museum, London, UK
# P405441                         British Museum, London, UK
# P405442                         British Museum, London, UK
# P405443                         British Museum, London, UK
# P405444                         British Museum, London, UK
# P405445                         British Museum, London, UK
# P405446                         British Museum, London, UK
# P405447                                          unlocated
# P405448                                          unlocated
# P405449                         British Museum, London, UK
# P450684                                          unlocated
# P450685  Oriental Institute, University of Chicago, Chi...
# P450686  Oriental Institute, University of Chicago, Chi...
# P450687                         British Museum, London, UK
# P450688                         British Museum, London, UK
# P450689                         British Museum, London, UK
# P450690                         British Museum, London, UK
# P450691                         British Museum, London, UK
# P450692                         British Museum, London, UK
# P450693                         British Museum, London, UK
# P450694                         British Museum, London, UK
# P450695                         British Museum, London, UK
# P450696                         British Museum, London, UK
# P450697                         British Museum, London, UK
# P450698                         British Museum, London, UK
# P450699                         British Museum, London, UK
# P450700                         British Museum, London, UK
# P450701                         British Museum, London, UK
# P450702                         British Museum, London, UK
#
#         collection_remarks_internal_only   ...    publication_date  \
# P295625                                    ...                1978
# P296047                                    ...                1978
# P296277                                    ...                1978
# P296278                                    ...                1978
# P296414                                    ...                1978
# P297038                                    ...                1978
# P311964                                    ...                1978
# P368396                                    ...                2007
# P368398                                    ...                2007
# P372766                                    ...                1914
# P372788                                    ...                1914
# P372789                                    ...                1914
# P372790                                    ...                1914
# P372791                                    ...                1914
# P372792                                    ...                1914
# P372793                                    ...                1914
# P372794                                    ...                1914
# P372795                                    ...                1914
# P372796                                    ...                1914
# P372797                                    ...                1914
# P372798                                    ...                1914
# P372799                                    ...                1914
# P372800                                    ...                1914
# P372801                                    ...                1914
# P372802                                    ...                1914
# P372803                                    ...                1914
# P372804                                    ...                1914
# P372805                                    ...                1914
# P372806                                    ...                1914
# P373740                                    ...                1914
# ...                                  ...   ...                 ...
# P405439                                    ...                1978
# P405440                                    ...                1978
# P405441                                    ...                1978
# P405442                                    ...                1978
# P405443                                    ...                1978
# P405444                                    ...                1978
# P405445                                    ...                1978
# P405446                                    ...                1978
# P405447                                    ...                1996
# P405448                                    ...                1996
# P405449                                    ...
# P450684                                    ...                1996
# P450685                                    ...                2013
# P450686                                    ...                2013
# P450687                                    ...                2009
# P450688                                    ...                2009
# P450689                                    ...                2009
# P450690                                    ...                2009
# P450691                                    ...                2009
# P450692                                    ...                2009
# P450693                                    ...                2009
# P450694                                    ...                2009
# P450695                                    ...                2009
# P450696                                    ...                2009
# P450697                                    ...                2009
# P450698                                    ...                2009
# P450699                                    ...                2009
# P450700                                    ...                2009
# P450701                                    ...                2009
# P450702                                    ...                2009
#
#                                        publication_history seal_id  \
# P295625                                                         Sx
# P296047  Scheil, Vincent, RT 20 (1898) 064-065 (MLC 01297)      Sx
# P296277                                                         Sx
# P296278
# P296414                                                         Sx
# P297038                                                         Sx
# P311964                                                         Sx
# P368396
# P368398
# P372766
# P372788
# P372789
# P372790
# P372791
# P372792
# P372793
# P372794
# P372795
# P372796
# P372797
# P372798
# P372799
# P372800
# P372801
# P372802
# P372803
# P372804
# P372805
# P372806
# P373740
# ...                                                    ...     ...
# P405439
# P405440
# P405441
# P405442
# P405443
# P405444
# P405445
# P405446
# P405447
# P405448
# P405449
# P450684
# P450685
# P450686
# P450687
# P450688
# P450689
# P450690
# P450691
# P450692
# P450693
# P450694
# P450695
# P450696
# P450697
# P450698
# P450699
# P450700
# P450701
# P450702
#
#                      subgenre  subgenre_remarks supergenre thickness  \
# P295625      bit asiri  flour                          ELA        20
# P296047                        bit asiri people        ELA        26
# P296277      bit asiri people                          ELA        23
# P296278      bit asiri people                          ELA        24
# P296414      bit asiri people                          ELA        28
# P297038      bit asiri people                          ELA        23
# P311964      bit asiri  flour                          ELA        18
# P368396      bit asiri people                          ELA         ?
# P368398      bit asiri people                          ELA         ?
# P372766      bit asiri people                          ELA
# P372788               cattle?                          ELA
# P372789      bit asiri people                          ELA
# P372790      bit asiri  flour                          ELA
# P372791      bit asiri  flour                          ELA
# P372792      bit asiri people                          ELA
# P372793      bit asiri people                          ELA
# P372794      bit asiri  flour                          ELA
# P372795      bit asiri  flour                          ELA
# P372796      bit asiri people                          ELA
# P372797      bit asiri  flour                          ELA
# P372798      bit asiri people                          ELA
# P372799      bit asiri people                          ELA
# P372800      bit asiri  flour                          ELA
# P372801      bit asiri  flour                          ELA
# P372802      bit asiri  flour                          ELA
# P372803      bit asiri people                          ELA
# P372804      bit asiri  flour                          ELA
# P372805      bit asiri  flour                          ELA
# P372806      bit asiri  flour                          ELA
# P373740      bit asiri  flour                          ELA
# ...                       ...               ...        ...       ...
# P405439      bit asiri  flour                          ELA
# P405440      bit asiri  flour                          ELA
# P405441      bit asiri  flour                          ELA
# P405442      bit asiri  flour                          ELA
# P405443      bit asiri people                          ELA
# P405444      bit asiri  flour                          ELA
# P405445     bit asiri  people                          ELA
# P405446     bit asiri  people                          ELA
# P405447  bit asiri (?) people                          ELA
# P405448               receipt                          ELA
# P405449  bit asiri (?) people                          ELA
# P450684                 wood?                          ELA
# P450685            memorandum                          ELA
# P450686       bit asiri flour                          ELA
# P450687       bit asiri flour                          ELA
# P450688       bit asiri flour                          ELA
# P450689       bit asiri flour                          ELA
# P450690       bit asiri flour                          ELA
# P450691       bit asiri flour                          ELA
# P450692       bit asiri flour                          ELA
# P450693       bit asiri flour                          ELA
# P450694       bit asiri flour                          ELA
# P450695       bit asiri flour                          ELA
# P450696       bit asiri flour                          ELA
# P450697       bit asiri flour                          ELA
# P450698       bit asiri flour                          ELA
# P450699       bit asiri flour                          ELA
# P450700       bit asiri flour                          ELA
# P450701       bit asiri flour                          ELA
# P450702       bit asiri flour                          ELA
#
#                                   uri width xproject
# P295625  http://cdli.ucla.edu/P295625    35     CDLI
# P296047  http://cdli.ucla.edu/P296047    54     CDLI
# P296277  http://cdli.ucla.edu/P296277    43     CDLI
# P296278  http://cdli.ucla.edu/P296278    45     CDLI
# P296414  http://cdli.ucla.edu/P296414    50     CDLI
# P297038  http://cdli.ucla.edu/P297038    38     CDLI
# P311964  http://cdli.ucla.edu/P311964    33     CDLI
# P368396  http://cdli.ucla.edu/P368396    85     CDLI
# P368398  http://cdli.ucla.edu/P368398    38     CDLI
# P372766  http://cdli.ucla.edu/P372766           CDLI
# P372788  http://cdli.ucla.edu/P372788           CDLI
# P372789  http://cdli.ucla.edu/P372789           CDLI
# P372790  http://cdli.ucla.edu/P372790           CDLI
# P372791  http://cdli.ucla.edu/P372791           CDLI
# P372792  http://cdli.ucla.edu/P372792           CDLI
# P372793  http://cdli.ucla.edu/P372793           CDLI
# P372794  http://cdli.ucla.edu/P372794           CDLI
# P372795  http://cdli.ucla.edu/P372795           CDLI
# P372796  http://cdli.ucla.edu/P372796           CDLI
# P372797  http://cdli.ucla.edu/P372797           CDLI
# P372798  http://cdli.ucla.edu/P372798           CDLI
# P372799  http://cdli.ucla.edu/P372799           CDLI
# P372800  http://cdli.ucla.edu/P372800           CDLI
# P372801  http://cdli.ucla.edu/P372801           CDLI
# P372802  http://cdli.ucla.edu/P372802           CDLI
# P372803  http://cdli.ucla.edu/P372803           CDLI
# P372804  http://cdli.ucla.edu/P372804           CDLI
# P372805  http://cdli.ucla.edu/P372805           CDLI
# P372806  http://cdli.ucla.edu/P372806           CDLI
# P373740  http://cdli.ucla.edu/P373740           CDLI
# ...                               ...   ...      ...
# P405439  http://cdli.ucla.edu/P405439           CDLI
# P405440  http://cdli.ucla.edu/P405440           CDLI
# P405441  http://cdli.ucla.edu/P405441           CDLI
# P405442  http://cdli.ucla.edu/P405442           CDLI
# P405443  http://cdli.ucla.edu/P405443           CDLI
# P405444  http://cdli.ucla.edu/P405444           CDLI
# P405445  http://cdli.ucla.edu/P405445           CDLI
# P405446  http://cdli.ucla.edu/P405446           CDLI
# P405447  http://cdli.ucla.edu/P405447           CDLI
# P405448  http://cdli.ucla.edu/P405448           CDLI
# P405449  http://cdli.ucla.edu/P405449           CDLI
# P450684  http://cdli.ucla.edu/P450684           CDLI
# P450685  http://cdli.ucla.edu/P450685           CDLI
# P450686  http://cdli.ucla.edu/P450686           CDLI
# P450687  http://cdli.ucla.edu/P450687           CDLI
# P450688  http://cdli.ucla.edu/P450688           CDLI
# P450689  http://cdli.ucla.edu/P450689           CDLI
# P450690  http://cdli.ucla.edu/P450690           CDLI
# P450691  http://cdli.ucla.edu/P450691           CDLI
# P450692  http://cdli.ucla.edu/P450692           CDLI
# P450693  http://cdli.ucla.edu/P450693           CDLI
# P450694  http://cdli.ucla.edu/P450694           CDLI
# P450695  http://cdli.ucla.edu/P450695           CDLI
# P450696  http://cdli.ucla.edu/P450696           CDLI
# P450697  http://cdli.ucla.edu/P450697           CDLI
# P450698  http://cdli.ucla.edu/P450698           CDLI
# P450699  http://cdli.ucla.edu/P450699           CDLI
# P450700  http://cdli.ucla.edu/P450700           CDLI
# P450701  http://cdli.ucla.edu/P450701           CDLI
# P450702  http://cdli.ucla.edu/P450702           CDLI
#
# [375 rows x 49 columns]

# %% [markdown]
# ## Select Relevant Fields
# First display all available fields, then select the ones that are relevant for the task at hand. The function `fillna('')` will put a blank (instead of `NaN`) in all fields that have no entry.

# %%
df.columns
# Out:
# Index(['accession_no', 'ark_number', 'atf_source', 'atf_up', 'author',
#        'author_remarks', 'cdli_remarks_internal_only', 'citation',
#        'collection', 'collection_remarks_internal_only', 'date_entered',
#        'date_of_origin', 'date_remarks', 'date_updated', 'dates_referenced',
#        'db_source', 'designation', 'excavation_no', 'genre', 'height', 'id',
#        'id_text', 'images', 'join_information', 'langs', 'language',
#        'lineart_up', 'material', 'museum_no', 'object_type', 'period',
#        'photo_up', 'primary_publication', 'project', 'provenience',
#        'provenience_remarks', 'public', 'public_atf', 'public_images',
#        'publication_date', 'publication_history', 'seal_id', 'subgenre',
#        'subgenre_remarks', 'supergenre', 'thickness', 'uri', 'width',
#        'xproject'],
#       dtype='object')

# %%
df1 = df[['designation', 'period', 'provenience',
        'museum_no']]
df1
# Out:
#                     designation          period        provenience  \
# P295625             YOS 14, 341  Old Babylonian  Uruk (mod. Warka)
# P296047             YOS 14, 338  Old Babylonian  Uruk (mod. Warka)
# P296277             YOS 14, 339  Old Babylonian  Uruk (mod. Warka)
# P296278             YOS 14, 342  Old Babylonian  Uruk (mod. Warka)
# P296414             YOS 14, 337  Old Babylonian  Uruk (mod. Warka)
# P297038             YOS 14, 340  Old Babylonian  Uruk (mod. Warka)
# P311964             YOS 14, 346  Old Babylonian  Uruk (mod. Warka)
# P368396    CDLJ 2007/1 \xA73.45  Old Babylonian  Uruk (mod. Warka)
# P368398    CDLJ 2007/1 \xA73.47  Old Babylonian  Uruk (mod. Warka)
# P372766              VS 13, 013  Old Babylonian  Uruk (mod. Warka)
# P372788              VS 13, 035  Old Babylonian  Uruk (mod. Warka)
# P372789              VS 13, 036  Old Babylonian  Uruk (mod. Warka)
# P372790              VS 13, 037  Old Babylonian  Uruk (mod. Warka)
# P372791              VS 13, 038  Old Babylonian  Uruk (mod. Warka)
# P372792              VS 13, 039  Old Babylonian  Uruk (mod. Warka)
# P372793              VS 13, 040  Old Babylonian  Uruk (mod. Warka)
# P372794              VS 13, 041  Old Babylonian  Uruk (mod. Warka)
# P372795              VS 13, 042  Old Babylonian  Uruk (mod. Warka)
# P372796              VS 13, 043  Old Babylonian  Uruk (mod. Warka)
# P372797              VS 13, 044  Old Babylonian  Uruk (mod. Warka)
# P372798              VS 13, 045  Old Babylonian  Uruk (mod. Warka)
# P372799              VS 13, 046  Old Babylonian  Uruk (mod. Warka)
# P372800              VS 13, 047  Old Babylonian  Uruk (mod. Warka)
# P372801              VS 13, 048  Old Babylonian  Uruk (mod. Warka)
# P372802              VS 13, 049  Old Babylonian  Uruk (mod. Warka)
# P372803              VS 13, 050  Old Babylonian  Uruk (mod. Warka)
# P372804              VS 13, 052  Old Babylonian  Uruk (mod. Warka)
# P372805              VS 13, 053  Old Babylonian  Uruk (mod. Warka)
# P372806              VS 13, 054  Old Babylonian  Uruk (mod. Warka)
# P373740              VS 13, 051  Old Babylonian  Uruk (mod. Warka)
# ...                         ...             ...                ...
# P405439           UF 10, 156 33  Old Babylonian  Uruk (mod. Warka)
# P405440           UF 10, 156 34  Old Babylonian  Uruk (mod. Warka)
# P405441           UF 10, 157 35  Old Babylonian  Uruk (mod. Warka)
# P405442           UF 10, 157 36  Old Babylonian  Uruk (mod. Warka)
# P405443           UF 10, 158 37  Old Babylonian  Uruk (mod. Warka)
# P405444           UF 10, 158 38  Old Babylonian  Uruk (mod. Warka)
# P405445           UF 10, 159 39  Old Babylonian  Uruk (mod. Warka)
# P405446           UF 10, 159 40  Old Babylonian  Uruk (mod. Warka)
# P405447        BagM 31, 124 320  Old Babylonian  Uruk (mod. Warka)
# P405448    BagM 31, 125-126 321  Old Babylonian  Uruk (mod. Warka)
# P405449  Nisaba 04 app, 195-197  Old Babylonian  Uruk (mod. Warka)
# P450684        BagM 31, 103 281  Old Babylonian  Uruk (mod. Warka)
# P450685             SANER 2, 25  Old Babylonian  Uruk (mod. Warka)
# P450686             SANER 2, 26  Old Babylonian  Uruk (mod. Warka)
# P450687              RSO 82, 01  Old Babylonian  Uruk (mod. Warka)
# P450688              RSO 82, 02  Old Babylonian  Uruk (mod. Warka)
# P450689              RSO 82, 03  Old Babylonian  Uruk (mod. Warka)
# P450690              RSO 82, 04  Old Babylonian  Uruk (mod. Warka)
# P450691              RSO 82, 05  Old Babylonian  Uruk (mod. Warka)
# P450692              RSO 82, 06  Old Babylonian  Uruk (mod. Warka)
# P450693              RSO 82, 07  Old Babylonian  Uruk (mod. Warka)
# P450694              RSO 82, 08  Old Babylonian  Uruk (mod. Warka)
# P450695              RSO 82, 09  Old Babylonian  Uruk (mod. Warka)
# P450696              RSO 82, 10  Old Babylonian  Uruk (mod. Warka)
# P450697              RSO 82, 11  Old Babylonian  Uruk (mod. Warka)
# P450698              RSO 82, 12  Old Babylonian  Uruk (mod. Warka)
# P450699              RSO 82, 13  Old Babylonian  Uruk (mod. Warka)
# P450700              RSO 82, 14  Old Babylonian  Uruk (mod. Warka)
# P450701              RSO 82, 15  Old Babylonian  Uruk (mod. Warka)
# P450702              RSO 82, 16  Old Babylonian  Uruk (mod. Warka)
#
#                      museum_no
# P295625              MLC 00837
# P296047  MLC 01284 & MLC 01297
# P296277              MLC 01588
# P296278              MLC 01589
# P296414              MLC 01741
# P297038              MLC 02650
# P311964              YBC 11995
# P368396            KVM 32.1160
# P368398            KVM 32.1186
# P372766              VAT 05589
# P372788              VAT 05139
# P372789              VAT 03964
# P372790              VAT 03955
# P372791              VAT 03953
# P372792              VAT 04349
# P372793              VAT 03883
# P372794              VAT 03854
# P372795              VAT 03872
# P372796              VAT 04317
# P372797              VAT 03954
# P372798              VAT 03939
# P372799              VAT 03931
# P372800              VAT 02958
# P372801              VAT 03928
# P372802              VAT 03965
# P372803              VAT 03886
# P372804              VAT 03855
# P372805              VAT 03863
# P372806              VAT 03875
# P373740              VAT 03877
# ...                        ...
# P405439              BM 014162
# P405440              BM 014175
# P405441              BM 014182
# P405442              BM 014188
# P405443              BM 014211
# P405444              BM 014212
# P405445              BM 014228
# P405446              BM 014231
# P405447              uncertain
# P405448              uncertain
# P405449              BM 016379
# P450684              uncertain
# P450685                A 04700
# P450686                A 04906
# P450687           BM 086048bis
# P450688             BM 086093a
# P450689             BM 086095a
# P450690              BM 086145
# P450691             BM 087738a
# P450692              BM 088510
# P450693              BM 088533
# P450694             BM 088588a
# P450695              BM 088601
# P450696              BM 088619
# P450697              BM 088694
# P450698              BM 088701
# P450699              BM 088802
# P450700              BM 088817
# P450701              BM 088977
# P450702              BM 088980
#
# [375 rows x 4 columns]

# %% [markdown]
# ## Manipulate
# The Dataframe may now be manipulated with standard Pandas methods. The example code selects the texts from Ur.
# > `ur = df1[df1.provenience == "Ur"]`

# %% [markdown]
# ## Save
# Save the resulting data set as a `csv` file. `UTF-8` encoding is the encoding with the widest support in text analysis (and also the encoding used by [ORACC](http://oracc.org). If you intend to use the catalog file in Excel, however, it is better to use `utf-16` encoding.

# %%
filename = project.replace('/', '-') + '_cat.csv'
with open('output/' + filename, 'w') as w:
    df1.to_csv(w, encoding='utf-8')
